# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 46.0 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7

# %%
import rasterio
import torch
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms, datasets
import matplotlib.pyplot as plt
import os
import shutil
import random
from google.colab import drive
import sys
import time
import json
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from PIL import Image

# %%
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#path = '/content/drive/MyDrive/Academico/Computer Vision'
#sys.path.append(path)
base_dir = os.getcwd()

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
def determine_max_pixel_value(data):
    max_value = 0
    for item in data:
        with rasterio.open(item['image_path']) as src:
            max_value = max(max_value, src.read([1,2,3]).max())
    return max_value

# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader
import rasterio
import numpy as np
from torchvision import transforms

# Function to load data from JSON file
def load_data(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)
    return data

def scale_and_normalize_image(image, max_value):
    image = np.array(image).astype(np.float32)
    image = (image / image.max()) * 255
    return image/max_value

class TiffDataset(Dataset):
    def __init__(self, data, transform=None, max_value = 255.0):
        self.data = data
        self.transform = transform
        self.max_value = max_value

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):

        item = self.data[idx]
        with rasterio.open(item['image_path']) as src:
            image = src.read([1,2,3])  # Read RGB bands
            image = np.transpose(image, (1, 2, 0))  # Channels last
            image = scale_and_normalize_image(image, self.max_value)

        if self.transform:
          image = self.transform(image)


        label = item['label']
        return image, label


# Load data from JSON files
train_json_file = base_dir + '/Data/Train_80.json'
test_json_file = base_dir + '/Data/Test_20.json'
train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

#max_pixel_value = determine_max_pixel_value(train_data)
max_pixel_value = 255.0
# Define transformations


transform_tr = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(degrees=180),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.Resize((224,224)),






])


transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((224,224))

])

# Determine the max pixel value from the training dataset for normalization

# Create datasets
train_dataset = TiffDataset(train_data, transform=transform_tr, max_value=max_pixel_value)
test_dataset = TiffDataset(test_data, transform=transform_val, max_value=max_pixel_value)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
import torch.nn as nn
import torch.optim as optim
import time

model = models.resnet50(weights="DEFAULT")
num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 2)

# Move the model to GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Multi-class classification
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Define a learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1) #Drop to 0.0001 after 50 epochs

# Training function
def train_model(model, criterion, optimizer, train_loader, val_loader, scheduler, num_epochs=100):
    best_acc = 0.0
    best_model_wts = None
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        corrects = 0
        start_time = time.time()

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            corrects += torch.sum(preds == labels.data)

        scheduler.step()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = corrects.double() / len(train_loader.dataset)
        elapsed_time = time.time() - start_time
        print(f"Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}, Time: {elapsed_time:.2f}s")

        # Validate the model
        model.eval()
        val_loss = 0.0
        corrects = 0
        all_labels = []
        all_preds = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                corrects += torch.sum(preds == labels.data)
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(preds.cpu().numpy())

        val_loss /= len(val_loader.dataset)
        val_acc = corrects.double() / len(val_loader.dataset)
        print(f"Validation Loss: {val_loss:.4f}, Accuracy: {val_acc:.4f}")
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = model.state_dict()
            best_all_labels = all_labels
            best_all_preds = all_preds

    model.load_state_dict(best_model_wts)


    torch.save(model.state_dict(), base_dir + '/Redes_entrenadas/Resnet50_not_enhanced.pth')
    print('Model saved with accuracy: {:.4f}'.format(best_acc))

    cm = confusion_matrix(best_all_labels, best_all_preds)
    cr = classification_report(best_all_labels, best_all_preds)
    accuracy = (np.array(best_all_preds) == np.array(best_all_labels)).mean()
    print("Matriz de Confusión:")
    print(cm)
    print("Reporte de Clasificación:")
    print(cr)
    print(f"Accuracy: {accuracy:.4f}")

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Clase 0', 'Clase 1'], yticklabels=['Clase 0', 'Clase 1'])
    plt.xlabel('Predicción')
    plt.ylabel('Verdadero')
    plt.title('Matriz de Confusión')
    plt.show()

# Train the model
train_model(model, criterion, optimizer, train_loader, test_loader, scheduler, num_epochs=100)
# Out:
# Epoch 0/99, Loss: 0.5472, Accuracy: 0.7184, Time: 83.50s
# Validation Loss: 1.5267, Accuracy: 0.6683
# Epoch 1/99, Loss: 0.5200, Accuracy: 0.7599, Time: 44.82s
# Validation Loss: 0.5284, Accuracy: 0.7277
# Epoch 2/99, Loss: 0.4160, Accuracy: 0.8077, Time: 33.34s
# Validation Loss: 0.7613, Accuracy: 0.8243
# Epoch 3/99, Loss: 0.3657, Accuracy: 0.8368, Time: 34.80s
# Validation Loss: 0.6631, Accuracy: 0.6188
# Epoch 4/99, Loss: 0.3661, Accuracy: 0.8449, Time: 42.88s
# Validation Loss: 0.3358, Accuracy: 0.8564
# Epoch 5/99, Loss: 0.3280, Accuracy: 0.8604, Time: 33.00s
# Validation Loss: 0.3240, Accuracy: 0.8540
# Epoch 6/99, Loss: 0.3246, Accuracy: 0.8666, Time: 31.56s
# Validation Loss: 0.3130, Accuracy: 0.8787
# Epoch 7/99, Loss: 0.3253, Accuracy: 0.8598, Time: 34.59s
# Validation Loss: 0.3789, Accuracy: 0.8218
# Epoch 8/99, Loss: 0.3220, Accuracy: 0.8629, Time: 44.37s
# Validation Loss: 0.2903, Accuracy: 0.8787
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x78d294286830>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x78d294286830>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x78d294286830>
# Traceback (most recent call last):
# Exception ignored in:   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x78d294286830>
# self._shutdown_workers()Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         self._shutdown_workers()if w.is_alive():
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         if w.is_alive():
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# AssertionError    : assert self._parent_pid == os.getpid(), 'can only test a child process'can only test a child process
#
# AssertionError: can only test a child process
# Epoch 9/99, Loss: 0.3044, Accuracy: 0.8778, Time: 33.71s
# Validation Loss: 0.3898, Accuracy: 0.8540
# Epoch 10/99, Loss: 0.3039, Accuracy: 0.8766, Time: 32.68s
# Validation Loss: 0.3140, Accuracy: 0.8787
# Epoch 11/99, Loss: 0.2978, Accuracy: 0.8710, Time: 44.53s
# Validation Loss: 0.4514, Accuracy: 0.8045
# Epoch 12/99, Loss: 0.3015, Accuracy: 0.8660, Time: 33.61s
# Validation Loss: 0.4253, Accuracy: 0.8688
# Epoch 13/99, Loss: 0.2931, Accuracy: 0.8759, Time: 33.63s
# Validation Loss: 0.3699, Accuracy: 0.8639
# Epoch 14/99, Loss: 0.2866, Accuracy: 0.8803, Time: 43.24s
# Validation Loss: 0.4970, Accuracy: 0.7450
# Epoch 15/99, Loss: 0.2821, Accuracy: 0.8834, Time: 32.27s
# Validation Loss: 0.3719, Accuracy: 0.8564
# Epoch 16/99, Loss: 0.3001, Accuracy: 0.8734, Time: 33.43s
# Validation Loss: 0.3509, Accuracy: 0.8812
# Epoch 17/99, Loss: 0.2826, Accuracy: 0.8828, Time: 44.20s
# Validation Loss: 0.3009, Accuracy: 0.8812
# Epoch 18/99, Loss: 0.2680, Accuracy: 0.8890, Time: 33.55s
# Validation Loss: 0.4546, Accuracy: 0.8168
# Epoch 19/99, Loss: 0.2890, Accuracy: 0.8797, Time: 33.48s
# Validation Loss: 0.3264, Accuracy: 0.8639
# Epoch 20/99, Loss: 0.2711, Accuracy: 0.8846, Time: 42.80s
# Validation Loss: 1.5435, Accuracy: 0.5322
# Epoch 21/99, Loss: 0.2826, Accuracy: 0.8784, Time: 34.24s
# Validation Loss: 0.8039, Accuracy: 0.8218
# Epoch 22/99, Loss: 0.3016, Accuracy: 0.8710, Time: 34.33s
# Validation Loss: 0.3587, Accuracy: 0.8490
# Epoch 23/99, Loss: 0.2820, Accuracy: 0.8759, Time: 49.89s
# Validation Loss: 0.3076, Accuracy: 0.8762
# Epoch 24/99, Loss: 0.2791, Accuracy: 0.8790, Time: 33.19s
# Validation Loss: 0.3458, Accuracy: 0.8837
# Epoch 25/99, Loss: 0.2753, Accuracy: 0.8790, Time: 33.16s
# Validation Loss: 0.9343, Accuracy: 0.6807
# Epoch 26/99, Loss: 0.2537, Accuracy: 0.8970, Time: 43.31s
# Validation Loss: 0.3308, Accuracy: 0.8688
# Epoch 27/99, Loss: 0.2659, Accuracy: 0.8865, Time: 34.39s
# Validation Loss: 0.2912, Accuracy: 0.8911
# Epoch 28/99, Loss: 0.2765, Accuracy: 0.8803, Time: 31.74s
# Validation Loss: 0.6584, Accuracy: 0.7995
# Epoch 29/99, Loss: 0.2505, Accuracy: 0.8983, Time: 43.21s
# Validation Loss: 1.7183, Accuracy: 0.5099
# Epoch 30/99, Loss: 0.2649, Accuracy: 0.8865, Time: 35.54s
# Validation Loss: 0.8152, Accuracy: 0.6411
# Epoch 31/99, Loss: 0.2676, Accuracy: 0.8933, Time: 32.56s
# Validation Loss: 0.3506, Accuracy: 0.8564
# Epoch 32/99, Loss: 0.2598, Accuracy: 0.8852, Time: 43.09s
# Validation Loss: 3.0461, Accuracy: 0.5272
# Epoch 33/99, Loss: 0.2581, Accuracy: 0.8952, Time: 34.38s
# Validation Loss: 0.5064, Accuracy: 0.8317
# Epoch 34/99, Loss: 0.2525, Accuracy: 0.9007, Time: 36.98s
# Validation Loss: 1.0993, Accuracy: 0.7104
# Epoch 35/99, Loss: 0.2376, Accuracy: 0.9026, Time: 46.65s
# Validation Loss: 0.9521, Accuracy: 0.6337
# Epoch 36/99, Loss: 0.2687, Accuracy: 0.8877, Time: 36.47s
# Validation Loss: 0.4386, Accuracy: 0.8515
# Epoch 37/99, Loss: 0.2702, Accuracy: 0.8896, Time: 35.52s
# Validation Loss: 0.2686, Accuracy: 0.8886
# Epoch 38/99, Loss: 0.2620, Accuracy: 0.8890, Time: 43.76s
# Validation Loss: 0.8314, Accuracy: 0.7426
# Epoch 39/99, Loss: 0.2631, Accuracy: 0.8908, Time: 36.29s
# Validation Loss: 0.5748, Accuracy: 0.7673
# Epoch 40/99, Loss: 0.2385, Accuracy: 0.9007, Time: 37.58s
# Validation Loss: 0.5473, Accuracy: 0.8490
# Epoch 41/99, Loss: 0.2268, Accuracy: 0.9001, Time: 45.84s
# Validation Loss: 0.4328, Accuracy: 0.8639
# Epoch 42/99, Loss: 0.2296, Accuracy: 0.9007, Time: 37.02s
# Validation Loss: 0.6148, Accuracy: 0.7649
# Epoch 43/99, Loss: 0.2451, Accuracy: 0.8995, Time: 35.42s
# Validation Loss: 0.4013, Accuracy: 0.8837
# Epoch 44/99, Loss: 0.2426, Accuracy: 0.8933, Time: 35.73s
# Validation Loss: 0.3418, Accuracy: 0.8861
# Epoch 45/99, Loss: 0.2535, Accuracy: 0.8883, Time: 34.35s
# Validation Loss: 0.3695, Accuracy: 0.8762
# Epoch 46/99, Loss: 0.2585, Accuracy: 0.8927, Time: 43.25s
# Validation Loss: 0.2721, Accuracy: 0.8787
# Epoch 47/99, Loss: 0.2262, Accuracy: 0.9057, Time: 35.53s
# Validation Loss: 0.2681, Accuracy: 0.8936
# Epoch 48/99, Loss: 0.2225, Accuracy: 0.9107, Time: 34.86s
# Validation Loss: 4.9922, Accuracy: 0.4975
# Epoch 49/99, Loss: 0.2403, Accuracy: 0.8921, Time: 42.28s
# Validation Loss: 0.8058, Accuracy: 0.7401
# Epoch 50/99, Loss: 0.2104, Accuracy: 0.9138, Time: 34.72s
# Validation Loss: 0.2516, Accuracy: 0.9059
# Epoch 51/99, Loss: 0.2147, Accuracy: 0.9088, Time: 35.81s
# Validation Loss: 0.2464, Accuracy: 0.9010
# Epoch 52/99, Loss: 0.1910, Accuracy: 0.9262, Time: 42.95s
# Validation Loss: 0.2541, Accuracy: 0.8985
# Epoch 53/99, Loss: 0.1948, Accuracy: 0.9206, Time: 35.29s
# Validation Loss: 0.2455, Accuracy: 0.9059
# Epoch 54/99, Loss: 0.1926, Accuracy: 0.9225, Time: 35.58s
# Validation Loss: 0.2490, Accuracy: 0.8985
# Epoch 55/99, Loss: 0.1904, Accuracy: 0.9225, Time: 42.99s
# Validation Loss: 0.2613, Accuracy: 0.8985
# Epoch 56/99, Loss: 0.1955, Accuracy: 0.9256, Time: 34.75s
# Validation Loss: 0.2496, Accuracy: 0.8985
# Epoch 57/99, Loss: 0.1856, Accuracy: 0.9231, Time: 33.78s
# Validation Loss: 0.2533, Accuracy: 0.9035
# Epoch 58/99, Loss: 0.1725, Accuracy: 0.9367, Time: 41.50s
# Validation Loss: 0.2497, Accuracy: 0.9035
# Epoch 59/99, Loss: 0.1694, Accuracy: 0.9336, Time: 33.75s
# Validation Loss: 0.2489, Accuracy: 0.8985
# Epoch 60/99, Loss: 0.1736, Accuracy: 0.9287, Time: 35.07s
# Validation Loss: 0.2633, Accuracy: 0.9109
# Epoch 61/99, Loss: 0.1840, Accuracy: 0.9268, Time: 36.06s
# Validation Loss: 0.2936, Accuracy: 0.8936
# Epoch 62/99, Loss: 0.1729, Accuracy: 0.9324, Time: 36.13s
# Validation Loss: 0.2733, Accuracy: 0.9035
# Epoch 63/99, Loss: 0.1652, Accuracy: 0.9336, Time: 35.58s
# Validation Loss: 0.2858, Accuracy: 0.9035
# Epoch 64/99, Loss: 0.1628, Accuracy: 0.9342, Time: 42.22s
# Validation Loss: 0.2782, Accuracy: 0.8985
# Epoch 65/99, Loss: 0.1567, Accuracy: 0.9324, Time: 37.38s
# Validation Loss: 0.2900, Accuracy: 0.9010
# Epoch 66/99, Loss: 0.1656, Accuracy: 0.9349, Time: 34.42s
# Validation Loss: 0.2974, Accuracy: 0.8936
# Epoch 67/99, Loss: 0.1763, Accuracy: 0.9330, Time: 42.99s
# Validation Loss: 0.3112, Accuracy: 0.8837
# Epoch 68/99, Loss: 0.1622, Accuracy: 0.9305, Time: 35.19s
# Validation Loss: 0.3066, Accuracy: 0.9084
# Epoch 69/99, Loss: 0.1534, Accuracy: 0.9380, Time: 35.21s
# Validation Loss: 0.2927, Accuracy: 0.9035
# Epoch 70/99, Loss: 0.1656, Accuracy: 0.9299, Time: 45.42s
# Validation Loss: 0.3268, Accuracy: 0.8960
# Epoch 71/99, Loss: 0.1477, Accuracy: 0.9367, Time: 35.28s
# Validation Loss: 0.3254, Accuracy: 0.8985
# Epoch 72/99, Loss: 0.1551, Accuracy: 0.9361, Time: 34.09s
# Validation Loss: 0.3407, Accuracy: 0.8936
# Epoch 73/99, Loss: 0.1591, Accuracy: 0.9355, Time: 43.07s
# Validation Loss: 0.3501, Accuracy: 0.9035
# Epoch 74/99, Loss: 0.1407, Accuracy: 0.9417, Time: 36.20s
# Validation Loss: 0.3569, Accuracy: 0.8960
# Epoch 75/99, Loss: 0.1578, Accuracy: 0.9355, Time: 34.11s
# Validation Loss: 0.3370, Accuracy: 0.8985
# Epoch 76/99, Loss: 0.1380, Accuracy: 0.9454, Time: 44.34s
# Validation Loss: 0.3334, Accuracy: 0.8861
# Epoch 77/99, Loss: 0.1623, Accuracy: 0.9429, Time: 35.08s
# Validation Loss: 0.3372, Accuracy: 0.8960
# Epoch 78/99, Loss: 0.1495, Accuracy: 0.9392, Time: 33.59s
# Validation Loss: 0.3890, Accuracy: 0.8911
# Epoch 79/99, Loss: 0.1427, Accuracy: 0.9479, Time: 41.64s
# Validation Loss: 0.3517, Accuracy: 0.8837
# Epoch 80/99, Loss: 0.1436, Accuracy: 0.9423, Time: 34.83s
# Validation Loss: 0.3770, Accuracy: 0.8812
# Epoch 81/99, Loss: 0.1385, Accuracy: 0.9479, Time: 35.49s
# Validation Loss: 0.3979, Accuracy: 0.8762
# Epoch 82/99, Loss: 0.1332, Accuracy: 0.9498, Time: 45.55s
# Validation Loss: 0.3986, Accuracy: 0.9035
# Epoch 83/99, Loss: 0.1301, Accuracy: 0.9498, Time: 34.41s
# Validation Loss: 0.4467, Accuracy: 0.8960
# Epoch 84/99, Loss: 0.1232, Accuracy: 0.9510, Time: 34.37s
# Validation Loss: 0.3854, Accuracy: 0.8837
# Epoch 85/99, Loss: 0.1405, Accuracy: 0.9404, Time: 41.82s
# Validation Loss: 0.3592, Accuracy: 0.8936
# Epoch 86/99, Loss: 0.1278, Accuracy: 0.9473, Time: 35.44s
# Validation Loss: 0.4394, Accuracy: 0.8886
# Epoch 87/99, Loss: 0.1438, Accuracy: 0.9491, Time: 35.23s
# Validation Loss: 0.4105, Accuracy: 0.8812
# Epoch 88/99, Loss: 0.1154, Accuracy: 0.9541, Time: 42.66s
# Validation Loss: 0.3970, Accuracy: 0.8837
# Epoch 89/99, Loss: 0.1448, Accuracy: 0.9386, Time: 35.12s
# Validation Loss: 0.4193, Accuracy: 0.8861
# Epoch 90/99, Loss: 0.1365, Accuracy: 0.9380, Time: 34.85s
# Validation Loss: 0.4116, Accuracy: 0.8738
# Epoch 91/99, Loss: 0.1397, Accuracy: 0.9423, Time: 38.25s
# Validation Loss: 0.3512, Accuracy: 0.8960
# Epoch 92/99, Loss: 0.1339, Accuracy: 0.9448, Time: 32.54s
# Validation Loss: 0.3377, Accuracy: 0.8936
# Epoch 93/99, Loss: 0.1122, Accuracy: 0.9597, Time: 32.71s
# Validation Loss: 0.3935, Accuracy: 0.8886
# Epoch 94/99, Loss: 0.1260, Accuracy: 0.9473, Time: 31.78s
# Validation Loss: 0.3919, Accuracy: 0.8713
# Epoch 95/99, Loss: 0.1279, Accuracy: 0.9479, Time: 40.47s
# Validation Loss: 0.3882, Accuracy: 0.8812
# Epoch 96/99, Loss: 0.1207, Accuracy: 0.9516, Time: 34.42s
# Validation Loss: 0.3726, Accuracy: 0.8936
# Epoch 97/99, Loss: 0.1222, Accuracy: 0.9553, Time: 32.47s
# Validation Loss: 0.3850, Accuracy: 0.8886
# Epoch 98/99, Loss: 0.1126, Accuracy: 0.9566, Time: 39.10s
# Validation Loss: 0.3516, Accuracy: 0.9010
# Epoch 99/99, Loss: 0.1297, Accuracy: 0.9498, Time: 31.89s
# Validation Loss: 0.3767, Accuracy: 0.8936
# Model saved with accuracy: 0.9109
# Matriz de Confusión:
# [[171  24]
#  [ 12 197]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       195
#            1       0.89      0.94      0.92       209
#
#     accuracy                           0.91       404
#    macro avg       0.91      0.91      0.91       404
# weighted avg       0.91      0.91      0.91       404
#
# Accuracy: 0.9109

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
import os
import numpy as np
import rasterio
import matplotlib.pyplot as plt


# Mover el modelo a GPU si está disponible
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = models.resnet50(weights="DEFAULT")
num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 2)
model = model.to(device)

# Cargar el estado guardado del modelo
model_save_path = base_dir + '/Redes_entrenadas/Resnet50_not_enhanced.pth'
model.load_state_dict(torch.load(model_save_path))
model.eval()  # Configurar el modelo en modo evaluación

# Definir las transformaciones de las imágenes

def scale_and_normalize_image(image, max_value):
    image = np.array(image).astype(np.float32)
    image = (image / image.max()) * 255
    return image / max_value




def determine_max_pixel_value(data):
    max_value = 0
    #data = [os.path.join(image_dir, img) for img in os.listdir(image_dir) if img.endswith('.tif')]
    data = base_dir + '/Data/Sentinel2_Buenos_Aires.tif'
    #for item in data:
    with rasterio.open(data) as src:
            max_value = max(max_value, src.read([1,2,3]).max())
    return max_value


class LandSet(Dataset):
    def __init__(self, image_dir,transform=None,max_value = 255.0):
        self.image_dir = image_dir
        self.transform = transform
        self.image_paths = [os.path.join(image_dir, img) for img in os.listdir(image_dir) if img.endswith('.tif')]
        self.max_value = max_value


    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        with rasterio.open(img_path) as src:
            image = src.read([1,2,3])  # Read RGB bands
            image = np.transpose(image, (1, 2, 0))  # Channels last
            image = scale_and_normalize_image(image, self.max_value)

        if self.transform:
          image = self.transform(image)
        return image, img_path



transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((224,224))





])


image_dir = base_dir + '/Data/Sentinel2'
#max_pixel_value = determine_max_pixel_value(image_dir)
max_pixel_value = 255
# Crear el dataset y el dataloader

dataset = LandSet(image_dir=image_dir, transform=transform, max_value=max_pixel_value)
data_loader = DataLoader(dataset, batch_size=32, shuffle=False, num_workers=4)

# Función para predecir si una imagen es un slum

def predict_slum(data_loader):
    model.eval()
    predictions = []
    image_paths = []

    with torch.no_grad():
        for inputs, paths in data_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            print(outputs)
            _, preds = torch.max(outputs, 1)
            predictions.extend(preds.cpu().numpy())
            image_paths.extend(paths)


    return image_paths, predictions

# Usar el DataLoader para hacer predicciones
image_paths, predictions = predict_slum(data_loader)

# Mostrar resultados
for path, pred in zip(image_paths, predictions):
    print(f'Image: {path}, Predicted: {"Slum" if pred == 1 else "Not Slum"}')
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#         [-4.1851,  4.5668],
#         [ 5.3431, -5.2522],
#         [ 4.5400, -4.5018],
#         [ 8.1226, -8.2055],
#         [ 6.9311, -6.9479],
#         [-3.0647,  3.5022],
#         [ 2.9809, -3.0110],
#         [ 2.4896, -2.3286],
#         [ 6.4408, -6.4788],
#         [-2.6925,  3.1230],
#         [-2.7395,  3.2208],
#         [-0.7597,  1.2389]], device='cuda:0')
# tensor([[ -3.3391,   3.8747],
#         [ -3.4941,   3.9130],
#         [ -2.1305,   2.6094],
#         [  0.6674,  -0.4636],
#         [  5.3518,  -5.4429],
#         [  3.4438,  -3.3971],
#         [  2.4035,  -2.2340],
#         [  8.8875,  -8.7815],
#         [  5.0910,  -5.0815],
#         [  2.9442,  -2.7423],
#         [  0.3056,   0.2109],
#         [ -3.2420,   3.6558],
#         [  6.8746,  -6.9185],
#         [ 15.1847, -15.6461],
#         [  4.5028,  -4.3549],
#         [  2.6293,  -2.5718],
#         [  6.1560,  -6.0486],
#         [  6.0587,  -6.1258],
#         [  7.3611,  -7.5208],
#         [  2.2714,  -2.0501],
#         [  6.1619,  -6.1110],
#         [ -1.1123,   1.3369],
#         [ -1.1230,   1.3801],
#         [  3.4568,  -3.3824],
#         [ -1.6483,   1.9644],
#         [  4.5665,  -4.5216],
#         [ -2.0952,   2.4594],
#         [ -0.1001,   0.3564],
#         [ -2.1285,   2.5278],
#         [  2.3109,  -2.1842],
#         [ -3.2549,   3.5574],
#         [ -0.9253,   1.2423]], device='cuda:0')
# tensor([[ 4.1041, -3.9274],
#         [-0.3226,  0.4769],
#         [-1.5618,  1.8137],
#         [-2.2889,  2.7578],
#         [ 7.7827, -7.9044],
#         [ 5.0996, -5.0292],
#         [ 1.0487, -0.7814],
#         [-3.9519,  4.4123],
#         [-0.4260,  0.6808],
#         [ 4.5659, -4.4218],
#         [ 0.8303, -0.7032],
#         [-0.6403,  0.8414],
#         [-0.8725,  1.1390],
#         [ 3.3363, -3.3248],
#         [ 3.1658, -3.0624],
#         [ 7.4006, -7.5394],
#         [ 1.5165, -1.4332],
#         [ 2.0687, -1.7733],
#         [ 5.6831, -5.4072],
#         [ 8.4263, -8.5144],
#         [ 4.8074, -4.7579],
#         [ 9.1897, -9.3081],
#         [ 6.1333, -6.1177],
#         [ 3.2707, -3.3364],
#         [ 4.2593, -4.1605],
#         [ 4.0402, -4.0486],
#         [ 8.9076, -8.9463],
#         [-1.4086,  1.8649],
#         [-5.2037,  5.6678],
#         [-2.4143,  2.9638],
#         [-3.6894,  4.1489],
#         [ 0.0431,  0.3830]], device='cuda:0')
# tensor([[ -6.9670,   7.4627],
#         [  9.6560,  -9.6309],
#         [  6.6845,  -6.7529],
#         [  9.8207, -10.0807],
#         [  4.8821,  -4.8017],
#         [  5.9619,  -6.0550],
#         [  1.4083,  -1.3036],
#         [  1.0281,  -0.7421],
#         [  0.3059,   0.1859],
#         [  2.5392,  -2.4251],
#         [  1.5559,  -1.4716],
#         [  6.4959,  -6.6256],
#         [  2.4527,  -2.5066],
#         [  1.2360,  -1.0173],
#         [ -0.9693,   1.2524],
#         [  4.4189,  -4.4100],
#         [  3.9637,  -3.7564],
#         [  2.5217,  -2.4520],
#         [  0.8494,  -0.7150],
#         [  3.7794,  -3.6342],
#         [  7.9081,  -7.9049],
#         [  8.2764,  -8.2110],
#         [  4.5331,  -4.6188],
#         [ -2.6173,   2.9799],
#         [  1.7191,  -1.5573],
#         [  0.2504,   0.1244],
#         [  4.2118,  -3.9386],
#         [ -2.2353,   2.4941],
#         [  5.5432,  -5.5386],
#         [ -8.7518,   9.4703],
#         [  5.0919,  -5.0320],
#         [  2.6637,  -2.5143]], device='cuda:0')
# tensor([[ 4.1616, -4.1941],
#         [-0.2686,  0.4408],
#         [ 2.6551, -2.6464],
#         [-1.6181,  1.9893],
#         [-0.3606,  0.6872],
#         [-8.1216,  8.6773],
#         [ 0.1706, -0.1186],
#         [-6.0033,  6.5189],
#         [ 1.2263, -1.0425],
#         [ 1.5465, -1.4637],
#         [-1.5232,  1.8190],
#         [ 3.0250, -2.9271],
#         [ 2.5408, -2.3282],
#         [-0.2574,  0.3955],
#         [-4.0092,  4.5908],
#         [ 3.7672, -3.5621],
#         [ 4.6464, -4.3900],
#         [ 2.4060, -2.1599],
#         [ 5.9647, -5.9458],
#         [ 9.2419, -9.3410],
#         [ 5.2020, -5.1605],
#         [ 6.4427, -6.6179],
#         [-1.4284,  1.6922],
#         [ 4.3507, -4.1241],
#         [ 4.2503, -4.0889],
#         [ 8.0034, -8.0327],
#         [ 0.7516, -0.3513],
#         [ 0.8068, -0.4223],
#         [-0.4455,  0.7455],
#         [-2.3318,  2.6989],
#         [ 2.4339, -2.3561],
#         [ 7.8726, -8.1052]], device='cuda:0')
# tensor([[  7.7067,  -7.8605],
#         [ -2.3768,   2.6330],
#         [  0.1975,   0.1782],
#         [  7.9340,  -7.8279],
#         [  3.5358,  -3.2498],
#         [  0.3101,   0.0235],
#         [ -3.5985,   4.0369],
#         [ -4.0363,   4.5608],
#         [  7.6184,  -7.5915],
#         [ 22.7170, -23.2019],
#         [  7.3267,  -7.6427],
#         [  0.8786,  -0.7725],
#         [  8.1524,  -8.3061],
#         [  0.3279,  -0.1314],
#         [  0.4821,  -0.2576],
#         [ -3.3324,   3.6678],
#         [  0.2164,   0.1298],
#         [ -0.6190,   0.9435],
#         [  3.0962,  -2.9970],
#         [  3.0775,  -2.8879],
#         [  3.5047,  -3.3371],
#         [  2.3084,  -2.1314],
#         [  2.9887,  -2.8746],
#         [ -0.0435,   0.2089],
#         [  2.0957,  -1.9495],
#         [  3.5860,  -3.5348],
#         [  7.9065,  -8.1707],
#         [ -0.8691,   0.9923],
#         [ -1.0565,   1.4063],
#         [ -3.2257,   3.6304],
#         [ -1.3459,   1.7559],
#         [ -1.0914,   1.2505]], device='cuda:0')
# tensor([[ -4.0885,   4.4910],
#         [ -1.9179,   2.1938],
#         [  5.6055,  -5.7931],
#         [  5.3834,  -5.3352],
#         [  0.8345,  -0.6868],
#         [ -3.5562,   3.9912],
#         [ -0.7339,   1.0089],
#         [ -1.2372,   1.4496],
#         [  2.2215,  -2.1089],
#         [ -0.4936,   0.8046],
#         [  5.2844,  -5.3731],
#         [  3.8132,  -3.9732],
#         [ -0.9343,   1.2486],
#         [  2.4489,  -2.1475],
#         [  3.2752,  -3.2818],
#         [  7.3656,  -7.5064],
#         [  6.8640,  -6.8242],
#         [ 14.3640, -14.4601],
#         [ 11.7848, -12.0641],
#         [ -4.3177,   4.8845],
#         [-11.0243,  11.7623],
#         [ -5.6822,   6.1627],
#         [  4.5111,  -4.5336],
#         [  1.6689,  -1.5071],
#         [  7.4771,  -7.4788],
#         [  5.9731,  -5.9363],
#         [ -2.4264,   2.7015],
#         [ -0.6730,   0.9557],
#         [ 14.1805, -14.3761],
#         [  6.0553,  -6.1801],
#         [  1.1175,  -0.6693],
#         [  5.3268,  -5.2076]], device='cuda:0')
# tensor([[  3.6441,  -3.5225],
#         [ -0.0954,   0.3821],
#         [  1.1758,  -0.9714],
#         [  4.8766,  -4.8544],
#         [  4.9766,  -4.9296],
#         [ -5.5996,   6.2624],
#         [ 11.5305, -11.6122],
#         [  0.1114,  -0.0940],
#         [  1.7871,  -1.6248],
#         [ -2.3796,   2.7569],
#         [  7.4143,  -7.4987],
#         [  4.6318,  -4.7151],
#         [  4.3682,  -4.3555],
#         [ -1.4007,   1.7262],
#         [  0.4881,  -0.1678],
#         [  0.8293,  -0.7763],
#         [  3.4051,  -3.2191],
#         [  3.7623,  -3.7223],
#         [  3.3713,  -3.3166],
#         [  6.0558,  -5.9411],
#         [  2.6565,  -2.6474],
#         [ -9.6748,  10.4290],
#         [  6.6382,  -6.7098],
#         [  3.4222,  -3.4473],
#         [ 11.6361, -11.9200],
#         [ -0.8936,   1.1184],
#         [  0.4049,  -0.1529],
#         [  2.4383,  -2.2107],
#         [ -4.5842,   5.1716],
#         [ -0.9914,   1.2568],
#         [ -2.3971,   2.7427],
#         [ -8.7219,   9.2299]], device='cuda:0')
# tensor([[  0.7951,  -0.7242],
#         [  0.9391,  -0.8795],
#         [  7.0158,  -6.9182],
#         [  6.8409,  -7.1320],
#         [  5.9579,  -6.1058],
#         [ -0.0916,   0.2906],
#         [  3.1124,  -3.1624],
#         [  0.0473,   0.1547],
#         [  2.0894,  -2.1438],
#         [  2.8380,  -2.7574],
#         [  3.7831,  -3.7129],
#         [  1.4450,  -1.1831],
#         [ 11.7464, -11.9037],
#         [  0.5695,  -0.1632],
#         [  2.6149,  -2.4063],
#         [  6.1850,  -6.2630],
#         [  1.6172,  -1.5152],
#         [ -1.1116,   1.4766],
#         [ -3.7923,   4.3221],
#         [  1.4013,  -1.3490],
#         [  6.8729,  -6.9407],
#         [  6.9528,  -6.8402],
#         [  2.5233,  -2.4549],
#         [  7.8214,  -7.8481],
#         [  5.9397,  -6.0844],
#         [  7.2084,  -7.3090],
#         [ -2.7124,   3.3149],
#         [-11.6632,  12.4759],
#         [ -5.2764,   5.8510],
#         [  1.7392,  -1.8009],
#         [  7.4069,  -7.4489],
#         [ 10.3354, -10.3385]], device='cuda:0')
# tensor([[ 3.8835e+00, -3.8022e+00],
#         [-1.7276e+00,  2.0693e+00],
#         [-3.5843e+00,  3.9907e+00],
#         [ 5.4763e+00, -5.4997e+00],
#         [ 4.5155e+00, -4.4931e+00],
#         [-4.8802e+00,  5.4197e+00],
#         [ 3.5932e+00, -3.6831e+00],
#         [ 2.1272e+00, -2.0187e+00],
#         [ 2.7340e+00, -2.8400e+00],
#         [-2.7685e+00,  3.1164e+00],
#         [ 1.1343e+00, -1.0454e+00],
#         [ 3.6305e-01, -1.1706e-01],
#         [-3.9068e+00,  4.3609e+00],
#         [-1.7435e-01,  5.6969e-01],
#         [ 1.2452e+00, -1.1115e+00],
#         [ 1.9657e-01,  2.0686e-03],
#         [ 1.3840e+00, -1.2807e+00],
#         [ 5.0706e+00, -5.0950e+00],
#         [-2.0706e+00,  2.4404e+00],
#         [ 1.1032e+00, -1.0500e+00],
#         [-6.1371e-01,  8.4596e-01],
#         [ 4.5610e+00, -4.6397e+00],
#         [ 3.2937e+00, -3.3062e+00],
#         [ 3.0117e+00, -3.0462e+00],
#         [ 6.2450e+00, -6.1508e+00],
#         [ 3.5691e+00, -3.4267e+00],
#         [ 1.8873e+00, -1.9545e+00],
#         [ 1.4021e+00, -1.3317e+00],
#         [ 4.8281e+00, -4.9585e+00],
#         [ 2.3777e+00, -2.3072e+00],
#         [ 4.1737e-01, -2.9917e-01],
#         [ 4.5326e+00, -4.6215e+00]], device='cuda:0')
# tensor([[  3.5119,  -3.6058],
#         [  8.6823,  -8.9080],
#         [  2.0408,  -1.7816],
#         [  1.3706,  -1.2001],
#         [  5.6104,  -5.5872],
#         [  2.4583,  -2.2483],
#         [  8.9065,  -9.1411],
#         [ 14.4492, -14.6234],
#         [  3.7262,  -3.7435],
#         [ -2.6461,   3.0468],
#         [  2.6218,  -2.5793],
#         [  1.1942,  -0.9133],
#         [  3.9658,  -3.9273],
#         [  2.8515,  -2.6535],
#         [  5.6613,  -5.4636],
#         [ -1.2211,   1.4795],
#         [ -1.9938,   2.3601],
#         [ -2.8904,   3.3544],
#         [  2.3805,  -2.1784],
#         [  1.4804,  -1.1979],
#         [  9.2702,  -9.3407],
#         [  5.0256,  -4.9738],
#         [  6.8625,  -7.1293],
#         [ -2.6449,   3.2492],
#         [ -2.2557,   2.6657],
#         [ -2.0630,   2.3983],
#         [  2.0087,  -1.8748],
#         [ -3.0795,   3.4245],
#         [  2.4176,  -2.1328],
#         [  0.6865,  -0.3452],
#         [  2.0326,  -1.8885],
#         [  3.5716,  -3.3538]], device='cuda:0')
# tensor([[  9.5926,  -9.5414],
#         [  3.7853,  -3.5885],
#         [  1.1741,  -1.0608],
#         [ -1.7172,   2.1574],
#         [  2.4854,  -2.4219],
#         [  1.1173,  -0.9002],
#         [ -0.2043,   0.5196],
#         [  0.6963,  -0.4820],
#         [-10.5968,  11.2998],
#         [  3.7902,  -3.6600],
#         [  6.0907,  -6.1082],
#         [ -2.4973,   2.8955],
#         [  0.8505,  -0.6338],
#         [  3.4582,  -3.4296],
#         [  2.7141,  -2.7269],
#         [ -0.6074,   0.7043],
#         [  2.9372,  -3.0154],
#         [  5.4094,  -5.2966],
#         [  5.4302,  -5.4163],
#         [  5.2375,  -5.2687],
#         [  3.6495,  -3.6735],
#         [  3.6882,  -3.6307],
#         [  3.9446,  -3.7103],
#         [ -0.4367,   0.7198],
#         [  2.1236,  -1.9082],
#         [  1.8944,  -1.6964],
#         [  2.0252,  -1.8870],
#         [  0.7820,  -0.5496],
#         [  0.8242,  -0.6067],
#         [  5.1728,  -5.2632],
#         [ 14.7077, -15.3754],
#         [ 15.6216, -16.3448]], device='cuda:0')
# tensor([[ 10.2149, -10.5861],
#         [  5.6829,  -5.5702],
#         [  0.3039,   0.0417],
#         [ -4.9491,   5.4491],
#         [  0.0544,   0.0638],
#         [  6.7019,  -6.8656],
#         [  3.6914,  -3.6680],
#         [  3.4169,  -3.3464],
#         [  1.5396,  -1.1887],
#         [  5.9611,  -5.7605],
#         [  6.3269,  -6.1743],
#         [ -0.1768,   0.5056],
#         [ -1.8832,   2.2563],
#         [ -1.5124,   1.7702],
#         [ 11.7870, -11.6941],
#         [  0.2105,   0.0164],
#         [  3.2369,  -3.0801],
#         [  5.8940,  -5.7958],
#         [  5.2140,  -5.2043],
#         [  1.9315,  -1.8304],
#         [  1.8796,  -1.6967],
#         [  6.2735,  -6.1812],
#         [  3.1420,  -3.0745],
#         [ -1.2468,   1.5624],
#         [  1.9874,  -1.8030],
#         [  0.8380,  -0.7860],
#         [  6.3500,  -6.3087],
#         [ 10.6222, -10.4365],
#         [ 10.2729, -10.2157],
#         [  3.1313,  -2.8241],
#         [ 11.3160, -11.4032],
#         [  3.2425,  -3.2833]], device='cuda:0')
# tensor([[  3.7036,  -3.6005],
#         [  2.0620,  -1.8109],
#         [  3.6966,  -3.5191],
#         [  0.1495,   0.1432],
#         [ -4.2154,   4.5656],
#         [  0.8036,  -0.6932],
#         [  1.1903,  -1.1544],
#         [ -1.5003,   1.9070],
#         [  3.3014,  -3.1017],
#         [  7.4790,  -7.4701],
#         [  3.4074,  -3.4211],
#         [  1.1961,  -0.8038],
#         [  4.9140,  -4.6910],
#         [  1.0405,  -0.9758],
#         [ -3.2662,   3.7673],
#         [ -0.0341,   0.3678],
#         [  2.1746,  -1.9718],
#         [  7.3457,  -7.4982],
#         [  8.6270,  -8.8083],
#         [  6.9683,  -7.0732],
#         [  0.0169,   0.1208],
#         [  5.2495,  -5.1171],
#         [  6.6188,  -6.6196],
#         [ 10.0342,  -9.9767],
#         [  0.2151,   0.0546],
#         [  1.9010,  -1.5815],
#         [  4.7828,  -4.6214],
#         [  4.1145,  -4.1766],
#         [ 15.7061, -16.5515],
#         [  8.5270,  -8.7856],
#         [  4.2817,  -4.3057],
#         [  1.8684,  -1.7715]], device='cuda:0')
# tensor([[ 4.0799, -4.1126],
#         [-0.3373,  0.7192],
#         [ 1.5786, -1.5216],
#         [ 2.6201, -2.5645],
#         [ 4.0256, -4.0511],
#         [-1.7914,  2.2556],
#         [-0.5435,  0.9486],
#         [ 4.0962, -3.8555],
#         [-0.5922,  0.8064],
#         [ 1.7614, -1.7252],
#         [ 2.5987, -2.6554],
#         [ 1.4272, -1.1117],
#         [ 6.1454, -6.1609],
#         [ 2.5334, -2.2443],
#         [-2.6114,  3.0316],
#         [ 2.6551, -2.6059],
#         [-4.3942,  4.7686],
#         [ 3.6690, -3.7930],
#         [ 1.3394, -1.2758],
#         [ 3.4193, -3.1627],
#         [ 7.6070, -7.7949],
#         [ 5.2959, -5.3553],
#         [ 6.8655, -7.0535],
#         [-0.3105,  0.3390],
#         [ 4.8190, -4.8474],
#         [ 2.9870, -2.9666],
#         [ 5.3867, -5.3703],
#         [ 4.1815, -4.0222],
#         [ 6.0124, -5.9599],
#         [ 3.0557, -3.0104],
#         [ 1.1001, -0.9485],
#         [ 8.2331, -8.2988]], device='cuda:0')
# tensor([[  3.4108,  -3.4022],
#         [  1.6322,  -1.6179],
#         [  2.1652,  -1.9039],
#         [ -4.3117,   4.9126],
#         [  2.2192,  -2.1184],
#         [  1.9596,  -1.8043],
#         [  5.3370,  -5.3951],
#         [  1.6797,  -1.6140],
#         [ 12.4074, -12.4656],
#         [ -1.9928,   2.3825],
#         [  0.9415,  -0.7316],
#         [  7.1862,  -7.0375],
#         [  7.1752,  -7.3326],
#         [ 10.5561, -10.7103],
#         [ 10.2341, -10.3764],
#         [  7.2369,  -7.3997],
#         [  7.7748,  -7.8948],
#         [  3.6930,  -3.7237],
#         [  0.7234,  -0.3990],
#         [  3.0464,  -2.9945],
#         [  2.6000,  -2.5858],
#         [  4.5202,  -4.3619],
#         [  8.4005,  -8.3857],
#         [ -2.8908,   3.1287],
#         [  2.7634,  -2.7638],
#         [  3.9204,  -3.9252],
#         [  1.6359,  -1.4961],
#         [  2.2244,  -2.1528],
#         [  6.3551,  -6.2939],
#         [ -4.2148,   4.6428],
#         [  2.0789,  -1.9251],
#         [ -5.9957,   6.4153]], device='cuda:0')
# tensor([[  1.9779,  -1.8972],
#         [ -4.9557,   5.3772],
#         [  0.3489,  -0.0740],
#         [ -1.0937,   1.3391],
#         [ -0.5811,   0.9608],
#         [  2.3117,  -2.0633],
#         [ -0.5484,   0.9321],
#         [  8.9749,  -9.0582],
#         [ 12.7811, -13.0798],
#         [  0.9655,  -0.8743],
#         [ -3.9513,   4.2585],
#         [ -3.2561,   3.7435],
#         [  0.3032,  -0.1157],
#         [ -3.9152,   4.2601],
#         [ -2.8161,   3.0449],
#         [ -1.8604,   2.2293],
#         [  0.2758,  -0.0353],
#         [  4.9097,  -4.8016],
#         [ -2.6935,   3.2068],
#         [  7.0138,  -7.2395],
#         [  8.4145,  -8.2691],
#         [ -3.0731,   3.4105],
#         [  6.8035,  -6.8974],
#         [  8.0567,  -8.2696],
#         [  8.9503,  -9.0821],
#         [  9.9598,  -9.9615],
#         [  0.6726,  -0.4694],
#         [  0.9775,  -0.6980],
#         [  6.5313,  -6.3785],
#         [  2.7205,  -2.5888],
#         [  0.1677,  -0.0539],
#         [  0.8655,  -0.5869]], device='cuda:0')
# tensor([[ -0.9050,   1.1557],
#         [ -0.4822,   0.7186],
#         [ -3.5614,   3.9044],
#         [  1.7692,  -1.5896],
#         [  6.0976,  -6.0978],
#         [  5.4719,  -5.3472],
#         [ 15.1751, -15.4384],
#         [  5.1540,  -5.0047],
#         [  1.9086,  -1.7636],
#         [  4.2559,  -3.9404],
#         [  1.4267,  -1.2274],
#         [  7.4128,  -7.4890],
#         [  4.9751,  -5.0634],
#         [  1.4755,  -1.3371],
#         [  5.0014,  -5.0197],
#         [  3.7458,  -3.6633],
#         [  0.0418,   0.2043],
#         [ -0.3131,   0.5395],
#         [ -1.5864,   1.9009],
#         [  7.0374,  -7.1257],
#         [  5.5562,  -5.3484],
#         [  3.6949,  -3.4091],
#         [-10.2477,  10.9569],
#         [  1.8467,  -1.7440],
#         [  2.2386,  -2.0305],
#         [  7.0910,  -7.1167],
#         [ 11.8348, -12.4834],
#         [  3.4872,  -3.4276],
#         [ -1.4519,   1.6273],
#         [  4.6208,  -4.7319],
#         [ -7.1745,   7.7491],
#         [  1.6757,  -1.4719]], device='cuda:0')
# tensor([[  5.9895,  -5.8968],
#         [  5.6390,  -5.7778],
#         [  9.4112,  -9.4766],
#         [ 11.1627, -11.1586],
#         [  4.2582,  -4.2870],
#         [  4.8326,  -4.8680],
#         [  3.4488,  -3.2809],
#         [  3.7706,  -3.6206],
#         [  6.8899,  -6.8411],
#         [ -0.5302,   0.7006],
#         [ -3.9613,   4.5217],
#         [ -2.8101,   3.1755],
#         [  1.0268,  -0.8929],
#         [  6.8351,  -6.7619],
#         [ -2.2767,   2.4961],
#         [ -4.7032,   5.1547],
#         [  1.2952,  -0.9822],
#         [  8.8882,  -9.0001],
#         [  0.9797,  -0.7559],
#         [  1.9785,  -1.9873],
#         [  9.6326,  -9.8675],
#         [  7.2752,  -7.3895],
#         [  4.4969,  -4.5412],
#         [  7.8669,  -7.9980],
#         [ 18.2104, -18.7146],
#         [  5.6134,  -5.6070],
#         [ -0.2735,   0.5625],
#         [  6.8060,  -6.7396],
#         [ -1.4302,   1.6206],
#         [  6.3499,  -6.2158],
#         [ -6.4521,   6.9832],
#         [ -4.5940,   4.9375]], device='cuda:0')
# tensor([[  2.9603,  -2.9584],
#         [  3.2143,  -3.0696],
#         [  8.6834,  -9.0015],
#         [ 12.2141, -12.3485],
#         [  3.6238,  -3.5646],
#         [  6.4645,  -6.4943],
#         [  3.6351,  -3.3395],
#         [  3.6344,  -3.6232],
#         [  6.8376,  -7.1368],
#         [  0.6047,  -0.3064],
#         [  8.6595,  -8.7714],
#         [  7.5952,  -7.7549],
#         [  2.5199,  -2.3246],
#         [  3.0342,  -2.8211],
#         [  2.4916,  -2.1692],
#         [-11.6471,  12.4421],
#         [  4.4432,  -4.3709],
#         [  8.2485,  -8.3067],
#         [  2.3579,  -2.2374],
#         [  9.3528,  -9.4282],
#         [  0.1418,   0.0419],
#         [  0.4310,  -0.2890],
#         [  2.4910,  -2.5115],
#         [  3.6929,  -3.6826],
#         [  7.5757,  -7.4721],
#         [ -2.5661,   2.9161],
#         [ -3.1871,   3.4878],
#         [  4.4282,  -4.3213],
#         [ -6.1106,   6.6663],
#         [  3.6879,  -3.5933],
#         [  0.6526,  -0.5048],
#         [ 14.0215, -14.0677]], device='cuda:0')
# tensor([[ -0.9789,   1.3059],
#         [  6.3199,  -6.2610],
#         [  5.4973,  -5.5713],
#         [  2.3561,  -2.2661],
#         [  7.0621,  -7.1303],
#         [  6.1675,  -6.2544],
#         [  4.2847,  -4.3014],
#         [ -5.1692,   5.5213],
#         [ -0.5459,   0.8842],
#         [  9.9075, -10.1466],
#         [  6.6884,  -6.9194],
#         [  5.6063,  -5.7065],
#         [  4.3058,  -4.1183],
#         [  1.1606,  -0.8773],
#         [  6.0439,  -5.8889],
#         [  7.6146,  -7.7286],
#         [  6.9384,  -7.0082],
#         [ 10.1661, -10.2968],
#         [  8.3208,  -8.4235],
#         [  8.3201,  -8.4954],
#         [  8.5456,  -8.8103],
#         [  7.0809,  -7.2006],
#         [  9.5999,  -9.7956],
#         [  9.5692,  -9.8857],
#         [  4.8072,  -4.6910],
#         [  0.7067,  -0.5080],
#         [ -1.7912,   2.2145],
#         [  1.0944,  -0.8304],
#         [  0.1416,   0.0396],
#         [ -2.7392,   3.0490],
#         [  1.3964,  -1.4185],
#         [  3.9045,  -3.7545]], device='cuda:0')
# tensor([[ 2.2858, -2.2890],
#         [ 1.0627, -0.9038],
#         [ 2.7484, -2.7532],
#         [ 4.6568, -4.7472],
#         [ 4.5482, -4.6872],
#         [ 6.9429, -7.0576],
#         [ 4.5567, -4.4523],
#         [ 7.9360, -8.0431],
#         [ 5.8135, -5.8976],
#         [ 6.7411, -6.8355],
#         [ 6.4663, -6.4841],
#         [ 4.6588, -4.6396],
#         [-0.6301,  0.9072],
#         [ 6.6591, -6.7965],
#         [ 3.8375, -3.7970],
#         [ 5.3258, -5.2549],
#         [ 1.6070, -1.4526],
#         [-0.9870,  1.2762],
#         [ 1.4282, -1.4234],
#         [-6.6336,  7.1722],
#         [ 2.0259, -2.0020],
#         [-1.5959,  1.8510],
#         [ 5.5367, -5.4171],
#         [-5.0988,  5.6078],
#         [ 3.1722, -3.0992],
#         [ 0.9112, -0.5909],
#         [-2.2871,  2.5298],
#         [ 4.3327, -4.4537],
#         [-3.2229,  3.6820],
#         [ 9.4593, -9.6807],
#         [ 5.4259, -5.3776],
#         [ 4.6755, -4.6713]], device='cuda:0')
# tensor([[  4.6704,  -4.6326],
#         [  6.4708,  -6.5377],
#         [  6.4229,  -6.5636],
#         [  5.9094,  -6.0023],
#         [  5.6945,  -5.7523],
#         [ -3.2918,   3.9012],
#         [  6.7021,  -6.8633],
#         [  7.3235,  -7.4329],
#         [  5.7041,  -5.8027],
#         [  4.8522,  -4.8170],
#         [  7.0335,  -7.1192],
#         [  6.4763,  -6.4999],
#         [ 14.3019, -14.4332],
#         [ 11.8746, -11.9156],
#         [ 10.8534, -11.3139],
#         [  4.7024,  -4.8028],
#         [  8.8098,  -8.9456],
#         [  7.6710,  -7.8466],
#         [  6.3639,  -6.4480],
#         [  6.4274,  -6.5479],
#         [  6.2233,  -6.3352],
#         [  5.2813,  -5.3978],
#         [ 21.8362, -22.3975],
#         [  9.0268,  -9.3548],
#         [ -1.6038,   1.9044],
#         [  1.2839,  -1.0741],
#         [ -4.3135,   4.6703],
#         [  0.7488,  -0.6647],
#         [  3.3750,  -3.3092],
#         [ -2.8290,   3.2557],
#         [ -3.3082,   3.7293],
#         [ -1.1445,   1.3571]], device='cuda:0')
# tensor([[  7.0729,  -7.0504],
#         [  2.8179,  -2.6559],
#         [  2.7180,  -2.5376],
#         [  4.7712,  -4.8063],
#         [  6.1660,  -6.2903],
#         [  8.2510,  -8.2940],
#         [  6.1750,  -6.3092],
#         [  7.0416,  -7.1745],
#         [  6.3094,  -6.3653],
#         [  5.9919,  -6.0746],
#         [ -1.3109,   1.4876],
#         [  0.8991,  -0.7083],
#         [ -2.1698,   2.5127],
#         [  1.4374,  -1.2324],
#         [  6.9222,  -7.1583],
#         [  5.0702,  -5.2475],
#         [  2.3875,  -2.1258],
#         [ -1.2941,   1.6427],
#         [  9.3999,  -9.4306],
#         [  2.1044,  -1.9028],
#         [  1.7102,  -1.6743],
#         [ -0.3207,   0.6073],
#         [ -2.7144,   3.0315],
#         [  0.3257,  -0.1865],
#         [ -3.4073,   3.7610],
#         [ -4.7450,   5.1155],
#         [ -1.1880,   1.4621],
#         [  2.7455,  -2.5725],
#         [  5.5200,  -5.5774],
#         [ -0.7621,   1.1820],
#         [  8.0751,  -8.1832],
#         [ 12.7944, -13.0581]], device='cuda:0')
# tensor([[  5.8268,  -5.9225],
#         [  6.0055,  -6.0662],
#         [  8.0774,  -8.1401],
#         [  8.7998,  -8.8196],
#         [ 10.9114, -11.1553],
#         [  7.4270,  -7.5213],
#         [  7.6232,  -7.7389],
#         [  5.0200,  -5.0851],
#         [  5.9820,  -6.1524],
#         [  7.1427,  -7.1978],
#         [  7.4915,  -7.6231],
#         [  7.3545,  -7.4646],
#         [  6.2886,  -6.3677],
#         [  6.9227,  -6.9784],
#         [  8.4466,  -8.5944],
#         [  6.9351,  -7.0100],
#         [  7.1334,  -7.2084],
#         [  5.1786,  -5.2327],
#         [  1.4658,  -1.3980],
#         [ 11.7792, -11.8749],
#         [ 11.0418, -11.2169],
#         [  5.2435,  -5.3278],
#         [  1.8970,  -1.7718],
#         [  2.0346,  -1.9449],
#         [ -1.4430,   1.7073],
#         [  1.4797,  -1.3308],
#         [  4.7151,  -4.8255],
#         [  1.4297,  -1.2387],
#         [ -4.3210,   4.7740],
#         [  6.2063,  -6.1637],
#         [  5.4853,  -5.4635],
#         [  6.2697,  -6.1668]], device='cuda:0')
# tensor([[  3.9286,  -3.8019],
#         [  7.7479,  -7.6461],
#         [  5.0659,  -4.9920],
#         [  6.4112,  -6.2347],
#         [  8.0563,  -8.2209],
#         [  6.0855,  -6.2988],
#         [  8.4212,  -8.6354],
#         [  2.8292,  -2.5598],
#         [  2.4192,  -2.3245],
#         [  1.2346,  -1.1058],
#         [  4.8617,  -4.7322],
#         [  1.8382,  -1.5121],
#         [  3.7228,  -3.5828],
#         [  3.5046,  -3.4251],
#         [  1.4553,  -1.3175],
#         [  5.9059,  -5.8601],
#         [  5.1862,  -5.2077],
#         [  5.8038,  -5.8086],
#         [  1.1854,  -0.9558],
#         [ -1.3413,   1.6206],
#         [ -4.0327,   4.4718],
#         [ -3.7472,   4.1206],
#         [ -7.8815,   8.5140],
#         [  9.9581, -10.1351],
#         [ 10.3390, -10.3788],
#         [  9.1915,  -9.4059],
#         [  8.7614,  -8.7636],
#         [  1.7062,  -1.5585],
#         [ -8.9589,   9.7052],
#         [  3.8575,  -3.7306],
#         [  3.8845,  -3.7249],
#         [  9.9121, -10.0468]], device='cuda:0')
# tensor([[ 10.2365, -10.3713],
#         [ 12.5386, -12.7637],
#         [  7.3674,  -7.5362],
#         [  7.1170,  -7.2219],
#         [  6.0241,  -6.1123],
#         [  5.8896,  -5.9810],
#         [  6.0958,  -6.1908],
#         [  8.4269,  -8.5668],
#         [  8.6313,  -8.7817],
#         [  5.9555,  -6.0467],
#         [  3.8601,  -3.8462],
#         [  6.8896,  -7.0519],
#         [  9.6706,  -9.8733],
#         [  8.5502,  -8.6964],
#         [  6.9737,  -7.0293],
#         [  6.2627,  -6.3642],
#         [  5.3506,  -5.4291],
#         [  8.4885,  -8.6039],
#         [  2.9338,  -2.9004],
#         [  9.3323,  -9.4457],
#         [  0.6284,  -0.3429],
#         [  1.1075,  -0.9392],
#         [ -2.8582,   3.2042],
#         [  5.9902,  -6.0265],
#         [  0.0195,   0.2230],
#         [ -2.2449,   2.4738],
#         [  0.8337,  -0.7397],
#         [ -2.4264,   2.6479],
#         [  7.3839,  -7.5375],
#         [  1.1162,  -0.8818],
#         [  5.9450,  -5.8980],
#         [ -1.3719,   1.6898]], device='cuda:0')
# tensor([[  6.5216,  -6.4588],
#         [  5.2472,  -5.2704],
#         [  6.0228,  -6.0751],
#         [ 14.6523, -14.9359],
#         [ -0.7471,   1.0965],
#         [ -1.8809,   2.1286],
#         [  5.7738,  -5.9388],
#         [ -0.9834,   1.2301],
#         [ -1.7221,   2.0399],
#         [  3.0727,  -3.0136],
#         [  3.6554,  -3.4366],
#         [  1.3959,  -1.2758],
#         [  5.2977,  -5.4040],
#         [ 13.5671, -13.6295],
#         [  5.0545,  -4.9119],
#         [  1.7110,  -1.7179],
#         [ -7.0058,   7.5555],
#         [ -4.8770,   5.3732],
#         [  0.6350,  -0.3808],
#         [ -4.4757,   4.9352],
#         [ -7.7900,   8.4798],
#         [ -0.7266,   1.1120],
#         [  6.9222,  -6.9948],
#         [  5.0239,  -5.0789],
#         [  7.2734,  -7.2218],
#         [  6.0405,  -6.0261],
#         [ -2.7032,   3.1811],
#         [ -7.0108,   7.6763],
#         [  2.5367,  -2.4026],
#         [  4.1804,  -4.2362],
#         [  3.6430,  -3.7584],
#         [  7.4420,  -7.6205]], device='cuda:0')
# tensor([[  7.3164,  -7.4428],
#         [  6.1903,  -6.3072],
#         [  6.6617,  -6.7780],
#         [  8.8641,  -9.0081],
#         [  8.6689,  -8.8121],
#         [  7.8688,  -8.0032],
#         [  6.5203,  -6.4524],
#         [  9.7044,  -9.7525],
#         [  3.6013,  -3.5694],
#         [  7.4702,  -7.5885],
#         [ 10.7473, -11.0003],
#         [ 10.1060, -10.3309],
#         [  9.1865,  -9.3676],
#         [  6.5696,  -6.6150],
#         [  6.2962,  -6.3550],
#         [  7.4823,  -7.6049],
#         [  4.3319,  -4.2853],
#         [  7.5602,  -7.6650],
#         [  3.7184,  -3.6798],
#         [  4.9210,  -4.9725],
#         [  3.9688,  -3.7910],
#         [  2.2633,  -2.1591],
#         [  3.7763,  -3.7669],
#         [  5.5089,  -5.6159],
#         [ -0.0126,   0.2169],
#         [  2.0636,  -2.0492],
#         [  8.6422,  -8.7549],
#         [  6.2893,  -6.1985],
#         [ -0.4738,   0.6395],
#         [  4.2238,  -4.1655],
#         [  1.6710,  -1.5364],
#         [  1.6949,  -1.5953]], device='cuda:0')
# tensor([[  2.7587,  -2.7089],
#         [  0.6820,  -0.4787],
#         [  2.5606,  -2.3168],
#         [ -2.7583,   3.0872],
#         [ -3.9253,   4.3424],
#         [ -0.8662,   1.0954],
#         [  3.4077,  -3.4219],
#         [  1.4518,  -1.3753],
#         [ -6.2792,   6.8738],
#         [  3.3388,  -3.3890],
#         [  5.9038,  -5.9709],
#         [  2.1395,  -1.9080],
#         [  0.8165,  -0.6190],
#         [ -0.4568,   0.5606],
#         [  3.8848,  -3.9357],
#         [ -7.5450,   8.0724],
#         [ 11.1260, -11.3488],
#         [  2.4259,  -2.3350],
#         [  2.2992,  -2.1659],
#         [  0.9090,  -0.7529],
#         [  6.7474,  -6.8063],
#         [  6.8910,  -6.9840],
#         [  4.8925,  -4.7796],
#         [  5.2711,  -5.4277],
#         [ -4.3969,   4.9296],
#         [  3.9328,  -4.0957],
#         [ -0.0363,   0.3972],
#         [ -5.1030,   5.5416],
#         [ -2.2509,   2.5711],
#         [ 16.8418, -17.0233],
#         [ -5.8348,   6.4499],
#         [ -2.1164,   2.3205]], device='cuda:0')
# tensor([[-0.4430,  0.7190],
#         [-0.0541,  0.3039],
#         [ 4.2233, -4.1913],
#         [ 5.2623, -5.2449],
#         [-0.2448,  0.5339],
#         [-1.1136,  1.3333],
#         [-0.2152,  0.2476],
#         [-2.1220,  2.3751],
#         [-5.9969,  6.5245],
#         [ 3.1825, -2.9850],
#         [ 8.1968, -8.2541],
#         [-1.8295,  2.1095],
#         [ 2.2563, -1.9959],
#         [ 6.2484, -6.1548],
#         [ 1.4235, -1.0622],
#         [-1.8512,  2.3251],
#         [-5.0543,  5.5455],
#         [ 1.3783, -1.2088],
#         [-0.9013,  1.1524],
#         [-0.0138,  0.1708],
#         [ 1.0429, -0.9947],
#         [-2.3941,  2.6702],
#         [ 1.9218, -1.7568],
#         [-0.4072,  0.6787],
#         [ 5.5000, -5.6270],
#         [ 5.1149, -4.9449],
#         [ 4.1473, -4.0633],
#         [-6.2144,  6.7690],
#         [ 0.1459,  0.1101],
#         [-1.1033,  1.3242],
#         [-2.1725,  2.6655],
#         [ 1.6903, -1.5758]], device='cuda:0')
# tensor([[  2.2001,  -2.0493],
#         [  4.3443,  -4.5866],
#         [  1.0595,  -0.7755],
#         [ -4.9348,   5.4873],
#         [  6.6072,  -6.4208],
#         [ -5.2030,   5.6006],
#         [ -2.3159,   2.6541],
#         [ -5.4973,   5.9725],
#         [ -7.7226,   8.3858],
#         [ -4.7585,   5.1866],
#         [  2.5289,  -2.1232],
#         [  3.4503,  -3.3500],
#         [ -5.9596,   6.5646],
#         [-10.3457,  11.0126],
#         [ -2.5743,   2.9762],
#         [ -2.8305,   3.2982],
#         [ -5.6906,   6.1731],
#         [ -6.2747,   6.8320],
#         [ -1.0032,   1.4205],
#         [ -2.0683,   2.3403],
#         [  7.4642,  -7.6002],
#         [  6.2796,  -6.4183],
#         [ -8.4815,   9.1061],
#         [  0.1989,   0.0351],
#         [ -0.7754,   1.0465],
#         [  3.2848,  -3.4046],
#         [ -5.7328,   6.2670],
#         [  2.5470,  -2.2737],
#         [ 18.1181, -18.4033],
#         [ -0.2810,   0.4704],
#         [ 10.7981, -10.7617],
#         [  0.9567,  -0.6676]], device='cuda:0')
# tensor([[  4.9156,  -4.8544],
#         [ 11.3120, -11.4124],
#         [  5.4244,  -5.2696],
#         [  1.3934,  -1.2833],
#         [ -3.4738,   3.8917],
#         [ -1.2108,   1.4907],
#         [ -0.3334,   0.6478],
#         [ -3.3716,   3.8476],
#         [  5.7844,  -5.8033],
#         [  7.8658,  -7.9422],
#         [  2.4295,  -2.3167],
#         [ -1.4354,   1.8172],
#         [ -7.3544,   8.0062],
#         [  9.4793,  -9.5130],
#         [  8.8807,  -9.1464],
#         [  4.0823,  -3.8703],
#         [ -5.1821,   5.7037],
#         [  1.2547,  -1.1226],
#         [  3.4738,  -3.4101],
#         [ 11.0139, -11.3523],
#         [ -2.6301,   3.0139],
#         [ -6.1272,   6.7131],
#         [  3.1378,  -3.1483],
#         [  4.0383,  -4.0102],
#         [  1.1078,  -1.0552],
#         [  2.5036,  -2.4879],
#         [ -4.1317,   4.5900],
#         [ -1.4488,   1.6463],
#         [ -0.8224,   1.0775],
#         [ -1.8518,   2.0844],
#         [  1.2024,  -1.0286],
#         [  9.1269,  -9.1837]], device='cuda:0')
# tensor([[  1.7125,  -1.3671],
#         [  8.7182,  -8.6431],
#         [  9.9921,  -9.9194],
#         [  6.4761,  -6.4705],
#         [  0.7471,  -0.4420],
#         [ -8.5647,   9.2699],
#         [  1.8421,  -1.5128],
#         [ -8.2817,   8.9690],
#         [-10.5493,  11.3094],
#         [ -3.1557,   3.7560],
#         [ -5.1405,   5.6129],
#         [-10.1115,  10.7716],
#         [ -6.6091,   7.2427],
#         [ -4.7547,   5.0608],
#         [  1.1384,  -0.9890],
#         [ -8.6924,   9.1848],
#         [ -2.6510,   3.0833],
#         [ -4.1559,   4.6224],
#         [  1.7501,  -1.5754],
#         [  9.9344, -10.1426],
#         [ -0.2657,   0.3145],
#         [ -0.7877,   1.1760],
#         [ -1.6178,   1.8382],
#         [ -1.4422,   1.9471],
#         [ -0.1662,   0.2103],
#         [  2.0996,  -1.8865],
#         [ 10.2364, -10.2451],
#         [  1.9916,  -1.7751],
#         [ -1.4280,   1.7805],
#         [ -7.0576,   7.5534],
#         [ -1.1072,   1.3833],
#         [ -0.4020,   0.5154]], device='cuda:0')
# tensor([[ -0.4292,   0.7800],
#         [ -0.7141,   1.0626],
#         [ -0.3954,   0.7739],
#         [  3.7720,  -3.7008],
#         [ -6.2065,   6.7789],
#         [ -1.5424,   1.9287],
#         [  7.4489,  -7.7293],
#         [  6.7918,  -6.8444],
#         [  1.7054,  -1.5265],
#         [  3.9758,  -3.8648],
#         [ -5.0494,   5.5196],
#         [ -1.3413,   1.6299],
#         [  6.5485,  -6.5853],
#         [ 11.9407, -12.0573],
#         [ 10.8459, -11.0155],
#         [  3.8259,  -3.7273],
#         [  6.7335,  -6.7391],
#         [  1.0474,  -1.0854],
#         [ -0.0368,   0.1375],
#         [  1.0237,  -0.8216],
#         [ -0.7493,   0.9745],
#         [ -1.8793,   2.1322],
#         [  3.1623,  -3.1564],
#         [  4.6700,  -4.7265],
#         [  0.1275,   0.0988],
#         [ -1.8906,   2.1035],
#         [  0.8127,  -0.6985],
#         [  5.9098,  -6.0057],
#         [  9.4424, -10.1018],
#         [  0.6163,  -0.5640],
#         [ -2.8141,   3.0857],
#         [  1.2426,  -1.1214]], device='cuda:0')
# tensor([[ 3.4789, -3.5032],
#         [ 2.1005, -1.7570],
#         [-2.6573,  3.1844],
#         [-5.4955,  6.0434],
#         [-6.4238,  6.9188],
#         [-3.7636,  4.2928],
#         [-4.7227,  5.1149],
#         [-7.1487,  7.8828],
#         [ 5.7452, -5.6990],
#         [-5.0375,  5.5509],
#         [-2.2439,  2.5573],
#         [-1.6411,  1.7901],
#         [-6.6950,  7.2688],
#         [-3.2662,  3.6112],
#         [ 0.7588, -0.5385],
#         [-3.2156,  3.5908],
#         [-4.5132,  5.0093],
#         [ 3.0377, -3.0599],
#         [ 3.5040, -3.4928],
#         [ 0.3491, -0.1223],
#         [-1.5557,  2.0296],
#         [-0.9867,  1.4343],
#         [-1.4537,  1.7749],
#         [ 4.4993, -4.3547],
#         [ 5.4608, -5.2258],
#         [-1.7306,  2.1634],
#         [-0.4389,  0.6836],
#         [ 2.5606, -2.5216],
#         [ 6.6251, -6.4697],
#         [-0.2389,  0.4549],
#         [ 3.1206, -2.9302],
#         [ 5.3853, -5.0004]], device='cuda:0')
# tensor([[  1.2021,  -1.0745],
#         [  0.6021,  -0.2122],
#         [  0.0961,   0.2506],
#         [  6.4568,  -6.5238],
#         [  6.9879,  -7.0921],
#         [  6.1038,  -6.1962],
#         [  0.7512,  -0.4800],
#         [  7.1710,  -7.2282],
#         [ 10.4163, -10.5351],
#         [ 13.3118, -13.5048],
#         [  9.9000,  -9.8123],
#         [  5.3228,  -5.4361],
#         [  3.2470,  -3.1877],
#         [  3.2689,  -3.3344],
#         [ -5.3654,   5.9252],
#         [ -3.0157,   3.4346],
#         [ -3.5405,   3.9695],
#         [ -4.0691,   4.5739],
#         [ -5.5795,   6.0403],
#         [ -6.1224,   6.5692],
#         [ -3.4731,   3.9680],
#         [  0.1651,   0.2179],
#         [  2.7971,  -2.5837],
#         [  6.9186,  -7.0327],
#         [  8.7524,  -9.1068],
#         [  6.7677,  -6.6839],
#         [  1.2153,  -1.1895],
#         [  1.8367,  -1.8514],
#         [  3.8751,  -4.0051],
#         [ -1.7132,   2.1449],
#         [ -3.2054,   3.5662],
#         [ -3.3539,   3.7156]], device='cuda:0')
# tensor([[ 11.6197, -11.5894],
#         [ -0.7545,   1.0701],
#         [  1.5882,  -1.2356],
#         [ -1.6845,   2.2156],
#         [ -9.5468,  10.2078],
#         [ -5.9291,   6.4393],
#         [ -6.7337,   7.3313],
#         [  1.9713,  -1.7360],
#         [  6.5866,  -6.6949],
#         [ -3.7575,   4.1587],
#         [ -0.4479,   0.8594],
#         [  7.5888,  -7.6789],
#         [  5.4884,  -5.5615],
#         [  6.1919,  -6.1802],
#         [ -6.2870,   6.8118],
#         [ -7.8664,   8.4490],
#         [ -1.9419,   2.3339],
#         [ -0.5286,   0.7713],
#         [  2.5898,  -2.5242],
#         [ -2.5507,   2.9196],
#         [ -4.1993,   4.7317],
#         [  0.7901,  -0.5280],
#         [ 12.1070, -12.0954],
#         [ -3.8922,   4.3353],
#         [-10.7871,  11.6674],
#         [  8.8113,  -8.6286],
#         [ -0.4368,   0.7134],
#         [  1.9747,  -1.8895],
#         [  6.4412,  -6.5002],
#         [ 14.3238, -14.5520],
#         [ -2.5654,   3.0765],
#         [  1.4385,  -1.3291]], device='cuda:0')
# tensor([[  2.6429,  -2.4544],
#         [  4.3670,  -4.3602],
#         [  5.5767,  -5.6494],
#         [  6.7137,  -6.8341],
#         [  9.6506,  -9.7915],
#         [  9.1629,  -9.0983],
#         [ -0.2485,   0.4190],
#         [  4.4639,  -4.1863],
#         [  4.2936,  -3.9762],
#         [  0.6369,  -0.3169],
#         [  2.3488,  -2.2222],
#         [  3.3587,  -3.2149],
#         [  0.4139,  -0.0338],
#         [  1.5738,  -1.3925],
#         [  3.7199,  -3.3760],
#         [ -1.2930,   1.6674],
#         [  2.4953,  -2.5539],
#         [ -1.5098,   1.7679],
#         [ -3.1659,   3.4298],
#         [  0.1526,   0.0203],
#         [ -4.5997,   5.1193],
#         [  5.5427,  -5.6057],
#         [ 13.6273, -13.9229],
#         [  9.8568, -10.1239],
#         [  4.8668,  -5.1992],
#         [  3.2790,  -3.2477],
#         [  3.0443,  -2.8921],
#         [ -0.0218,   0.3964],
#         [  7.2880,  -7.4272],
#         [  0.8643,  -0.7548],
#         [  3.2591,  -3.3319],
#         [  2.7489,  -2.5199]], device='cuda:0')
# tensor([[ -1.1756,   1.6130],
#         [  6.6104,  -6.4640],
#         [ -0.8849,   1.3238],
#         [ -7.6821,   8.2727],
#         [-11.7402,  12.5013],
#         [ -9.2794,  10.0102],
#         [ -3.3972,   3.7858],
#         [ -1.2033,   1.5837],
#         [ -4.8969,   5.2955],
#         [  5.3206,  -5.2924],
#         [  0.7981,  -0.5725],
#         [  5.8341,  -5.9441],
#         [  0.2958,  -0.0637],
#         [ -9.0914,   9.7638],
#         [  2.8933,  -2.8911],
#         [ -2.8442,   3.2806],
#         [ -3.1298,   3.5618],
#         [ -2.0111,   2.3511],
#         [ -0.3958,   0.7397],
#         [ -4.0688,   4.4905],
#         [  4.7868,  -4.7109],
#         [  4.5806,  -4.3609],
#         [ -0.9077,   1.2889],
#         [ -7.0993,   7.5930],
#         [ -2.6400,   2.9717],
#         [  8.2817,  -8.4853],
#         [  7.4906,  -7.5513],
#         [  6.5195,  -6.5545],
#         [  1.9766,  -1.8639],
#         [  1.2164,  -1.0959],
#         [  0.4090,  -0.1961],
#         [  5.8783,  -5.9784]], device='cuda:0')
# tensor([[  9.0688,  -9.1890],
#         [  6.2902,  -6.2514],
#         [  0.2734,  -0.0407],
#         [  2.9229,  -2.7804],
#         [ -4.1352,   4.5721],
#         [  1.7299,  -1.5289],
#         [  4.5304,  -4.3454],
#         [  5.1535,  -5.1167],
#         [  5.4912,  -5.4502],
#         [  3.3687,  -3.2538],
#         [  5.7202,  -5.6200],
#         [ -0.2752,   0.4953],
#         [  1.9324,  -1.6897],
#         [ -1.4438,   1.7673],
#         [ -5.0613,   5.5108],
#         [  0.3648,  -0.1482],
#         [ -0.2834,   0.4410],
#         [  1.2918,  -1.0017],
#         [  6.0430,  -5.6861],
#         [ -2.7334,   3.0373],
#         [ 13.5460, -13.7214],
#         [  6.4047,  -6.4473],
#         [  5.1730,  -5.4204],
#         [ -4.8254,   5.2832],
#         [ -1.8639,   2.1047],
#         [  3.5912,  -3.4029],
#         [ -1.5955,   1.8701],
#         [  1.5101,  -1.3147],
#         [  0.1951,   0.1148],
#         [ -1.5441,   1.8875],
#         [  9.6368,  -9.6800],
#         [ -7.3216,   7.9373]], device='cuda:0')
# tensor([[-6.7836e+00,  7.4030e+00],
#         [-7.0888e+00,  7.6784e+00],
#         [-4.5955e+00,  5.1350e+00],
#         [ 7.0737e+00, -6.8056e+00],
#         [-5.2118e+00,  5.7527e+00],
#         [ 3.0037e+00, -2.7971e+00],
#         [ 4.8593e+00, -4.7201e+00],
#         [ 2.5315e-01, -8.2327e-03],
#         [-1.6602e+00,  1.7923e+00],
#         [-2.1111e+00,  2.3969e+00],
#         [-7.5690e-01,  1.0167e+00],
#         [ 3.6493e+00, -3.5905e+00],
#         [ 4.3202e+00, -4.2821e+00],
#         [-1.5807e+00,  1.9430e+00],
#         [-1.0020e+00,  1.3718e+00],
#         [ 1.4980e+00, -1.2497e+00],
#         [ 2.4225e+00, -2.2117e+00],
#         [ 1.5594e-01,  1.2493e-01],
#         [-1.9523e+00,  2.2495e+00],
#         [-6.4013e+00,  6.9709e+00],
#         [ 2.2148e+00, -2.1054e+00],
#         [ 3.0232e+00, -3.0541e+00],
#         [ 3.0282e+00, -3.0471e+00],
#         [ 4.6893e+00, -4.6321e+00],
#         [ 2.9828e+00, -2.9235e+00],
#         [ 5.6888e+00, -5.7765e+00],
#         [ 6.5468e+00, -6.6105e+00],
#         [ 6.6238e+00, -6.7565e+00],
#         [ 7.1027e+00, -7.2206e+00],
#         [ 9.9939e+00, -1.0306e+01],
#         [ 4.7804e+00, -4.7561e+00],
#         [-1.6161e+00,  1.8612e+00]], device='cuda:0')
# tensor([[-2.9035e+00,  3.3977e+00],
#         [-6.5358e+00,  7.1168e+00],
#         [ 2.6126e+00, -2.3083e+00],
#         [ 6.9323e+00, -6.9202e+00],
#         [ 1.0025e+01, -1.0076e+01],
#         [ 8.5932e+00, -8.5556e+00],
#         [ 9.6218e+00, -9.6254e+00],
#         [ 6.0323e+00, -6.0334e+00],
#         [ 6.6084e+00, -6.9303e+00],
#         [ 2.9668e+00, -3.0746e+00],
#         [ 1.7188e+00, -1.6843e+00],
#         [-5.1708e+00,  5.5751e+00],
#         [-3.6968e+00,  4.1968e+00],
#         [ 3.2146e+00, -3.2064e+00],
#         [ 9.8933e-01, -7.9967e-01],
#         [-4.9680e+00,  5.5006e+00],
#         [ 2.0612e+00, -2.0092e+00],
#         [-3.9105e+00,  4.3504e+00],
#         [ 5.8125e+00, -5.7528e+00],
#         [-1.9931e+00,  2.2975e+00],
#         [ 4.4033e+00, -4.3439e+00],
#         [ 4.8121e+00, -4.5810e+00],
#         [ 2.0362e+00, -1.9754e+00],
#         [ 3.3803e+00, -3.2318e+00],
#         [ 7.7766e-03,  1.2373e-01],
#         [-2.9105e+00,  3.3925e+00],
#         [ 9.9322e-01, -6.8211e-01],
#         [-3.3115e+00,  3.6283e+00],
#         [ 2.2353e+00, -1.9411e+00],
#         [ 4.5206e+00, -4.3812e+00],
#         [-2.7240e+00,  3.3656e+00],
#         [ 5.4920e+00, -5.3612e+00]], device='cuda:0')
# tensor([[-10.4538,  11.1360],
#         [ -2.9494,   3.2912],
#         [ -5.2362,   5.8362],
#         [-10.6781,  11.4254],
#         [  5.6508,  -5.5335],
#         [  1.8421,  -1.7003],
#         [ -2.3190,   2.7201],
#         [ -0.6942,   0.9994],
#         [ -0.4040,   0.8092],
#         [  3.8102,  -3.7774],
#         [  5.8374,  -5.6434],
#         [ -0.7264,   1.0645],
#         [  2.4572,  -2.2665],
#         [  7.4280,  -7.4834],
#         [  1.2162,  -0.9982],
#         [  1.6392,  -1.3924],
#         [ -4.4243,   4.9073],
#         [ -6.0644,   6.5528],
#         [ -3.0047,   3.3856],
#         [  3.6480,  -3.5099],
#         [  4.5614,  -4.3771],
#         [  4.2961,  -4.3680],
#         [  5.7464,  -5.8381],
#         [  8.6573,  -8.8509],
#         [ 10.1560, -10.3995],
#         [  1.0680,  -0.8930],
#         [  7.7861,  -7.6916],
#         [  3.4051,  -3.3697],
#         [ -2.5303,   2.9455],
#         [  0.4622,  -0.2592],
#         [ -1.1334,   1.3575],
#         [ -2.2077,   2.4515]], device='cuda:0')
# tensor([[ -4.1743,   4.6166],
#         [  0.8886,  -0.6078],
#         [  2.3782,  -2.2589],
#         [  6.5171,  -6.6197],
#         [  3.9799,  -3.8176],
#         [  3.7777,  -3.6701],
#         [  3.4210,  -3.3983],
#         [ -1.2471,   1.5453],
#         [-11.4346,  12.2075],
#         [  3.3492,  -3.3609],
#         [  2.2840,  -2.3508],
#         [  2.4172,  -2.3136],
#         [ -1.2773,   1.5447],
#         [ -1.7638,   2.0519],
#         [  5.0494,  -5.1426],
#         [ -1.4243,   1.6616],
#         [  4.2399,  -4.1817],
#         [ -1.2891,   1.5542],
#         [ -3.7088,   4.1199],
#         [  6.4949,  -6.7199],
#         [  9.3277,  -9.4481],
#         [  1.3129,  -1.1519],
#         [  0.2282,   0.0227],
#         [  0.0248,   0.3463],
#         [  2.1249,  -1.9985],
#         [  0.8368,  -0.5512],
#         [ -0.8124,   1.1653],
#         [ -1.7400,   2.2421],
#         [  3.0643,  -2.8235],
#         [ -2.6138,   3.0502],
#         [ -5.6970,   6.3109],
#         [ -4.4892,   5.0779]], device='cuda:0')
# tensor([[ -2.8297,   3.2960],
#         [ -5.9404,   6.4672],
#         [ -6.3733,   6.8231],
#         [ -8.6136,   9.2274],
#         [ -8.0670,   8.7704],
#         [ -2.2730,   2.6299],
#         [  4.8943,  -4.7604],
#         [ -8.9428,   9.5414],
#         [  2.7518,  -2.6266],
#         [  5.8346,  -6.0579],
#         [ 14.4470, -14.4661],
#         [  4.7935,  -4.6952],
#         [  4.6074,  -4.4411],
#         [  2.9014,  -2.7477],
#         [  3.6598,  -3.4833],
#         [ -5.9114,   6.3565],
#         [  6.4972,  -6.6270],
#         [ 13.8246, -13.8434],
#         [  8.2972,  -8.3457],
#         [  5.4640,  -5.5362],
#         [  7.5665,  -7.8001],
#         [  3.9592,  -4.0231],
#         [  6.5857,  -6.5128],
#         [  3.9996,  -4.1640],
#         [ 10.4855, -10.6469],
#         [  5.3020,  -5.3062],
#         [  4.0578,  -3.8219],
#         [  2.2903,  -2.1828],
#         [  3.3022,  -3.1725],
#         [ -4.1001,   4.6193],
#         [  2.9209,  -2.7130],
#         [ -2.5408,   2.9599]], device='cuda:0')
# tensor([[  2.3196,  -2.0604],
#         [ -1.0110,   1.3247],
#         [  3.0320,  -2.8627],
#         [ -0.8362,   1.2982],
#         [ -4.5441,   4.9055],
#         [ -6.4522,   7.0083],
#         [  3.6648,  -3.4697],
#         [  1.3814,  -1.2080],
#         [ -5.4910,   5.8464],
#         [-14.5322,  15.4216],
#         [ -3.3852,   3.7921],
#         [ -1.6796,   1.9411],
#         [ -3.3860,   3.6385],
#         [  0.1368,   0.0342]], device='cuda:0')
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1280_1728.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1280_1760.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1280_1792.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1280_1824.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1280_1856.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1280_1888.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1280_1920.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1280_1952.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_0.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_32.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_64.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_96.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_128.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_160.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_192.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_224.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_256.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_288.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_320.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_352.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_384.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_416.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_448.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_480.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_512.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_544.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_576.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_1312_608.tif, Predicted: Not Slum
# ...
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_224.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_256.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_288.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_320.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_352.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_384.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_416.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_448.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_480.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_512.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_544.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_576.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_608.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_640.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_672.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_704.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_736.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_768.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_800.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_832.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_864.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_896.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_928.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_960.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_992.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1024.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1056.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1088.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1120.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1152.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1184.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1216.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1248.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1280.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1312.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1344.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1376.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1408.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1440.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1472.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1504.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1536.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1568.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1600.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1632.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1664.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1696.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1728.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1760.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1792.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1824.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1856.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1888.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1920.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_192_1952.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_0.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_32.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_64.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_96.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_128.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_160.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_192.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_224.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_256.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_288.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_320.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_352.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_384.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_416.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_448.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_480.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_512.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_544.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_576.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_608.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_640.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_672.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_704.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_736.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_768.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_800.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_832.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_864.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_896.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_928.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_960.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_992.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1024.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1056.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1088.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1120.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1152.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1184.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1216.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1248.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1280.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1312.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1344.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1376.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1408.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1440.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1472.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1504.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1536.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1568.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1600.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1632.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1664.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1696.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1728.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1760.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1792.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1824.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1856.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1888.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1920.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_224_1952.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_0.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_32.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_64.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_96.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_128.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_160.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_192.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_224.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_256.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_288.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_320.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_352.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_384.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_416.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_448.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_480.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_512.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_544.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_576.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_608.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_640.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_672.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_704.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_736.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_768.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_800.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_832.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_864.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_896.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_928.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_960.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_992.tif, Predicted: Not Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_1024.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_1056.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_1088.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_1120.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_1152.tif, Predicted: Slum
# Image: /content/drive/MyDrive/Academico/Computer Vision/Sentinel2/tile_256_1184.tif, Predicted: Not Slum

# %%
import numpy as np
import rasterio
import matplotlib.pyplot as plt
import os

# Ruta a la imagen original
original_image_path = base_dir + '/Data/Sentinel2_Buenos_Aires.tif'
tile_size = 32

def scale_and_normalize_image(image):
    image = np.array(image).astype(np.float32)
    image = (image / image.max()) * 255
    return image


def load_tile(tile_path):

    with rasterio.open(tile_path) as tile_path:
      image = tile_path.read([1,2,3])  # Read RGB bands
      image = np.transpose(image, (1, 2, 0))
      image = scale_and_normalize_image(image)

    image = np.array(image).astype(np.uint8)  # Asegurarse de que esté en formato uint8
    return image


# Abrir la imagen original para obtener las dimensiones
with rasterio.open(original_image_path) as src:
    width = src.width
    height = src.height

# Crear una imagen vacía para los resultados
result_image = np.zeros((height, width, 3), dtype=np.uint8)

# Iterar sobre los tiles y reconstruir la imagen
for path, pred in zip(image_paths, predictions):
    tile = load_tile(path)
    filename = os.path.basename(path)
    #i, j = map(int, filename.replace('tile_', '').replace('_enhanced.png', '').split('_'))
    i, j = map(int, filename.replace('tile_', '').replace('.tif', '').split('_'))

    if pred == 1:
        # Si se predice como slum, pintar el tile de rojo
        result_image[j:j+tile_size, i:i+tile_size] = [255, 0, 0]
    else:
        # Si no es un slum, usar los colores originales del tile

        result_image[j:j+tile_size, i:i+tile_size] = tile

# Mostrar la imagen resultante
plt.figure(figsize=(10, 10))
plt.imshow(result_image)
plt.title('Prediction of Slums in Buenos Aires')
plt.axis('off')
plt.show()
