# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 59.8 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7

# %%
import rasterio
import torch
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms, datasets
import matplotlib.pyplot as plt
import os
import shutil
import random
from google.colab import drive
import sys
import time
import json
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from PIL import Image

# %%
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#path = '/content/drive/MyDrive/Academico/Computer Vision'
#sys.path.append(path)
base_dir = os.getcwd()

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
def determine_max_pixel_value(data):
    max_value = 0
    for item in data:
        with rasterio.open(item['image_path']) as src:
            max_value = max(max_value, src.read([1,2,3]).max())
    return max_value

# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader
import rasterio
import numpy as np
from torchvision import transforms

# Function to load data from JSON file
def load_data(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)
    return data

def scale_and_normalize_image(image, max_value):
    image = np.array(image).astype(np.float32)
    image = (image / image.max()) * 255
    return image/max_value

class TiffDataset(Dataset):
    def __init__(self, data, transform=None, max_value = 255.0):
        self.data = data
        self.transform = transform
        self.max_value = max_value

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):

        item = self.data[idx]
        with rasterio.open(item['image_path']) as src:
            image = src.read([1,2,3])  # Read RGB bands
            image = np.transpose(image, (1, 2, 0))  # Channels last
            image = scale_and_normalize_image(image, self.max_value)

        if self.transform:
          image = self.transform(image)


        label = item['label']
        return image, label


# Load data from JSON files
train_json_file =  base_dir + '/Data/Train_80.json'
test_json_file = base_dir +  '/Data/Test_20.json'
train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

#max_pixel_value = determine_max_pixel_value(train_data)
max_pixel_value = 255.0
# Define transformations


transform_tr = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(degrees=180),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.Resize((224,224)),






])


transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((224,224))




])

# Determine the max pixel value from the training dataset for normalization

# Create datasets
train_dataset = TiffDataset(train_data, transform=transform_tr, max_value=max_pixel_value)
test_dataset = TiffDataset(test_data, transform=transform_val, max_value=max_pixel_value)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
import torch.nn as nn
import torch.optim as optim
import time

model = models.mobilenet_v2(weights='DEFAULT')
num_ftrs = model.classifier[1].in_features
model.classifier[1] = torch.nn.Linear(num_ftrs, 2)

# Move the model to GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Multi-class classification
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Define a learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1) #Drop to 0.0001 after 50 epochs

# Training function
def train_model(model, criterion, optimizer, train_loader, val_loader, scheduler, num_epochs=100):
    best_acc = 0.0
    best_model_wts = None
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        corrects = 0
        start_time = time.time()

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            corrects += torch.sum(preds == labels.data)

        scheduler.step()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = corrects.double() / len(train_loader.dataset)
        elapsed_time = time.time() - start_time
        print(f"Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}, Time: {elapsed_time:.2f}s")

        # Validate the model
        model.eval()
        val_loss = 0.0
        corrects = 0
        all_labels = []
        all_preds = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                corrects += torch.sum(preds == labels.data)
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(preds.cpu().numpy())


        val_loss /= len(val_loader.dataset)
        val_acc = corrects.double() / len(val_loader.dataset)
        print(f"Validation Loss: {val_loss:.4f}, Accuracy: {val_acc:.4f}")
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = model.state_dict()
            best_all_labels = all_labels
            best_all_preds = all_preds

    model.load_state_dict(best_model_wts)


    torch.save(model.state_dict(), base_dir + '/Redes_entrenadas/MobileNet_not_enhanced.pth')
    print('Model saved with accuracy: {:.4f}'.format(best_acc))

    cm = confusion_matrix(best_all_labels, best_all_preds)
    cr = classification_report(best_all_labels, best_all_preds)
    accuracy = (np.array(best_all_preds) == np.array(best_all_labels)).mean()
    print("Matriz de Confusión:")
    print(cm)
    print("Reporte de Clasificación:")
    print(cr)
    print(f"Accuracy: {accuracy:.4f}")

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Clase 0', 'Clase 1'], yticklabels=['Clase 0', 'Clase 1'])
    plt.xlabel('Predicción')
    plt.ylabel('Verdadero')
    plt.title('Matriz de Confusión')
    plt.show()

# Train the model
train_model(model, criterion, optimizer, train_loader, test_loader, scheduler, num_epochs=100)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-7ebf99e0.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-7ebf99e0.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 110MB/s]
# Epoch 0/99, Loss: 0.4652, Accuracy: 0.7661, Time: 76.78s
# Validation Loss: 0.4945, Accuracy: 0.8193
# Epoch 1/99, Loss: 0.4191, Accuracy: 0.8195, Time: 32.80s
# Validation Loss: 0.4710, Accuracy: 0.8366
# Epoch 2/99, Loss: 0.3788, Accuracy: 0.8294, Time: 44.43s
# Validation Loss: 0.3925, Accuracy: 0.8441
# Epoch 3/99, Loss: 0.3582, Accuracy: 0.8449, Time: 32.29s
# Validation Loss: 0.3699, Accuracy: 0.8342
# Epoch 4/99, Loss: 0.3296, Accuracy: 0.8617, Time: 31.99s
# Validation Loss: 0.3532, Accuracy: 0.8515
# Epoch 5/99, Loss: 0.3290, Accuracy: 0.8598, Time: 41.28s
# Validation Loss: 0.4304, Accuracy: 0.8416
# Epoch 6/99, Loss: 0.3333, Accuracy: 0.8610, Time: 33.65s
# Validation Loss: 0.5203, Accuracy: 0.8515
# Epoch 7/99, Loss: 0.3179, Accuracy: 0.8691, Time: 33.10s
# Validation Loss: 0.2772, Accuracy: 0.8812
# Epoch 8/99, Loss: 0.3008, Accuracy: 0.8685, Time: 40.82s
# Validation Loss: 0.2795, Accuracy: 0.8886
# Epoch 9/99, Loss: 0.2785, Accuracy: 0.8883, Time: 30.26s
# Validation Loss: 0.3430, Accuracy: 0.8688
# Epoch 10/99, Loss: 0.3042, Accuracy: 0.8741, Time: 31.89s
# Validation Loss: 0.4356, Accuracy: 0.7921
# Epoch 11/99, Loss: 0.2900, Accuracy: 0.8803, Time: 30.36s
# Validation Loss: 0.2831, Accuracy: 0.8837
# Epoch 12/99, Loss: 0.2858, Accuracy: 0.8797, Time: 39.58s
# Validation Loss: 0.4326, Accuracy: 0.8639
# Epoch 13/99, Loss: 0.2686, Accuracy: 0.8840, Time: 31.41s
# Validation Loss: 0.2881, Accuracy: 0.8960
# Epoch 14/99, Loss: 0.2656, Accuracy: 0.8902, Time: 31.42s
# Validation Loss: 0.2883, Accuracy: 0.8762
# Epoch 15/99, Loss: 0.2599, Accuracy: 0.8883, Time: 43.27s
# Validation Loss: 0.3299, Accuracy: 0.8787
# Epoch 16/99, Loss: 0.2883, Accuracy: 0.8734, Time: 31.09s
# Validation Loss: 0.2683, Accuracy: 0.8960
# Epoch 17/99, Loss: 0.2558, Accuracy: 0.8945, Time: 31.30s
# Validation Loss: 0.3019, Accuracy: 0.8886
# Epoch 18/99, Loss: 0.2543, Accuracy: 0.8902, Time: 39.60s
# Validation Loss: 0.3102, Accuracy: 0.8589
# Epoch 19/99, Loss: 0.2637, Accuracy: 0.8877, Time: 31.87s
# Validation Loss: 0.2870, Accuracy: 0.8787
# Epoch 20/99, Loss: 0.2512, Accuracy: 0.8952, Time: 32.16s
# Validation Loss: 0.2591, Accuracy: 0.9035
# Epoch 21/99, Loss: 0.2674, Accuracy: 0.8797, Time: 31.61s
# Validation Loss: 0.3025, Accuracy: 0.8911
# Epoch 22/99, Loss: 0.2599, Accuracy: 0.8828, Time: 42.54s
# Validation Loss: 0.2750, Accuracy: 0.8886
# Epoch 23/99, Loss: 0.2590, Accuracy: 0.8908, Time: 31.49s
# Validation Loss: 0.2677, Accuracy: 0.8861
# Epoch 24/99, Loss: 0.2467, Accuracy: 0.8964, Time: 33.25s
# Validation Loss: 0.2642, Accuracy: 0.8960
# Epoch 25/99, Loss: 0.2416, Accuracy: 0.8970, Time: 41.52s
# Validation Loss: 0.2406, Accuracy: 0.9010
# Epoch 26/99, Loss: 0.2320, Accuracy: 0.8995, Time: 31.29s
# Validation Loss: 0.3607, Accuracy: 0.8886
# Epoch 27/99, Loss: 0.2536, Accuracy: 0.8964, Time: 31.85s
# Validation Loss: 0.3859, Accuracy: 0.8267
# Epoch 28/99, Loss: 0.2375, Accuracy: 0.9045, Time: 41.56s
# Validation Loss: 0.2557, Accuracy: 0.8960
# Epoch 29/99, Loss: 0.2334, Accuracy: 0.8927, Time: 31.32s
# Validation Loss: 0.3926, Accuracy: 0.8738
# Epoch 30/99, Loss: 0.2320, Accuracy: 0.8914, Time: 32.47s
# Validation Loss: 0.2792, Accuracy: 0.8787
# Epoch 31/99, Loss: 0.2280, Accuracy: 0.8958, Time: 42.20s
# Validation Loss: 0.3206, Accuracy: 0.8762
# Epoch 32/99, Loss: 0.2246, Accuracy: 0.9063, Time: 31.83s
# Validation Loss: 0.3092, Accuracy: 0.8861
# Epoch 33/99, Loss: 0.2465, Accuracy: 0.9007, Time: 30.44s
# Validation Loss: 0.3045, Accuracy: 0.8416
# Epoch 34/99, Loss: 0.2078, Accuracy: 0.9094, Time: 32.95s
# Validation Loss: 0.3029, Accuracy: 0.8886
# Epoch 35/99, Loss: 0.2341, Accuracy: 0.9094, Time: 40.07s
# Validation Loss: 0.3061, Accuracy: 0.8861
# Epoch 36/99, Loss: 0.2229, Accuracy: 0.9094, Time: 31.05s
# Validation Loss: 0.3357, Accuracy: 0.8490
# Epoch 37/99, Loss: 0.2207, Accuracy: 0.9088, Time: 32.13s
# Validation Loss: 0.3179, Accuracy: 0.8738
# Epoch 38/99, Loss: 0.2367, Accuracy: 0.9020, Time: 39.15s
# Validation Loss: 0.2814, Accuracy: 0.8911
# Epoch 39/99, Loss: 0.2337, Accuracy: 0.9076, Time: 31.49s
# Validation Loss: 0.3093, Accuracy: 0.8589
# Epoch 40/99, Loss: 0.2292, Accuracy: 0.9038, Time: 31.55s
# Validation Loss: 0.2862, Accuracy: 0.8985
# Epoch 41/99, Loss: 0.2162, Accuracy: 0.9082, Time: 39.23s
# Validation Loss: 0.5929, Accuracy: 0.8366
# Epoch 42/99, Loss: 0.2115, Accuracy: 0.9169, Time: 31.46s
# Validation Loss: 0.3280, Accuracy: 0.8886
# Epoch 43/99, Loss: 0.1940, Accuracy: 0.9187, Time: 31.82s
# Validation Loss: 0.2977, Accuracy: 0.8911
# Epoch 44/99, Loss: 0.2195, Accuracy: 0.9181, Time: 40.96s
# Validation Loss: 0.3047, Accuracy: 0.8886
# Epoch 45/99, Loss: 0.2029, Accuracy: 0.9119, Time: 32.01s
# Validation Loss: 0.3040, Accuracy: 0.9010
# Epoch 46/99, Loss: 0.1736, Accuracy: 0.9342, Time: 33.35s
# Validation Loss: 0.3056, Accuracy: 0.8861
# Epoch 47/99, Loss: 0.1918, Accuracy: 0.9144, Time: 31.71s
# Validation Loss: 0.3060, Accuracy: 0.8911
# Epoch 48/99, Loss: 0.2127, Accuracy: 0.9181, Time: 41.64s
# Validation Loss: 0.4306, Accuracy: 0.8787
# Epoch 49/99, Loss: 0.2051, Accuracy: 0.9156, Time: 31.43s
# Validation Loss: 0.3486, Accuracy: 0.8936
# Epoch 50/99, Loss: 0.1636, Accuracy: 0.9380, Time: 31.26s
# Validation Loss: 0.3060, Accuracy: 0.8837
# Epoch 51/99, Loss: 0.1604, Accuracy: 0.9336, Time: 39.45s
# Validation Loss: 0.3124, Accuracy: 0.8861
# Epoch 52/99, Loss: 0.1505, Accuracy: 0.9404, Time: 31.46s
# Validation Loss: 0.3328, Accuracy: 0.8861
# Epoch 53/99, Loss: 0.1428, Accuracy: 0.9411, Time: 33.39s
# Validation Loss: 0.3337, Accuracy: 0.8886
# Epoch 54/99, Loss: 0.1384, Accuracy: 0.9442, Time: 38.74s
# Validation Loss: 0.3410, Accuracy: 0.8837
# Epoch 55/99, Loss: 0.1467, Accuracy: 0.9442, Time: 32.42s
# Validation Loss: 0.3314, Accuracy: 0.8837
# Epoch 56/99, Loss: 0.1386, Accuracy: 0.9435, Time: 30.33s
# Validation Loss: 0.3351, Accuracy: 0.8886
# Epoch 57/99, Loss: 0.1359, Accuracy: 0.9454, Time: 38.98s
# Validation Loss: 0.3712, Accuracy: 0.8960
# Epoch 58/99, Loss: 0.1211, Accuracy: 0.9516, Time: 33.04s
# Validation Loss: 0.3634, Accuracy: 0.8960
# Epoch 59/99, Loss: 0.1304, Accuracy: 0.9435, Time: 31.36s
# Validation Loss: 0.3147, Accuracy: 0.8837
# Epoch 60/99, Loss: 0.1129, Accuracy: 0.9491, Time: 30.85s
# Validation Loss: 0.3291, Accuracy: 0.8886
# Epoch 61/99, Loss: 0.1101, Accuracy: 0.9547, Time: 39.66s
# Validation Loss: 0.3535, Accuracy: 0.8787
# Epoch 62/99, Loss: 0.1106, Accuracy: 0.9597, Time: 32.80s
# Validation Loss: 0.3735, Accuracy: 0.8936
# Epoch 63/99, Loss: 0.1097, Accuracy: 0.9522, Time: 31.00s
# Validation Loss: 0.4392, Accuracy: 0.8886
# Epoch 64/99, Loss: 0.1056, Accuracy: 0.9615, Time: 38.67s
# Validation Loss: 0.3943, Accuracy: 0.8960
# Epoch 65/99, Loss: 0.1157, Accuracy: 0.9479, Time: 33.59s
# Validation Loss: 0.3781, Accuracy: 0.8787
# Epoch 66/99, Loss: 0.1112, Accuracy: 0.9553, Time: 31.97s
# Validation Loss: 0.3966, Accuracy: 0.8911
# Epoch 67/99, Loss: 0.1145, Accuracy: 0.9479, Time: 38.23s
# Validation Loss: 0.3570, Accuracy: 0.8886
# Epoch 68/99, Loss: 0.1064, Accuracy: 0.9572, Time: 31.02s
# Validation Loss: 0.3874, Accuracy: 0.8911
# Epoch 69/99, Loss: 0.1074, Accuracy: 0.9522, Time: 29.80s
# Validation Loss: 0.3638, Accuracy: 0.8936
# Epoch 70/99, Loss: 0.1101, Accuracy: 0.9535, Time: 30.08s
# Validation Loss: 0.3916, Accuracy: 0.8936
# Epoch 71/99, Loss: 0.1091, Accuracy: 0.9535, Time: 39.95s
# Validation Loss: 0.3783, Accuracy: 0.8861
# Epoch 72/99, Loss: 0.0922, Accuracy: 0.9628, Time: 31.52s
# Validation Loss: 0.3773, Accuracy: 0.8787
# Epoch 73/99, Loss: 0.0899, Accuracy: 0.9628, Time: 31.24s
# Validation Loss: 0.4096, Accuracy: 0.8837
# Epoch 74/99, Loss: 0.0928, Accuracy: 0.9566, Time: 39.95s
# Validation Loss: 0.4033, Accuracy: 0.8911
# Epoch 75/99, Loss: 0.0945, Accuracy: 0.9622, Time: 32.79s
# Validation Loss: 0.4102, Accuracy: 0.8812
# Epoch 76/99, Loss: 0.0732, Accuracy: 0.9715, Time: 31.64s
# Validation Loss: 0.4356, Accuracy: 0.8861
# Epoch 77/99, Loss: 0.0985, Accuracy: 0.9584, Time: 41.75s
# Validation Loss: 0.4136, Accuracy: 0.8812
# Epoch 78/99, Loss: 0.0881, Accuracy: 0.9609, Time: 30.81s
# Validation Loss: 0.4052, Accuracy: 0.8911
# Epoch 79/99, Loss: 0.1028, Accuracy: 0.9578, Time: 31.33s
# Validation Loss: 0.4142, Accuracy: 0.8837
# Epoch 80/99, Loss: 0.0817, Accuracy: 0.9684, Time: 31.93s
# Validation Loss: 0.4340, Accuracy: 0.8837
# Epoch 81/99, Loss: 0.0835, Accuracy: 0.9659, Time: 38.06s
# Validation Loss: 0.4534, Accuracy: 0.8812
# Epoch 82/99, Loss: 0.0808, Accuracy: 0.9684, Time: 32.48s
# Validation Loss: 0.4318, Accuracy: 0.8861
# Epoch 83/99, Loss: 0.0756, Accuracy: 0.9727, Time: 31.74s
# Validation Loss: 0.4350, Accuracy: 0.8886
# Epoch 84/99, Loss: 0.0892, Accuracy: 0.9622, Time: 38.85s
# Validation Loss: 0.4151, Accuracy: 0.8936
# Epoch 85/99, Loss: 0.0847, Accuracy: 0.9659, Time: 31.20s
# Validation Loss: 0.4684, Accuracy: 0.8886
# Epoch 86/99, Loss: 0.0902, Accuracy: 0.9622, Time: 32.11s
# Validation Loss: 0.4432, Accuracy: 0.8936
# Epoch 87/99, Loss: 0.0800, Accuracy: 0.9653, Time: 38.77s
# Validation Loss: 0.4157, Accuracy: 0.8837
# Epoch 88/99, Loss: 0.0789, Accuracy: 0.9733, Time: 30.87s
# Validation Loss: 0.4699, Accuracy: 0.8911
# Epoch 89/99, Loss: 0.0760, Accuracy: 0.9653, Time: 31.63s
# Validation Loss: 0.4855, Accuracy: 0.8886
# Epoch 90/99, Loss: 0.0688, Accuracy: 0.9702, Time: 30.83s
# Validation Loss: 0.4451, Accuracy: 0.8936
# Epoch 91/99, Loss: 0.0838, Accuracy: 0.9721, Time: 38.28s
# Validation Loss: 0.4482, Accuracy: 0.8960
# Epoch 92/99, Loss: 0.0634, Accuracy: 0.9814, Time: 31.10s
# Validation Loss: 0.5133, Accuracy: 0.8960
# Epoch 93/99, Loss: 0.0723, Accuracy: 0.9715, Time: 32.93s
# Validation Loss: 0.4942, Accuracy: 0.8936
# Epoch 94/99, Loss: 0.0735, Accuracy: 0.9702, Time: 40.02s
# Validation Loss: 0.4872, Accuracy: 0.8960
# Epoch 95/99, Loss: 0.0632, Accuracy: 0.9752, Time: 32.30s
# Validation Loss: 0.5594, Accuracy: 0.8911
# Epoch 96/99, Loss: 0.0780, Accuracy: 0.9690, Time: 31.74s
# Validation Loss: 0.5332, Accuracy: 0.8861
# Epoch 97/99, Loss: 0.0649, Accuracy: 0.9715, Time: 40.46s
# Validation Loss: 0.5148, Accuracy: 0.9010
# Epoch 98/99, Loss: 0.0730, Accuracy: 0.9702, Time: 31.61s
# Validation Loss: 0.5111, Accuracy: 0.8936
# Epoch 99/99, Loss: 0.0536, Accuracy: 0.9783, Time: 30.80s
# Validation Loss: 0.5394, Accuracy: 0.8936
# Model saved with accuracy: 0.9035
# Matriz de Confusión:
# [[169  26]
#  [ 13 196]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       195
#            1       0.88      0.94      0.91       209
#
#     accuracy                           0.90       404
#    macro avg       0.91      0.90      0.90       404
# weighted avg       0.90      0.90      0.90       404
#
# Accuracy: 0.9035
