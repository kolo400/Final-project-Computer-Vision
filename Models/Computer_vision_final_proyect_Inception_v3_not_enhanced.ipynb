# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 60.1 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7

# %%
import rasterio
import torch
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms, datasets
import matplotlib.pyplot as plt
import os
import shutil
import random
from google.colab import drive
import sys
import time
import json
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from PIL import Image

# %%
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#path = '/content/drive/MyDrive/Academico/Computer Vision'
#sys.path.append(path)

base_dir = os.getcwd()

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
def determine_max_pixel_value(data):
    max_value = 0
    for item in data:
        with rasterio.open(item['image_path']) as src:
            max_value = max(max_value, src.read([1,2,3]).max())
    return max_value

# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader
import rasterio
import numpy as np
from torchvision import transforms

# Function to load data from JSON file
def load_data(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)
    return data

def scale_and_normalize_image(image, max_value):
    image = np.array(image).astype(np.float32)
    image = (image / image.max()) * 255
    return image/max_value

class TiffDataset(Dataset):
    def __init__(self, data, transform=None, max_value = 255.0):
        self.data = data
        self.transform = transform
        self.max_value = max_value

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):

        item = self.data[idx]
        with rasterio.open(item['image_path']) as src:
            image = src.read([1,2,3])  # Read RGB bands
            image = np.transpose(image, (1, 2, 0))  # Channels last
            image = scale_and_normalize_image(image, self.max_value)

        if self.transform:
          image = self.transform(image)


        label = item['label']
        return image, label


# Load data from JSON files
train_json_file = base_dir + '/Data/Train_80.json'
test_json_file = base_dir +  '/Data/Test_20.json'
train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

#max_pixel_value = determine_max_pixel_value(train_data)
max_pixel_value = 255.0
# Define transformations


transform_tr = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(degrees=180),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.Resize((299,299)),






])


transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((299,299))




])

# Determine the max pixel value from the training dataset for normalization

# Create datasets
train_dataset = TiffDataset(train_data, transform=transform_tr, max_value=max_pixel_value)
test_dataset = TiffDataset(test_data, transform=transform_val, max_value=max_pixel_value)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
import torch.nn as nn
import torch.optim as optim
import time

model =  models.inception_v3(weights='DEFAULT')
num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 2)

# Move the model to GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Multi-class classification
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Define a learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1) #Drop to 0.0001 after 50 epochs

# Training function
def train_model(model, criterion, optimizer, train_loader, val_loader, scheduler, num_epochs=100):
    best_acc = 0.0
    best_model_wts = None
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        corrects = 0
        start_time = time.time()

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            outputs = outputs.logits if isinstance(outputs, models.inception.InceptionOutputs) else outputs
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            corrects += torch.sum(preds == labels.data)

        scheduler.step()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = corrects.double() / len(train_loader.dataset)
        elapsed_time = time.time() - start_time
        print(f"Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}, Time: {elapsed_time:.2f}s")

        # Validate the model
        model.eval()
        val_loss = 0.0
        corrects = 0
        all_labels = []
        all_preds = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                corrects += torch.sum(preds == labels.data)
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(preds.cpu().numpy())


        val_loss /= len(val_loader.dataset)
        val_acc = corrects.double() / len(val_loader.dataset)
        print(f"Validation Loss: {val_loss:.4f}, Accuracy: {val_acc:.4f}")
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = model.state_dict()
            best_all_labels = all_labels
            best_all_preds = all_preds

    model.load_state_dict(best_model_wts)


    torch.save(model.state_dict(), base_dir + '/Redes_entrenadas/InceptionV3_not_enhanced.pth')
    print('Model saved with accuracy: {:.4f}'.format(best_acc))

    cm = confusion_matrix(best_all_labels, best_all_preds)
    cr = classification_report(best_all_labels, best_all_preds)
    accuracy = (np.array(best_all_preds) == np.array(best_all_labels)).mean()
    print("Matriz de Confusión:")
    print(cm)
    print("Reporte de Clasificación:")
    print(cr)
    print(f"Accuracy: {accuracy:.4f}")

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Clase 0', 'Clase 1'], yticklabels=['Clase 0', 'Clase 1'])
    plt.xlabel('Predicción')
    plt.ylabel('Verdadero')
    plt.title('Matriz de Confusión')
    plt.show()

# Train the model
train_model(model, criterion, optimizer, train_loader, test_loader, scheduler, num_epochs=100)
# Out:
# Epoch 0/99, Loss: 0.5152, Accuracy: 0.7444, Time: 33.33s
# Validation Loss: 0.5704, Accuracy: 0.7673
# Epoch 1/99, Loss: 0.4075, Accuracy: 0.8182, Time: 45.31s
# Validation Loss: 0.5705, Accuracy: 0.7871
# Epoch 2/99, Loss: 0.4217, Accuracy: 0.8251, Time: 35.44s
# Validation Loss: 0.5064, Accuracy: 0.8391
# Epoch 3/99, Loss: 0.3816, Accuracy: 0.8207, Time: 34.64s
# Validation Loss: 0.3783, Accuracy: 0.8639
# Epoch 4/99, Loss: 0.3661, Accuracy: 0.8449, Time: 41.96s
# Validation Loss: 0.3848, Accuracy: 0.8540
# Epoch 5/99, Loss: 0.3475, Accuracy: 0.8536, Time: 35.85s
# Validation Loss: 0.3616, Accuracy: 0.8490
# Epoch 6/99, Loss: 0.3334, Accuracy: 0.8654, Time: 35.32s
# Validation Loss: 0.4485, Accuracy: 0.7550
# Epoch 7/99, Loss: 0.3181, Accuracy: 0.8629, Time: 45.51s
# Validation Loss: 0.3295, Accuracy: 0.8639
# Epoch 8/99, Loss: 0.3214, Accuracy: 0.8710, Time: 33.85s
# Validation Loss: 0.3525, Accuracy: 0.8688
# Epoch 9/99, Loss: 0.3112, Accuracy: 0.8716, Time: 34.37s
# Validation Loss: 0.3937, Accuracy: 0.8391
# Epoch 10/99, Loss: 0.3274, Accuracy: 0.8579, Time: 42.91s
# Validation Loss: 0.4112, Accuracy: 0.8119
# Epoch 11/99, Loss: 0.3246, Accuracy: 0.8598, Time: 32.51s
# Validation Loss: 0.3309, Accuracy: 0.8564
# Epoch 12/99, Loss: 0.3096, Accuracy: 0.8728, Time: 33.11s
# Validation Loss: 0.3027, Accuracy: 0.8787
# Epoch 13/99, Loss: 0.3059, Accuracy: 0.8697, Time: 42.06s
# Validation Loss: 0.4570, Accuracy: 0.8441
# Epoch 14/99, Loss: 0.3095, Accuracy: 0.8734, Time: 35.07s
# Validation Loss: 0.2834, Accuracy: 0.8688
# Epoch 15/99, Loss: 0.2890, Accuracy: 0.8728, Time: 34.56s
# Validation Loss: 0.3355, Accuracy: 0.8886
# Epoch 16/99, Loss: 0.2918, Accuracy: 0.8716, Time: 42.77s
# Validation Loss: 0.2937, Accuracy: 0.8639
# Epoch 17/99, Loss: 0.2875, Accuracy: 0.8846, Time: 35.77s
# Validation Loss: 0.3800, Accuracy: 0.8861
# Epoch 18/99, Loss: 0.3021, Accuracy: 0.8753, Time: 32.90s
# Validation Loss: 0.2818, Accuracy: 0.8688
# Epoch 19/99, Loss: 0.2931, Accuracy: 0.8766, Time: 44.22s
# Validation Loss: 0.3583, Accuracy: 0.8639
# Epoch 20/99, Loss: 0.2964, Accuracy: 0.8846, Time: 36.08s
# Validation Loss: 0.3303, Accuracy: 0.8639
# Epoch 21/99, Loss: 0.2829, Accuracy: 0.8859, Time: 34.79s
# Validation Loss: 0.4594, Accuracy: 0.8540
# Epoch 22/99, Loss: 0.2819, Accuracy: 0.8908, Time: 42.48s
# Validation Loss: 0.3390, Accuracy: 0.8837
# Epoch 23/99, Loss: 0.2673, Accuracy: 0.8883, Time: 34.61s
# Validation Loss: 0.2921, Accuracy: 0.9059
# Epoch 24/99, Loss: 0.2827, Accuracy: 0.8722, Time: 33.98s
# Validation Loss: 0.6275, Accuracy: 0.7030
# Epoch 25/99, Loss: 0.2849, Accuracy: 0.8790, Time: 42.97s
# Validation Loss: 0.2961, Accuracy: 0.8886
# Epoch 26/99, Loss: 0.2743, Accuracy: 0.8927, Time: 36.65s
# Validation Loss: 0.2875, Accuracy: 0.8886
# Epoch 27/99, Loss: 0.2800, Accuracy: 0.8908, Time: 33.69s
# Validation Loss: 0.4919, Accuracy: 0.8366
# Epoch 28/99, Loss: 0.2645, Accuracy: 0.8896, Time: 40.85s
# Validation Loss: 0.8671, Accuracy: 0.8391
# Epoch 29/99, Loss: 0.2712, Accuracy: 0.8865, Time: 32.96s
# Validation Loss: 0.3089, Accuracy: 0.8713
# Epoch 30/99, Loss: 0.2720, Accuracy: 0.8908, Time: 34.12s
# Validation Loss: 0.2938, Accuracy: 0.8861
# Epoch 31/99, Loss: 0.2741, Accuracy: 0.8877, Time: 40.76s
# Validation Loss: 0.3460, Accuracy: 0.8614
# Epoch 32/99, Loss: 0.2694, Accuracy: 0.8846, Time: 33.85s
# Validation Loss: 0.3149, Accuracy: 0.8589
# Epoch 33/99, Loss: 0.2659, Accuracy: 0.8902, Time: 32.62s
# Validation Loss: 0.3532, Accuracy: 0.8515
# Epoch 34/99, Loss: 0.2655, Accuracy: 0.8983, Time: 41.23s
# Validation Loss: 0.2790, Accuracy: 0.8837
# Epoch 35/99, Loss: 0.2638, Accuracy: 0.8852, Time: 32.12s
# Validation Loss: 0.3179, Accuracy: 0.8812
# Epoch 36/99, Loss: 0.2723, Accuracy: 0.8828, Time: 33.62s
# Validation Loss: 0.2807, Accuracy: 0.8837
# Epoch 37/99, Loss: 0.2651, Accuracy: 0.8883, Time: 41.04s
# Validation Loss: 0.3341, Accuracy: 0.8738
# Epoch 38/99, Loss: 0.2724, Accuracy: 0.8865, Time: 34.38s
# Validation Loss: 0.3497, Accuracy: 0.8540
# Epoch 39/99, Loss: 0.2752, Accuracy: 0.8797, Time: 33.26s
# Validation Loss: 0.3502, Accuracy: 0.8366
# Epoch 40/99, Loss: 0.2875, Accuracy: 0.8778, Time: 41.49s
# Validation Loss: 0.3130, Accuracy: 0.8812
# Epoch 41/99, Loss: 0.2794, Accuracy: 0.8883, Time: 35.25s
# Validation Loss: 0.2559, Accuracy: 0.8911
# Epoch 42/99, Loss: 0.2565, Accuracy: 0.8945, Time: 32.87s
# Validation Loss: 0.3048, Accuracy: 0.8787
# Epoch 43/99, Loss: 0.2607, Accuracy: 0.8914, Time: 40.92s
# Validation Loss: 0.3434, Accuracy: 0.8589
# Epoch 44/99, Loss: 0.2532, Accuracy: 0.8921, Time: 38.33s
# Validation Loss: 0.3072, Accuracy: 0.8688
# Epoch 45/99, Loss: 0.2738, Accuracy: 0.8871, Time: 33.57s
# Validation Loss: 0.2969, Accuracy: 0.8787
# Epoch 46/99, Loss: 0.2703, Accuracy: 0.8883, Time: 40.75s
# Validation Loss: 0.7615, Accuracy: 0.7228
# Epoch 47/99, Loss: 0.2520, Accuracy: 0.8989, Time: 33.05s
# Validation Loss: 0.2943, Accuracy: 0.8861
# Epoch 48/99, Loss: 0.2593, Accuracy: 0.8952, Time: 32.04s
# Validation Loss: 0.2885, Accuracy: 0.8886
# Epoch 49/99, Loss: 0.2548, Accuracy: 0.8945, Time: 35.40s
# Validation Loss: 0.3059, Accuracy: 0.8886
# Epoch 50/99, Loss: 0.2251, Accuracy: 0.8970, Time: 44.18s
# Validation Loss: 0.2766, Accuracy: 0.8911
# Epoch 51/99, Loss: 0.2195, Accuracy: 0.9107, Time: 34.30s
# Validation Loss: 0.2707, Accuracy: 0.8861
# Epoch 52/99, Loss: 0.2043, Accuracy: 0.9163, Time: 32.46s
# Validation Loss: 0.2665, Accuracy: 0.8812
# Epoch 53/99, Loss: 0.1991, Accuracy: 0.9187, Time: 39.60s
# Validation Loss: 0.2707, Accuracy: 0.8812
# Epoch 54/99, Loss: 0.2078, Accuracy: 0.9218, Time: 33.14s
# Validation Loss: 0.2679, Accuracy: 0.8936
# Epoch 55/99, Loss: 0.1995, Accuracy: 0.9163, Time: 33.76s
# Validation Loss: 0.2742, Accuracy: 0.8886
# Epoch 56/99, Loss: 0.1944, Accuracy: 0.9200, Time: 44.81s
# Validation Loss: 0.2731, Accuracy: 0.8861
# Epoch 57/99, Loss: 0.2028, Accuracy: 0.9181, Time: 34.63s
# Validation Loss: 0.2771, Accuracy: 0.8861
# Epoch 58/99, Loss: 0.1786, Accuracy: 0.9361, Time: 33.29s
# Validation Loss: 0.2728, Accuracy: 0.8837
# Epoch 59/99, Loss: 0.1917, Accuracy: 0.9256, Time: 41.22s
# Validation Loss: 0.2748, Accuracy: 0.8861
# Epoch 60/99, Loss: 0.1873, Accuracy: 0.9287, Time: 32.98s
# Validation Loss: 0.2729, Accuracy: 0.8812
# Epoch 61/99, Loss: 0.1807, Accuracy: 0.9225, Time: 33.97s
# Validation Loss: 0.2805, Accuracy: 0.8886
# Epoch 62/99, Loss: 0.1800, Accuracy: 0.9187, Time: 42.96s
# Validation Loss: 0.2847, Accuracy: 0.8886
# Epoch 63/99, Loss: 0.1788, Accuracy: 0.9262, Time: 34.60s
# Validation Loss: 0.3010, Accuracy: 0.8812
# Epoch 64/99, Loss: 0.1742, Accuracy: 0.9293, Time: 33.67s
# Validation Loss: 0.2963, Accuracy: 0.8985
# Epoch 65/99, Loss: 0.1866, Accuracy: 0.9256, Time: 43.21s
# Validation Loss: 0.3106, Accuracy: 0.8837
# Epoch 66/99, Loss: 0.1754, Accuracy: 0.9274, Time: 33.34s
# Validation Loss: 0.3041, Accuracy: 0.8738
# Epoch 67/99, Loss: 0.1636, Accuracy: 0.9349, Time: 33.85s
# Validation Loss: 0.2951, Accuracy: 0.8713
# Epoch 68/99, Loss: 0.1839, Accuracy: 0.9243, Time: 41.21s
# Validation Loss: 0.2959, Accuracy: 0.8787
# Epoch 69/99, Loss: 0.1779, Accuracy: 0.9231, Time: 32.37s
# Validation Loss: 0.3046, Accuracy: 0.8861
# Epoch 70/99, Loss: 0.1580, Accuracy: 0.9349, Time: 33.21s
# Validation Loss: 0.3133, Accuracy: 0.8911
# Epoch 71/99, Loss: 0.1744, Accuracy: 0.9268, Time: 42.21s
# Validation Loss: 0.3005, Accuracy: 0.8837
# Epoch 72/99, Loss: 0.1753, Accuracy: 0.9237, Time: 33.62s
# Validation Loss: 0.2868, Accuracy: 0.8837
# Epoch 73/99, Loss: 0.1556, Accuracy: 0.9411, Time: 33.38s
# Validation Loss: 0.3041, Accuracy: 0.8861
# Epoch 74/99, Loss: 0.1598, Accuracy: 0.9349, Time: 43.18s
# Validation Loss: 0.3062, Accuracy: 0.8861
# Epoch 75/99, Loss: 0.1635, Accuracy: 0.9386, Time: 31.96s
# Validation Loss: 0.3159, Accuracy: 0.8936
# Epoch 76/99, Loss: 0.1541, Accuracy: 0.9392, Time: 32.81s
# Validation Loss: 0.3038, Accuracy: 0.8911
# Epoch 77/99, Loss: 0.1452, Accuracy: 0.9349, Time: 40.46s
# Validation Loss: 0.3837, Accuracy: 0.8861
# Epoch 78/99, Loss: 0.1701, Accuracy: 0.9293, Time: 35.32s
# Validation Loss: 0.3815, Accuracy: 0.8911
# Epoch 79/99, Loss: 0.1584, Accuracy: 0.9417, Time: 35.79s
# Validation Loss: 0.3234, Accuracy: 0.8812
# Epoch 80/99, Loss: 0.1507, Accuracy: 0.9361, Time: 41.13s
# Validation Loss: 0.3535, Accuracy: 0.8837
# Epoch 81/99, Loss: 0.1529, Accuracy: 0.9367, Time: 32.65s
# Validation Loss: 0.3323, Accuracy: 0.8812
# Epoch 82/99, Loss: 0.1644, Accuracy: 0.9342, Time: 34.99s
# Validation Loss: 0.3409, Accuracy: 0.8762
# Epoch 83/99, Loss: 0.1415, Accuracy: 0.9448, Time: 31.68s
# Validation Loss: 0.3730, Accuracy: 0.8886
# Epoch 84/99, Loss: 0.1518, Accuracy: 0.9435, Time: 40.12s
# Validation Loss: 0.3228, Accuracy: 0.8960
# Epoch 85/99, Loss: 0.1493, Accuracy: 0.9386, Time: 33.22s
# Validation Loss: 0.3656, Accuracy: 0.9010
# Epoch 86/99, Loss: 0.1499, Accuracy: 0.9373, Time: 32.98s
# Validation Loss: 0.3439, Accuracy: 0.8960
# Epoch 87/99, Loss: 0.1423, Accuracy: 0.9442, Time: 41.98s
# Validation Loss: 0.3497, Accuracy: 0.8936
# Epoch 88/99, Loss: 0.1385, Accuracy: 0.9460, Time: 34.95s
# Validation Loss: 0.3503, Accuracy: 0.8812
# Epoch 89/99, Loss: 0.1421, Accuracy: 0.9423, Time: 33.52s
# Validation Loss: 0.3826, Accuracy: 0.8911
# Epoch 90/99, Loss: 0.1371, Accuracy: 0.9429, Time: 39.64s
# Validation Loss: 0.3464, Accuracy: 0.8837
# Epoch 91/99, Loss: 0.1328, Accuracy: 0.9498, Time: 32.85s
# Validation Loss: 0.4139, Accuracy: 0.8886
# Epoch 92/99, Loss: 0.1477, Accuracy: 0.9380, Time: 33.20s
# Validation Loss: 0.3740, Accuracy: 0.8911
# Epoch 93/99, Loss: 0.1373, Accuracy: 0.9460, Time: 42.96s
# Validation Loss: 0.3869, Accuracy: 0.8960
# Epoch 94/99, Loss: 0.1260, Accuracy: 0.9510, Time: 35.57s
# Validation Loss: 0.4005, Accuracy: 0.8985
# Epoch 95/99, Loss: 0.1226, Accuracy: 0.9516, Time: 34.67s
# Validation Loss: 0.3796, Accuracy: 0.8861
# Epoch 96/99, Loss: 0.1340, Accuracy: 0.9417, Time: 41.16s
# Validation Loss: 0.3740, Accuracy: 0.8886
# Epoch 97/99, Loss: 0.1394, Accuracy: 0.9454, Time: 33.08s
# Validation Loss: 0.4485, Accuracy: 0.8812
# Epoch 98/99, Loss: 0.1289, Accuracy: 0.9522, Time: 33.12s
# Validation Loss: 0.3782, Accuracy: 0.8911
# Epoch 99/99, Loss: 0.1371, Accuracy: 0.9404, Time: 40.85s
# Validation Loss: 0.3526, Accuracy: 0.8762
# Model saved with accuracy: 0.9059
# Matriz de Confusión:
# [[166  29]
#  [  9 200]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90       195
#            1       0.87      0.96      0.91       209
#
#     accuracy                           0.91       404
#    macro avg       0.91      0.90      0.91       404
# weighted avg       0.91      0.91      0.91       404
#
# Accuracy: 0.9059
