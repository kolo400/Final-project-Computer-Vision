# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 64.5 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7

# %%
import rasterio
import torch
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms, datasets
import matplotlib.pyplot as plt
import os
import shutil
import random
from google.colab import drive
import sys
import time
import json
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from PIL import Image

# %%
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#path = '/content/drive/MyDrive/Academico/Computer Vision'
#sys.path.append(path)

base_dir = os.getcwd()

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
def determine_max_pixel_value(data):
    max_value = 0
    for item in data:
        with rasterio.open(item['image_path']) as src:
            max_value = max(max_value, src.read([1,2,3]).max())
    return max_value

# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader
import rasterio
import numpy as np
from torchvision import transforms

# Function to load data from JSON file
def load_data(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)
    return data

def scale_and_normalize_image(image, max_value):
    image = np.array(image).astype(np.float32)
    image = (image / image.max()) * 255
    return image/max_value

class TiffDataset(Dataset):
    def __init__(self, data, transform=None, max_value = 255.0):
        self.data = data
        self.transform = transform
        self.max_value = max_value

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):

        item = self.data[idx]
        with rasterio.open(item['image_path']) as src:
            image = src.read([1,2,3])  # Read RGB bands
            image = np.transpose(image, (1, 2, 0))  # Channels last
            image = scale_and_normalize_image(image, self.max_value)

        if self.transform:
          image = self.transform(image)


        label = item['label']
        return image, label


# Load data from JSON files
train_json_file = base_dir + '/Data/Train_80.json'
test_json_file = base_dir +  '/Data/Test_20.json'
train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

#max_pixel_value = determine_max_pixel_value(train_data)
max_pixel_value = 255.0
# Define transformations


transform_tr = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(degrees=180),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.Resize((224,224)),






])


transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((224,224))




])

# Determine the max pixel value from the training dataset for normalization

# Create datasets
train_dataset = TiffDataset(train_data, transform=transform_tr, max_value=max_pixel_value)
test_dataset = TiffDataset(test_data, transform=transform_val, max_value=max_pixel_value)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
import torch.nn as nn
import torch.optim as optim
import time

model = models.resnet34(weights="DEFAULT")
num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 2)

# Move the model to GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Multi-class classification
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Define a learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1) #Drop to 0.0001 after 50 epochs

# Training function
def train_model(model, criterion, optimizer, train_loader, val_loader, scheduler, num_epochs=100):
    best_acc = 0.0
    best_model_wts = None
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        corrects = 0
        start_time = time.time()

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            corrects += torch.sum(preds == labels.data)

        scheduler.step()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = corrects.double() / len(train_loader.dataset)
        elapsed_time = time.time() - start_time
        print(f"Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}, Time: {elapsed_time:.2f}s")

        # Validate the model
        model.eval()
        val_loss = 0.0
        corrects = 0
        all_labels = []
        all_preds = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                corrects += torch.sum(preds == labels.data)
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(preds.cpu().numpy())


        val_loss /= len(val_loader.dataset)
        val_acc = corrects.double() / len(val_loader.dataset)
        print(f"Validation Loss: {val_loss:.4f}, Accuracy: {val_acc:.4f}")
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = model.state_dict()
            best_all_labels = all_labels
            best_all_preds = all_preds

    model.load_state_dict(best_model_wts)


    torch.save(model.state_dict(), base_dir + '/Redes_entrenadas/Resnet34_not_enhanced.pth')
    print('Model saved with accuracy: {:.4f}'.format(best_acc))

    cm = confusion_matrix(best_all_labels, best_all_preds)
    cr = classification_report(best_all_labels, best_all_preds)
    accuracy = (np.array(best_all_preds) == np.array(best_all_labels)).mean()
    print("Matriz de Confusión:")
    print(cm)
    print("Reporte de Clasificación:")
    print(cr)
    print(f"Accuracy: {accuracy:.4f}")

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Clase 0', 'Clase 1'], yticklabels=['Clase 0', 'Clase 1'])
    plt.xlabel('Predicción')
    plt.ylabel('Verdadero')
    plt.title('Matriz de Confusión')
    plt.show()

# Train the model
train_model(model, criterion, optimizer, train_loader, test_loader, scheduler, num_epochs=100)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:01<00:00, 86.6MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch 0/99, Loss: 0.5909, Accuracy: 0.7277, Time: 102.29s
# Validation Loss: 0.4662, Accuracy: 0.8020
# Epoch 1/99, Loss: 0.4387, Accuracy: 0.7891, Time: 60.49s
# Validation Loss: 0.4716, Accuracy: 0.8267
# Epoch 2/99, Loss: 0.4070, Accuracy: 0.8127, Time: 48.00s
# Validation Loss: 0.3859, Accuracy: 0.8342
# Epoch 3/99, Loss: 0.3538, Accuracy: 0.8474, Time: 57.24s
# Validation Loss: 0.4928, Accuracy: 0.8267
# Epoch 4/99, Loss: 0.3555, Accuracy: 0.8499, Time: 46.40s
# Validation Loss: 0.3536, Accuracy: 0.8342
# Epoch 5/99, Loss: 0.3418, Accuracy: 0.8548, Time: 55.16s
# Validation Loss: 0.6943, Accuracy: 0.7079
# Epoch 6/99, Loss: 0.3272, Accuracy: 0.8561, Time: 42.71s
# Validation Loss: 0.3082, Accuracy: 0.8812
# Epoch 7/99, Loss: 0.3389, Accuracy: 0.8592, Time: 44.83s
# Validation Loss: 0.4065, Accuracy: 0.8243
# Epoch 8/99, Loss: 0.3317, Accuracy: 0.8635, Time: 56.07s
# Validation Loss: 1.0243, Accuracy: 0.6683
# Epoch 9/99, Loss: 0.3339, Accuracy: 0.8468, Time: 47.14s
# Validation Loss: 0.3274, Accuracy: 0.8812
# Epoch 10/99, Loss: 0.2886, Accuracy: 0.8840, Time: 58.57s
# Validation Loss: 0.4404, Accuracy: 0.8020
# Epoch 11/99, Loss: 0.3001, Accuracy: 0.8716, Time: 47.48s
# Validation Loss: 0.3026, Accuracy: 0.8812
# Epoch 12/99, Loss: 0.2846, Accuracy: 0.8790, Time: 56.35s
# Validation Loss: 0.3811, Accuracy: 0.8366
# Epoch 13/99, Loss: 0.2956, Accuracy: 0.8728, Time: 48.40s
# Validation Loss: 0.2943, Accuracy: 0.8762
# Epoch 14/99, Loss: 0.3259, Accuracy: 0.8524, Time: 55.87s
# Validation Loss: 1.9250, Accuracy: 0.5347
# Epoch 15/99, Loss: 0.3079, Accuracy: 0.8741, Time: 44.71s
# Validation Loss: 0.9060, Accuracy: 0.7252
# Epoch 16/99, Loss: 0.3122, Accuracy: 0.8703, Time: 45.45s
# Validation Loss: 0.2918, Accuracy: 0.8812
# Epoch 17/99, Loss: 0.2872, Accuracy: 0.8784, Time: 57.78s
# Validation Loss: 0.3744, Accuracy: 0.8267
# Epoch 18/99, Loss: 0.3043, Accuracy: 0.8697, Time: 44.74s
# Validation Loss: 0.5197, Accuracy: 0.8416
# Epoch 19/99, Loss: 0.3242, Accuracy: 0.8666, Time: 62.02s
# Validation Loss: 0.3242, Accuracy: 0.8366
# Epoch 20/99, Loss: 0.2883, Accuracy: 0.8778, Time: 47.58s
# Validation Loss: 0.3509, Accuracy: 0.8490
# Epoch 21/99, Loss: 0.3201, Accuracy: 0.8672, Time: 56.46s
# Validation Loss: 0.4939, Accuracy: 0.8342
# Epoch 22/99, Loss: 0.2937, Accuracy: 0.8766, Time: 48.16s
# Validation Loss: 0.3510, Accuracy: 0.8614
# Epoch 23/99, Loss: 0.2688, Accuracy: 0.8828, Time: 56.93s
# Validation Loss: 0.3157, Accuracy: 0.8812
# Epoch 24/99, Loss: 0.2888, Accuracy: 0.8834, Time: 46.39s
# Validation Loss: 0.3048, Accuracy: 0.8861
# Epoch 25/99, Loss: 0.2724, Accuracy: 0.8797, Time: 63.69s
# Validation Loss: 0.5886, Accuracy: 0.8391
# Epoch 26/99, Loss: 0.2946, Accuracy: 0.8834, Time: 45.94s
# Validation Loss: 0.5712, Accuracy: 0.7723
# Epoch 27/99, Loss: 0.3019, Accuracy: 0.8654, Time: 56.17s
# Validation Loss: 0.3530, Accuracy: 0.8218
# Epoch 28/99, Loss: 0.2897, Accuracy: 0.8753, Time: 47.31s
# Validation Loss: 0.3226, Accuracy: 0.8787
# Epoch 29/99, Loss: 0.2771, Accuracy: 0.8747, Time: 47.04s
# Validation Loss: 0.2849, Accuracy: 0.8812
# Epoch 30/99, Loss: 0.2840, Accuracy: 0.8859, Time: 59.53s
# Validation Loss: 0.5003, Accuracy: 0.8045
# Epoch 31/99, Loss: 0.2908, Accuracy: 0.8766, Time: 46.97s
# Validation Loss: 0.3904, Accuracy: 0.8267
# Epoch 32/99, Loss: 0.2836, Accuracy: 0.8821, Time: 60.11s
# Validation Loss: 0.3844, Accuracy: 0.8688
# Epoch 33/99, Loss: 0.2625, Accuracy: 0.8902, Time: 45.65s
# Validation Loss: 0.2960, Accuracy: 0.8886
# Epoch 34/99, Loss: 0.2677, Accuracy: 0.8846, Time: 55.43s
# Validation Loss: 0.3978, Accuracy: 0.8465
# Epoch 35/99, Loss: 0.2904, Accuracy: 0.8840, Time: 45.76s
# Validation Loss: 0.3599, Accuracy: 0.8564
# Epoch 36/99, Loss: 0.3029, Accuracy: 0.8741, Time: 57.74s
# Validation Loss: 0.6601, Accuracy: 0.7475
# Epoch 37/99, Loss: 0.3218, Accuracy: 0.8703, Time: 46.61s
# Validation Loss: 0.4028, Accuracy: 0.8614
# Epoch 38/99, Loss: 0.3075, Accuracy: 0.8654, Time: 47.79s
# Validation Loss: 0.3105, Accuracy: 0.8589
# Epoch 39/99, Loss: 0.2820, Accuracy: 0.8809, Time: 45.25s
# Validation Loss: 0.5710, Accuracy: 0.7896
# Epoch 40/99, Loss: 0.2701, Accuracy: 0.8933, Time: 45.49s
# Validation Loss: 0.2742, Accuracy: 0.8738
# Epoch 41/99, Loss: 0.2669, Accuracy: 0.8859, Time: 60.24s
# Validation Loss: 0.3348, Accuracy: 0.8713
# Epoch 42/99, Loss: 0.2813, Accuracy: 0.8939, Time: 48.57s
# Validation Loss: 0.3966, Accuracy: 0.8317
# Epoch 43/99, Loss: 0.2816, Accuracy: 0.8834, Time: 55.45s
# Validation Loss: 0.3365, Accuracy: 0.8564
# Epoch 44/99, Loss: 0.2694, Accuracy: 0.8890, Time: 44.47s
# Validation Loss: 0.3540, Accuracy: 0.8589
# Epoch 45/99, Loss: 0.2572, Accuracy: 0.8890, Time: 55.75s
# Validation Loss: 0.4413, Accuracy: 0.8589
# Epoch 46/99, Loss: 0.2779, Accuracy: 0.8803, Time: 50.54s
# Validation Loss: 0.2994, Accuracy: 0.8688
# Epoch 47/99, Loss: 0.2705, Accuracy: 0.8809, Time: 56.55s
# Validation Loss: 0.3510, Accuracy: 0.8639
# Epoch 48/99, Loss: 0.2530, Accuracy: 0.8896, Time: 45.04s
# Validation Loss: 0.3192, Accuracy: 0.8762
# Epoch 49/99, Loss: 0.3015, Accuracy: 0.8759, Time: 47.17s
# Validation Loss: 0.4608, Accuracy: 0.8738
# Epoch 50/99, Loss: 0.2622, Accuracy: 0.8970, Time: 52.83s
# Validation Loss: 0.2848, Accuracy: 0.8861
# Epoch 51/99, Loss: 0.2410, Accuracy: 0.9088, Time: 45.56s
# Validation Loss: 0.2772, Accuracy: 0.8837
# Epoch 52/99, Loss: 0.2381, Accuracy: 0.8989, Time: 54.10s
# Validation Loss: 0.2769, Accuracy: 0.8936
# Epoch 53/99, Loss: 0.2197, Accuracy: 0.9051, Time: 48.32s
# Validation Loss: 0.2781, Accuracy: 0.8911
# Epoch 54/99, Loss: 0.2339, Accuracy: 0.9082, Time: 59.47s
# Validation Loss: 0.2791, Accuracy: 0.8886
# Epoch 55/99, Loss: 0.2232, Accuracy: 0.9132, Time: 47.47s
# Validation Loss: 0.2805, Accuracy: 0.8911
# Epoch 56/99, Loss: 0.2163, Accuracy: 0.9125, Time: 45.71s
# Validation Loss: 0.2734, Accuracy: 0.8985
# Epoch 57/99, Loss: 0.2156, Accuracy: 0.9100, Time: 52.56s
# Validation Loss: 0.2965, Accuracy: 0.8936
# Epoch 58/99, Loss: 0.2166, Accuracy: 0.9119, Time: 48.93s
# Validation Loss: 0.2798, Accuracy: 0.8936
# Epoch 59/99, Loss: 0.2143, Accuracy: 0.9156, Time: 56.43s
# Validation Loss: 0.2900, Accuracy: 0.8886
# Epoch 60/99, Loss: 0.2075, Accuracy: 0.9150, Time: 46.47s
# Validation Loss: 0.2716, Accuracy: 0.8886
# Epoch 61/99, Loss: 0.2259, Accuracy: 0.9100, Time: 55.54s
# Validation Loss: 0.2643, Accuracy: 0.8985
# Epoch 62/99, Loss: 0.2104, Accuracy: 0.9119, Time: 46.03s
# Validation Loss: 0.2615, Accuracy: 0.8985
# Epoch 63/99, Loss: 0.2080, Accuracy: 0.9125, Time: 53.80s
# Validation Loss: 0.2908, Accuracy: 0.8886
# Epoch 64/99, Loss: 0.2007, Accuracy: 0.9194, Time: 46.63s
# Validation Loss: 0.2865, Accuracy: 0.8837
# Epoch 65/99, Loss: 0.2147, Accuracy: 0.9082, Time: 48.01s
# Validation Loss: 0.2921, Accuracy: 0.8837
# Epoch 66/99, Loss: 0.2063, Accuracy: 0.9107, Time: 53.72s
# Validation Loss: 0.2979, Accuracy: 0.8936
# Epoch 67/99, Loss: 0.2087, Accuracy: 0.9156, Time: 45.96s
# Validation Loss: 0.2655, Accuracy: 0.8886
# Epoch 68/99, Loss: 0.1947, Accuracy: 0.9237, Time: 56.13s
# Validation Loss: 0.3157, Accuracy: 0.8837
# Epoch 69/99, Loss: 0.1933, Accuracy: 0.9287, Time: 45.16s
# Validation Loss: 0.2784, Accuracy: 0.8762
# Epoch 70/99, Loss: 0.1966, Accuracy: 0.9218, Time: 55.92s
# Validation Loss: 0.2838, Accuracy: 0.8960
# Epoch 71/99, Loss: 0.2055, Accuracy: 0.9150, Time: 47.28s
# Validation Loss: 0.2985, Accuracy: 0.8936
# Epoch 72/99, Loss: 0.1967, Accuracy: 0.9274, Time: 54.87s
# Validation Loss: 0.3021, Accuracy: 0.8886
# Epoch 73/99, Loss: 0.1906, Accuracy: 0.9200, Time: 48.25s
# Validation Loss: 0.2750, Accuracy: 0.8936
# Epoch 74/99, Loss: 0.1912, Accuracy: 0.9237, Time: 45.40s
# Validation Loss: 0.2841, Accuracy: 0.8936
# Epoch 75/99, Loss: 0.1922, Accuracy: 0.9169, Time: 56.02s
# Validation Loss: 0.3090, Accuracy: 0.8985
# Epoch 76/99, Loss: 0.1881, Accuracy: 0.9218, Time: 46.88s
# Validation Loss: 0.2828, Accuracy: 0.9010
# Epoch 77/99, Loss: 0.1929, Accuracy: 0.9187, Time: 53.31s
# Validation Loss: 0.2784, Accuracy: 0.9010
# Epoch 78/99, Loss: 0.1848, Accuracy: 0.9225, Time: 46.94s
# Validation Loss: 0.2728, Accuracy: 0.9035
# Epoch 79/99, Loss: 0.1862, Accuracy: 0.9262, Time: 54.69s
# Validation Loss: 0.3172, Accuracy: 0.8812
# Epoch 80/99, Loss: 0.1911, Accuracy: 0.9163, Time: 46.51s
# Validation Loss: 0.3189, Accuracy: 0.8837
# Epoch 81/99, Loss: 0.1830, Accuracy: 0.9181, Time: 45.69s
# Validation Loss: 0.3188, Accuracy: 0.8688
# Epoch 82/99, Loss: 0.1716, Accuracy: 0.9330, Time: 56.08s
# Validation Loss: 0.3861, Accuracy: 0.8911
# Epoch 83/99, Loss: 0.1846, Accuracy: 0.9225, Time: 46.43s
# Validation Loss: 0.3302, Accuracy: 0.8886
# Epoch 84/99, Loss: 0.1873, Accuracy: 0.9274, Time: 55.02s
# Validation Loss: 0.3148, Accuracy: 0.8861
# Epoch 85/99, Loss: 0.1797, Accuracy: 0.9311, Time: 48.58s
# Validation Loss: 0.3743, Accuracy: 0.8762
# Epoch 86/99, Loss: 0.1808, Accuracy: 0.9243, Time: 53.91s
# Validation Loss: 0.3200, Accuracy: 0.8911
# Epoch 87/99, Loss: 0.1869, Accuracy: 0.9237, Time: 49.16s
# Validation Loss: 0.3131, Accuracy: 0.8861
# Epoch 88/99, Loss: 0.1678, Accuracy: 0.9423, Time: 53.84s
# Validation Loss: 0.3237, Accuracy: 0.8911
# Epoch 89/99, Loss: 0.1805, Accuracy: 0.9262, Time: 45.31s
# Validation Loss: 0.3212, Accuracy: 0.8960
# Epoch 90/99, Loss: 0.1692, Accuracy: 0.9373, Time: 45.95s
# Validation Loss: 0.3209, Accuracy: 0.8936
# Epoch 91/99, Loss: 0.1533, Accuracy: 0.9367, Time: 55.83s
# Validation Loss: 0.3756, Accuracy: 0.8812
# Epoch 92/99, Loss: 0.1746, Accuracy: 0.9268, Time: 48.14s
# Validation Loss: 0.3098, Accuracy: 0.8886
# Epoch 93/99, Loss: 0.1754, Accuracy: 0.9243, Time: 57.02s
# Validation Loss: 0.2875, Accuracy: 0.9035
# Epoch 94/99, Loss: 0.1876, Accuracy: 0.9231, Time: 48.67s
# Validation Loss: 0.3126, Accuracy: 0.8812
# Epoch 95/99, Loss: 0.1656, Accuracy: 0.9268, Time: 51.43s
# Validation Loss: 0.4606, Accuracy: 0.8713
# Epoch 96/99, Loss: 0.1590, Accuracy: 0.9349, Time: 44.39s
# Validation Loss: 0.4643, Accuracy: 0.8762
# Epoch 97/99, Loss: 0.1767, Accuracy: 0.9311, Time: 52.53s
# Validation Loss: 0.3693, Accuracy: 0.8960
# Epoch 98/99, Loss: 0.1624, Accuracy: 0.9361, Time: 47.40s
# Validation Loss: 0.5414, Accuracy: 0.8688
# Epoch 99/99, Loss: 0.1630, Accuracy: 0.9373, Time: 44.38s
# Validation Loss: 0.3767, Accuracy: 0.8787
# Model saved with accuracy: 0.9035
# Matriz de Confusión:
# [[173  22]
#  [ 17 192]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       195
#            1       0.90      0.92      0.91       209
#
#     accuracy                           0.90       404
#    macro avg       0.90      0.90      0.90       404
# weighted avg       0.90      0.90      0.90       404
#
# Accuracy: 0.9035
