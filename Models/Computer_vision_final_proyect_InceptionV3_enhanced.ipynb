# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 53.6 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7

# %%
import rasterio
import torch
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms, datasets
import matplotlib.pyplot as plt
import os
import shutil
import random
from google.colab import drive
import sys
import time
import json
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from PIL import Image

# %%
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#path = '/content/drive/MyDrive/Academico/Computer Vision'
#sys.path.append(path)

base_dir = os.getcwd()

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
def determine_max_pixel_value(data):
    max_value = 0
    for item in data:
        image = Image.open(item['image_path'])
        if image.mode != 'RGB':
            image = image.convert('RGB')
        image_np = np.array(image)
        max_value = max(max_value, image_np.max())
    return max_value

# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader
import rasterio
import numpy as np
from torchvision import transforms

# Function to load data from JSON file
def load_data(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)
    return data

def scale_and_normalize_image(image, max_value):
    image = np.array(image).astype(np.float32)
    image = (image / image.max()) * 255
    return image/max_value

class TiffDataset(Dataset):
    def __init__(self, data, transform=None, max_value = 255.0):
        self.data = data
        self.transform = transform
        self.max_value = max_value

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        image = Image.open(item['image_path'])

        # Convert to RGB if necessary
        if image.mode != 'RGB':
            image = image.convert('RGB')

        image = scale_and_normalize_image(image, self.max_value)

        if self.transform:
            image = self.transform(image)

        label = item['label']
        return image, label

# Load data from JSON files
train_json_file = base_dir + '/Data/Train_80_enhanced.json'
test_json_file = base_dir + '/Data/Test_20_enhanced.json'
train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

#max_pixel_value = determine_max_pixel_value(train_data)
max_pixel_value = 255.0
# Define transformations


transform_tr = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(degrees=180),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.Resize((299,299)),






])


transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((299,299))

])

# Determine the max pixel value from the training dataset for normalization

# Create datasets
train_dataset = TiffDataset(train_data, transform=transform_tr, max_value=max_pixel_value)
test_dataset = TiffDataset(test_data, transform=transform_val, max_value=max_pixel_value)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
import torch.nn as nn
import torch.optim as optim
import time

model =  models.inception_v3(weights='DEFAULT')
num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 2)

# Move the model to GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Multi-class classification
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Define a learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1) #Drop to 0.0001 after 50 epochs

# Training function
def train_model(model, criterion, optimizer, train_loader, val_loader, scheduler, num_epochs=100):
    best_acc = 0.0
    best_model_wts = None
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        corrects = 0
        start_time = time.time()

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            outputs = outputs.logits if isinstance(outputs, models.inception.InceptionOutputs) else outputs
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            corrects += torch.sum(preds == labels.data)

        scheduler.step()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = corrects.double() / len(train_loader.dataset)
        elapsed_time = time.time() - start_time
        print(f"Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}, Time: {elapsed_time:.2f}s")

        # Validate the model
        model.eval()
        val_loss = 0.0
        corrects = 0
        all_labels = []
        all_preds = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                corrects += torch.sum(preds == labels.data)
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(preds.cpu().numpy())


        val_loss /= len(val_loader.dataset)
        val_acc = corrects.double() / len(val_loader.dataset)
        print(f"Validation Loss: {val_loss:.4f}, Accuracy: {val_acc:.4f}")
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = model.state_dict()
            best_all_labels = all_labels
            best_all_preds = all_preds

    model.load_state_dict(best_model_wts)


    torch.save(model.state_dict(), base_dir + '/Redes_entrenadas/InceptionV3_enhanced_fp.pth')
    print('Model saved with accuracy: {:.4f}'.format(best_acc))

    cm = confusion_matrix(best_all_labels, best_all_preds)
    cr = classification_report(best_all_labels, best_all_preds)
    accuracy = (np.array(best_all_preds) == np.array(best_all_labels)).mean()
    print("Matriz de Confusión:")
    print(cm)
    print("Reporte de Clasificación:")
    print(cr)
    print(f"Accuracy: {accuracy:.4f}")

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Clase 0', 'Clase 1'], yticklabels=['Clase 0', 'Clase 1'])
    plt.xlabel('Predicción')
    plt.ylabel('Verdadero')
    plt.title('Matriz de Confusión')
    plt.show()

# Train the model
train_model(model, criterion, optimizer, train_loader, test_loader, scheduler, num_epochs=100)
# Out:
# Epoch 0/99, Loss: 0.5460, Accuracy: 0.7184, Time: 272.26s
# Validation Loss: 0.4618, Accuracy: 0.7772
# Epoch 1/99, Loss: 0.4798, Accuracy: 0.7599, Time: 4.88s
# Validation Loss: 0.5363, Accuracy: 0.7995
# Epoch 2/99, Loss: 0.4690, Accuracy: 0.7699, Time: 4.87s
# Validation Loss: 0.7934, Accuracy: 0.8045
# Epoch 3/99, Loss: 0.4406, Accuracy: 0.8040, Time: 4.90s
# Validation Loss: 0.4855, Accuracy: 0.7649
# Epoch 4/99, Loss: 0.4127, Accuracy: 0.8114, Time: 4.83s
# Validation Loss: 0.4617, Accuracy: 0.8144
# Epoch 5/99, Loss: 0.4250, Accuracy: 0.8058, Time: 4.78s
# Validation Loss: 0.8966, Accuracy: 0.7896
# Epoch 6/99, Loss: 0.4337, Accuracy: 0.8083, Time: 5.06s
# Validation Loss: 0.4386, Accuracy: 0.8193
# Epoch 7/99, Loss: 0.4056, Accuracy: 0.8145, Time: 4.83s
# Validation Loss: 1.0853, Accuracy: 0.7772
# Epoch 8/99, Loss: 0.4239, Accuracy: 0.8052, Time: 5.39s
# Validation Loss: 0.4721, Accuracy: 0.8317
# Epoch 9/99, Loss: 0.4036, Accuracy: 0.8114, Time: 4.86s
# Validation Loss: 0.6005, Accuracy: 0.8267
# Epoch 10/99, Loss: 0.4094, Accuracy: 0.8127, Time: 5.03s
# Validation Loss: 0.4525, Accuracy: 0.7970
# Epoch 11/99, Loss: 0.3859, Accuracy: 0.8226, Time: 4.74s
# Validation Loss: 0.5453, Accuracy: 0.7203
# Epoch 12/99, Loss: 0.4048, Accuracy: 0.8220, Time: 4.82s
# Validation Loss: 0.8248, Accuracy: 0.7673
# Epoch 13/99, Loss: 0.4458, Accuracy: 0.7984, Time: 4.82s
# Validation Loss: 0.4611, Accuracy: 0.8168
# Epoch 14/99, Loss: 0.4250, Accuracy: 0.7996, Time: 4.86s
# Validation Loss: 0.7006, Accuracy: 0.6312
# Epoch 15/99, Loss: 0.3951, Accuracy: 0.8145, Time: 4.86s
# Validation Loss: 0.4461, Accuracy: 0.8267
# Epoch 16/99, Loss: 0.3925, Accuracy: 0.8176, Time: 4.93s
# Validation Loss: 0.4929, Accuracy: 0.7995
# Epoch 17/99, Loss: 0.3900, Accuracy: 0.8257, Time: 5.05s
# Validation Loss: 0.4377, Accuracy: 0.8069
# Epoch 18/99, Loss: 0.3870, Accuracy: 0.8232, Time: 4.77s
# Validation Loss: 0.3821, Accuracy: 0.8317
# Epoch 19/99, Loss: 0.3782, Accuracy: 0.8300, Time: 4.97s
# Validation Loss: 0.4196, Accuracy: 0.8490
# Epoch 20/99, Loss: 0.3625, Accuracy: 0.8275, Time: 4.81s
# Validation Loss: 0.7153, Accuracy: 0.8020
# Epoch 21/99, Loss: 0.3657, Accuracy: 0.8325, Time: 4.90s
# Validation Loss: 0.5971, Accuracy: 0.7921
# Epoch 22/99, Loss: 0.3815, Accuracy: 0.8282, Time: 4.76s
# Validation Loss: 0.4581, Accuracy: 0.8391
# Epoch 23/99, Loss: 0.3581, Accuracy: 0.8344, Time: 4.88s
# Validation Loss: 0.5852, Accuracy: 0.7970
# Epoch 24/99, Loss: 0.3618, Accuracy: 0.8400, Time: 4.82s
# Validation Loss: 0.3989, Accuracy: 0.8589
# Epoch 25/99, Loss: 0.3703, Accuracy: 0.8313, Time: 4.65s
# Validation Loss: 0.4033, Accuracy: 0.8292
# Epoch 26/99, Loss: 0.3661, Accuracy: 0.8368, Time: 4.91s
# Validation Loss: 0.6931, Accuracy: 0.8094
# Epoch 27/99, Loss: 0.3672, Accuracy: 0.8313, Time: 4.78s
# Validation Loss: 0.4584, Accuracy: 0.8465
# Epoch 28/99, Loss: 0.3808, Accuracy: 0.8170, Time: 5.03s
# Validation Loss: 0.6734, Accuracy: 0.7401
# Epoch 29/99, Loss: 0.3691, Accuracy: 0.8368, Time: 4.71s
# Validation Loss: 0.4083, Accuracy: 0.8144
# Epoch 30/99, Loss: 0.3578, Accuracy: 0.8344, Time: 4.96s
# Validation Loss: 0.3977, Accuracy: 0.8416
# Epoch 31/99, Loss: 0.3720, Accuracy: 0.8306, Time: 4.79s
# Validation Loss: 0.3906, Accuracy: 0.8292
# Epoch 32/99, Loss: 0.3480, Accuracy: 0.8449, Time: 4.77s
# Validation Loss: 0.7462, Accuracy: 0.8292
# Epoch 33/99, Loss: 0.3680, Accuracy: 0.8331, Time: 4.89s
# Validation Loss: 0.5707, Accuracy: 0.8342
# Epoch 34/99, Loss: 0.3477, Accuracy: 0.8412, Time: 4.84s
# Validation Loss: 0.4207, Accuracy: 0.8416
# Epoch 35/99, Loss: 0.3606, Accuracy: 0.8344, Time: 4.97s
# Validation Loss: 0.3963, Accuracy: 0.8317
# Epoch 36/99, Loss: 0.3452, Accuracy: 0.8418, Time: 4.77s
# Validation Loss: 0.4591, Accuracy: 0.8342
# Epoch 37/99, Loss: 0.3216, Accuracy: 0.8480, Time: 5.00s
# Validation Loss: 0.4413, Accuracy: 0.8218
# Epoch 38/99, Loss: 0.3339, Accuracy: 0.8437, Time: 4.77s
# Validation Loss: 0.3804, Accuracy: 0.8342
# Epoch 39/99, Loss: 0.3339, Accuracy: 0.8468, Time: 5.09s
# Validation Loss: 0.4052, Accuracy: 0.8342
# Epoch 40/99, Loss: 0.3279, Accuracy: 0.8468, Time: 4.75s
# Validation Loss: 0.4485, Accuracy: 0.8218
# Epoch 41/99, Loss: 0.3338, Accuracy: 0.8400, Time: 4.80s
# Validation Loss: 0.4048, Accuracy: 0.8515
# Epoch 42/99, Loss: 0.3213, Accuracy: 0.8592, Time: 4.75s
# Validation Loss: 0.4776, Accuracy: 0.8168
# Epoch 43/99, Loss: 0.3309, Accuracy: 0.8493, Time: 4.83s
# Validation Loss: 0.4127, Accuracy: 0.8391
# Epoch 44/99, Loss: 0.3323, Accuracy: 0.8511, Time: 4.80s
# Validation Loss: 0.4330, Accuracy: 0.8416
# Epoch 45/99, Loss: 0.3230, Accuracy: 0.8592, Time: 4.84s
# Validation Loss: 0.4964, Accuracy: 0.8218
# Epoch 46/99, Loss: 0.3445, Accuracy: 0.8455, Time: 4.97s
# Validation Loss: 0.4127, Accuracy: 0.8366
# Epoch 47/99, Loss: 0.3217, Accuracy: 0.8480, Time: 5.00s
# Validation Loss: 0.4222, Accuracy: 0.8218
# Epoch 48/99, Loss: 0.3351, Accuracy: 0.8561, Time: 4.97s
# Validation Loss: 0.6730, Accuracy: 0.7797
# Epoch 49/99, Loss: 0.3474, Accuracy: 0.8412, Time: 4.84s
# Validation Loss: 0.4390, Accuracy: 0.8366
# Epoch 50/99, Loss: 0.3218, Accuracy: 0.8480, Time: 5.01s
# Validation Loss: 0.3935, Accuracy: 0.8391
# Epoch 51/99, Loss: 0.2972, Accuracy: 0.8741, Time: 4.81s
# Validation Loss: 0.4059, Accuracy: 0.8490
# Epoch 52/99, Loss: 0.2947, Accuracy: 0.8672, Time: 4.81s
# Validation Loss: 0.4001, Accuracy: 0.8564
# Epoch 53/99, Loss: 0.3049, Accuracy: 0.8610, Time: 4.73s
# Validation Loss: 0.3972, Accuracy: 0.8490
# Epoch 54/99, Loss: 0.2653, Accuracy: 0.8828, Time: 4.93s
# Validation Loss: 0.4102, Accuracy: 0.8564
# Epoch 55/99, Loss: 0.2933, Accuracy: 0.8641, Time: 4.72s
# Validation Loss: 0.4167, Accuracy: 0.8465
# Epoch 56/99, Loss: 0.2885, Accuracy: 0.8660, Time: 4.79s
# Validation Loss: 0.4253, Accuracy: 0.8589
# Epoch 57/99, Loss: 0.2763, Accuracy: 0.8766, Time: 4.97s
# Validation Loss: 0.4198, Accuracy: 0.8589
# Epoch 58/99, Loss: 0.2742, Accuracy: 0.8766, Time: 4.73s
# Validation Loss: 0.4306, Accuracy: 0.8540
# Epoch 59/99, Loss: 0.2558, Accuracy: 0.8921, Time: 5.00s
# Validation Loss: 0.4368, Accuracy: 0.8564
# Epoch 60/99, Loss: 0.2706, Accuracy: 0.8815, Time: 4.82s
# Validation Loss: 0.4633, Accuracy: 0.8540
# Epoch 61/99, Loss: 0.2670, Accuracy: 0.8890, Time: 4.98s
# Validation Loss: 0.4274, Accuracy: 0.8540
# Epoch 62/99, Loss: 0.2592, Accuracy: 0.8821, Time: 4.84s
# Validation Loss: 0.4886, Accuracy: 0.8515
# Epoch 63/99, Loss: 0.2575, Accuracy: 0.8828, Time: 4.70s
# Validation Loss: 0.4741, Accuracy: 0.8490
# Epoch 64/99, Loss: 0.2562, Accuracy: 0.8890, Time: 4.87s
# Validation Loss: 0.4472, Accuracy: 0.8465
# Epoch 65/99, Loss: 0.2580, Accuracy: 0.8821, Time: 4.77s
# Validation Loss: 0.4409, Accuracy: 0.8441
# Epoch 66/99, Loss: 0.2511, Accuracy: 0.8927, Time: 4.99s
# Validation Loss: 0.4833, Accuracy: 0.8515
# Epoch 67/99, Loss: 0.2377, Accuracy: 0.8964, Time: 4.70s
# Validation Loss: 0.4413, Accuracy: 0.8540
# Epoch 68/99, Loss: 0.2607, Accuracy: 0.8859, Time: 4.94s
# Validation Loss: 0.4135, Accuracy: 0.8490
# Epoch 69/99, Loss: 0.2475, Accuracy: 0.8834, Time: 4.79s
# Validation Loss: 0.4344, Accuracy: 0.8515
# Epoch 70/99, Loss: 0.2419, Accuracy: 0.8865, Time: 5.07s
# Validation Loss: 0.4753, Accuracy: 0.8515
# Epoch 71/99, Loss: 0.2369, Accuracy: 0.8852, Time: 4.82s
# Validation Loss: 0.5085, Accuracy: 0.8490
# Epoch 72/99, Loss: 0.2371, Accuracy: 0.8846, Time: 4.89s
# Validation Loss: 0.4787, Accuracy: 0.8564
# Epoch 73/99, Loss: 0.2480, Accuracy: 0.8846, Time: 4.84s
# Validation Loss: 0.4676, Accuracy: 0.8515
# Epoch 74/99, Loss: 0.2533, Accuracy: 0.8902, Time: 4.80s
# Validation Loss: 0.4609, Accuracy: 0.8465
# Epoch 75/99, Loss: 0.2404, Accuracy: 0.8890, Time: 4.86s
# Validation Loss: 0.4775, Accuracy: 0.8416
# Epoch 76/99, Loss: 0.2410, Accuracy: 0.8921, Time: 4.77s
# Validation Loss: 0.4850, Accuracy: 0.8441
# Epoch 77/99, Loss: 0.2218, Accuracy: 0.8970, Time: 4.96s
# Validation Loss: 0.5172, Accuracy: 0.8540
# Epoch 78/99, Loss: 0.2123, Accuracy: 0.9007, Time: 4.82s
# Validation Loss: 0.5141, Accuracy: 0.8490
# Epoch 79/99, Loss: 0.2468, Accuracy: 0.8890, Time: 4.93s
# Validation Loss: 0.6248, Accuracy: 0.8490
# Epoch 80/99, Loss: 0.2277, Accuracy: 0.9038, Time: 4.85s
# Validation Loss: 0.5158, Accuracy: 0.8465
# Epoch 81/99, Loss: 0.2209, Accuracy: 0.9076, Time: 5.03s
# Validation Loss: 0.5064, Accuracy: 0.8416
# Epoch 82/99, Loss: 0.2423, Accuracy: 0.8921, Time: 4.82s
# Validation Loss: 0.5143, Accuracy: 0.8465
# Epoch 83/99, Loss: 0.2187, Accuracy: 0.9057, Time: 4.90s
# Validation Loss: 0.4855, Accuracy: 0.8292
# Epoch 84/99, Loss: 0.2106, Accuracy: 0.9063, Time: 4.79s
# Validation Loss: 0.4936, Accuracy: 0.8391
# Epoch 85/99, Loss: 0.2290, Accuracy: 0.9026, Time: 4.75s
# Validation Loss: 0.5254, Accuracy: 0.8515
# Epoch 86/99, Loss: 0.2208, Accuracy: 0.8927, Time: 5.02s
# Validation Loss: 0.4928, Accuracy: 0.8416
# Epoch 87/99, Loss: 0.2056, Accuracy: 0.9020, Time: 4.94s
# Validation Loss: 0.5587, Accuracy: 0.8416
# Epoch 88/99, Loss: 0.2126, Accuracy: 0.9082, Time: 4.79s
# Validation Loss: 0.5495, Accuracy: 0.8441
# Epoch 89/99, Loss: 0.2201, Accuracy: 0.8989, Time: 4.74s
# Validation Loss: 0.5592, Accuracy: 0.8465
# Epoch 90/99, Loss: 0.2180, Accuracy: 0.9001, Time: 5.04s
# Validation Loss: 0.4921, Accuracy: 0.8391
# Epoch 91/99, Loss: 0.2115, Accuracy: 0.9088, Time: 4.79s
# Validation Loss: 0.5305, Accuracy: 0.8416
# Epoch 92/99, Loss: 0.2006, Accuracy: 0.9156, Time: 4.97s
# Validation Loss: 0.5106, Accuracy: 0.8243
# Epoch 93/99, Loss: 0.2056, Accuracy: 0.9125, Time: 4.78s
# Validation Loss: 0.4986, Accuracy: 0.8441
# Epoch 94/99, Loss: 0.2137, Accuracy: 0.9001, Time: 4.88s
# Validation Loss: 0.5135, Accuracy: 0.8391
# Epoch 95/99, Loss: 0.1912, Accuracy: 0.9212, Time: 4.77s
# Validation Loss: 0.5484, Accuracy: 0.8267
# Epoch 96/99, Loss: 0.1940, Accuracy: 0.9163, Time: 4.75s
# Validation Loss: 0.5981, Accuracy: 0.8416
# Epoch 97/99, Loss: 0.1868, Accuracy: 0.9144, Time: 4.86s
# Validation Loss: 0.5817, Accuracy: 0.8267
# Epoch 98/99, Loss: 0.1788, Accuracy: 0.9237, Time: 4.81s
# Validation Loss: 0.5783, Accuracy: 0.8540
# Epoch 99/99, Loss: 0.2054, Accuracy: 0.9063, Time: 4.91s
# Validation Loss: 0.5680, Accuracy: 0.8416
# Model saved with accuracy: 0.8589
# Matriz de Confusión:
# [[156  39]
#  [ 18 191]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.90      0.80      0.85       195
#            1       0.83      0.91      0.87       209
#
#     accuracy                           0.86       404
#    macro avg       0.86      0.86      0.86       404
# weighted avg       0.86      0.86      0.86       404
#
# Accuracy: 0.8589
