# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 60.4 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7

# %%
import rasterio
import torch
import torch.nn as nn
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms, datasets
import matplotlib.pyplot as plt
import os
import shutil
import random
from google.colab import drive
import sys
import time
import json
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from PIL import Image

# %%
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#path = '/content/drive/MyDrive/Academico/Computer Vision'
#sys.path.append(path)

base_dir = os.getcwd()

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
def determine_max_pixel_value(data):
    max_value = 0
    for item in data:
        with rasterio.open(item['image_path']) as src:
            max_value = max(max_value, src.read([1,2,3]).max())
    return max_value

# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader
import rasterio
import numpy as np
from torchvision import transforms

# Function to load data from JSON file
def load_data(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)
    return data

def scale_and_normalize_image(image, max_value):
    image = np.array(image).astype(np.float32)
    image = (image / image.max()) * 255
    return image/max_value

class TiffDataset(Dataset):
    def __init__(self, data, transform=None, max_value = 255.0):
        self.data = data
        self.transform = transform
        self.max_value = max_value

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):

        item = self.data[idx]
        with rasterio.open(item['image_path']) as src:
            image = src.read([1,2,3])  # Read RGB bands
            image = np.transpose(image, (1, 2, 0))  # Channels last
            image = scale_and_normalize_image(image, self.max_value)

        if self.transform:
          image = self.transform(image)


        label = item['label']
        return image, label


# Load data from JSON files
train_json_file = base_dir + '/Data/Train_80.json'
test_json_file = base_dir + '/Data/Test_20.json'
train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

train_data = load_data(train_json_file)
test_data = load_data(test_json_file)


max_pixel_value = 255.0
# Define transformations


transform_tr = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(degrees=180),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    #transforms.Resize(64)

])


transform_val = transforms.Compose([
    transforms.ToTensor(),
    #transforms.Resize(64)





])

# Determine the max pixel value from the training dataset for normalization

# Create datasets
train_dataset = TiffDataset(train_data, transform=transform_tr, max_value=max_pixel_value)
test_dataset = TiffDataset(test_data, transform=transform_val, max_value=max_pixel_value)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.dropout = nn.Dropout(p=0.5)

        # Calcular las dimensiones de la salida después de las capas convolucionales y de pooling
        self.feature_size = 128 * 8 * 8  # Usando la entrada de 128x128, esto cambiará según tus capas

        self.fc1 = nn.Linear(self.feature_size, 512)
        self.fc2 = nn.Linear(512, 2)  # Binary classification with two output units

    def forward(self, x):
        x = self.conv1(x)
        x = nn.ReLU()(x)
        x = self.conv2(x)
        x = nn.ReLU()(x)
        x = self.pool(x)
        x = self.conv3(x)
        x = nn.ReLU()(x)
        x = self.pool(x)
        x = self.dropout(x)

        # Calcular el tamaño del lote dinámicamente
        batch_size = x.size(0)
        x = x.view(batch_size, -1)  # Redimensionar el tensor para la capa fully connected

        x = self.fc1(x)
        x = nn.ReLU()(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
import torch.nn as nn
import torch.optim as optim
import time

model = SimpleCNN()

# Move the model to GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Multi-class classification
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Define a learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1) #Drop to 0.0001 after 50 epochs

# Training function
def train_model(model, criterion, optimizer, train_loader, val_loader, scheduler, num_epochs=100):
    best_acc = 0.0
    best_model_wts = None
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        corrects = 0
        start_time = time.time()

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            corrects += torch.sum(preds == labels.data)

        scheduler.step()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = corrects.double() / len(train_loader.dataset)
        elapsed_time = time.time() - start_time
        print(f"Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}, Time: {elapsed_time:.2f}s")

        # Validate the model
        model.eval()
        val_loss = 0.0
        corrects = 0
        all_labels = []
        all_preds = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                corrects += torch.sum(preds == labels.data)
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(preds.cpu().numpy())


        val_loss /= len(val_loader.dataset)
        val_acc = corrects.double() / len(val_loader.dataset)
        print(f"Validation Loss: {val_loss:.4f}, Accuracy: {val_acc:.4f}")
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = model.state_dict()
            best_all_labels = all_labels
            best_all_preds = all_preds

    model.load_state_dict(best_model_wts)


    torch.save(model.state_dict(), base_dir + '/Redes_entrenadas/CNN_not_enhanced.pth')
    print('Model saved with accuracy: {:.4f}'.format(best_acc))

    cm = confusion_matrix(best_all_labels, best_all_preds)
    cr = classification_report(best_all_labels, best_all_preds)
    accuracy = (np.array(best_all_preds) == np.array(best_all_labels)).mean()
    print("Matriz de Confusión:")
    print(cm)
    print("Reporte de Clasificación:")
    print(cr)
    print(f"Accuracy: {accuracy:.4f}")

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Clase 0', 'Clase 1'], yticklabels=['Clase 0', 'Clase 1'])
    plt.xlabel('Predicción')
    plt.ylabel('Verdadero')
    plt.title('Matriz de Confusión')
    plt.show()

# Train the model
train_model(model, criterion, optimizer, train_loader, test_loader, scheduler, num_epochs=100)
# Out:
# Epoch 0/99, Loss: 0.6854, Accuracy: 0.5242, Time: 40.75s
# Validation Loss: 0.6446, Accuracy: 0.5594
# Epoch 1/99, Loss: 0.6061, Accuracy: 0.6402, Time: 30.79s
# Validation Loss: 0.5793, Accuracy: 0.6906
# Epoch 2/99, Loss: 0.5699, Accuracy: 0.6811, Time: 40.02s
# Validation Loss: 0.5518, Accuracy: 0.6955
# Epoch 3/99, Loss: 0.5801, Accuracy: 0.6663, Time: 28.75s
# Validation Loss: 0.5591, Accuracy: 0.6980
# Epoch 4/99, Loss: 0.5652, Accuracy: 0.6911, Time: 29.41s
# Validation Loss: 0.5507, Accuracy: 0.7203
# Epoch 5/99, Loss: 0.5649, Accuracy: 0.6892, Time: 28.49s
# Validation Loss: 0.5492, Accuracy: 0.7054
# Epoch 6/99, Loss: 0.5474, Accuracy: 0.7041, Time: 38.85s
# Validation Loss: 0.5625, Accuracy: 0.7030
# Epoch 7/99, Loss: 0.5466, Accuracy: 0.7010, Time: 28.91s
# Validation Loss: 0.5400, Accuracy: 0.7203
# Epoch 8/99, Loss: 0.5567, Accuracy: 0.6960, Time: 30.78s
# Validation Loss: 0.5561, Accuracy: 0.6906
# Epoch 9/99, Loss: 0.5481, Accuracy: 0.7066, Time: 40.83s
# Validation Loss: 0.5495, Accuracy: 0.7005
# Epoch 10/99, Loss: 0.5232, Accuracy: 0.7233, Time: 29.76s
# Validation Loss: 0.5314, Accuracy: 0.7376
# Epoch 11/99, Loss: 0.5183, Accuracy: 0.7221, Time: 28.80s
# Validation Loss: 0.5714, Accuracy: 0.6683
# Epoch 12/99, Loss: 0.5203, Accuracy: 0.7134, Time: 29.50s
# Validation Loss: 0.5604, Accuracy: 0.7153
# Epoch 13/99, Loss: 0.5225, Accuracy: 0.7357, Time: 39.79s
# Validation Loss: 0.5434, Accuracy: 0.6881
# Epoch 14/99, Loss: 0.5397, Accuracy: 0.7196, Time: 29.45s
# Validation Loss: 0.5358, Accuracy: 0.7351
# Epoch 15/99, Loss: 0.5223, Accuracy: 0.7177, Time: 29.96s
# Validation Loss: 0.5370, Accuracy: 0.7401
# Epoch 16/99, Loss: 0.5248, Accuracy: 0.7333, Time: 40.51s
# Validation Loss: 0.6051, Accuracy: 0.6757
# Epoch 17/99, Loss: 0.5315, Accuracy: 0.7326, Time: 28.34s
# Validation Loss: 0.5470, Accuracy: 0.7302
# Epoch 18/99, Loss: 0.5307, Accuracy: 0.7246, Time: 31.39s
# Validation Loss: 0.5459, Accuracy: 0.7054
# Epoch 19/99, Loss: 0.5163, Accuracy: 0.7277, Time: 29.19s
# Validation Loss: 0.5789, Accuracy: 0.6733
# Epoch 20/99, Loss: 0.5250, Accuracy: 0.7258, Time: 37.74s
# Validation Loss: 0.5494, Accuracy: 0.6906
# Epoch 21/99, Loss: 0.5129, Accuracy: 0.7301, Time: 30.99s
# Validation Loss: 0.5283, Accuracy: 0.7252
# Epoch 22/99, Loss: 0.5036, Accuracy: 0.7308, Time: 35.84s
# Validation Loss: 0.5279, Accuracy: 0.7104
# Epoch 23/99, Loss: 0.5011, Accuracy: 0.7444, Time: 44.12s
# Validation Loss: 0.5643, Accuracy: 0.6807
# Epoch 24/99, Loss: 0.5077, Accuracy: 0.7401, Time: 34.25s
# Validation Loss: 0.5411, Accuracy: 0.7079
# Epoch 25/99, Loss: 0.5168, Accuracy: 0.7289, Time: 36.10s
# Validation Loss: 0.5112, Accuracy: 0.7574
# Epoch 26/99, Loss: 0.5175, Accuracy: 0.7314, Time: 43.57s
# Validation Loss: 0.5325, Accuracy: 0.7129
# Epoch 27/99, Loss: 0.5105, Accuracy: 0.7301, Time: 35.83s
# Validation Loss: 0.5604, Accuracy: 0.7129
# Epoch 28/99, Loss: 0.5257, Accuracy: 0.7146, Time: 36.17s
# Validation Loss: 0.5215, Accuracy: 0.7277
# Epoch 29/99, Loss: 0.5085, Accuracy: 0.7351, Time: 44.71s
# Validation Loss: 0.5469, Accuracy: 0.7129
# Epoch 30/99, Loss: 0.5138, Accuracy: 0.7289, Time: 34.85s
# Validation Loss: 0.5164, Accuracy: 0.7525
# Epoch 31/99, Loss: 0.4940, Accuracy: 0.7512, Time: 33.21s
# Validation Loss: 0.5345, Accuracy: 0.7302
# Epoch 32/99, Loss: 0.4979, Accuracy: 0.7395, Time: 45.97s
# Validation Loss: 0.5269, Accuracy: 0.7277
# Epoch 33/99, Loss: 0.4936, Accuracy: 0.7506, Time: 33.83s
# Validation Loss: 0.5353, Accuracy: 0.7475
# Epoch 34/99, Loss: 0.4968, Accuracy: 0.7463, Time: 32.58s
# Validation Loss: 0.5222, Accuracy: 0.7351
# Epoch 35/99, Loss: 0.5260, Accuracy: 0.7159, Time: 40.62s
# Validation Loss: 0.5209, Accuracy: 0.7302
# Epoch 36/99, Loss: 0.4965, Accuracy: 0.7407, Time: 32.78s
# Validation Loss: 0.5230, Accuracy: 0.7698
# Epoch 37/99, Loss: 0.4946, Accuracy: 0.7475, Time: 33.80s
# Validation Loss: 0.5359, Accuracy: 0.7426
# Epoch 38/99, Loss: 0.4901, Accuracy: 0.7618, Time: 43.78s
# Validation Loss: 0.5290, Accuracy: 0.7277
# Epoch 39/99, Loss: 0.4857, Accuracy: 0.7562, Time: 31.63s
# Validation Loss: 0.5165, Accuracy: 0.7550
# Epoch 40/99, Loss: 0.4917, Accuracy: 0.7450, Time: 33.28s
# Validation Loss: 0.4969, Accuracy: 0.7673
# Epoch 41/99, Loss: 0.4832, Accuracy: 0.7636, Time: 41.74s
# Validation Loss: 0.5099, Accuracy: 0.7500
# Epoch 42/99, Loss: 0.4787, Accuracy: 0.7630, Time: 32.61s
# Validation Loss: 0.5647, Accuracy: 0.6881
# Epoch 43/99, Loss: 0.4798, Accuracy: 0.7599, Time: 32.29s
# Validation Loss: 0.5054, Accuracy: 0.7624
# Epoch 44/99, Loss: 0.4838, Accuracy: 0.7550, Time: 41.89s
# Validation Loss: 0.5516, Accuracy: 0.7228
# Epoch 45/99, Loss: 0.5026, Accuracy: 0.7326, Time: 33.49s
# Validation Loss: 0.4994, Accuracy: 0.7401
# Epoch 46/99, Loss: 0.4772, Accuracy: 0.7612, Time: 33.19s
# Validation Loss: 0.5223, Accuracy: 0.7624
# Epoch 47/99, Loss: 0.4935, Accuracy: 0.7581, Time: 43.26s
# Validation Loss: 0.4988, Accuracy: 0.7525
# Epoch 48/99, Loss: 0.4835, Accuracy: 0.7537, Time: 35.32s
# Validation Loss: 0.5599, Accuracy: 0.7426
# Epoch 49/99, Loss: 0.5073, Accuracy: 0.7401, Time: 32.65s
# Validation Loss: 0.4997, Accuracy: 0.7574
# Epoch 50/99, Loss: 0.4770, Accuracy: 0.7699, Time: 33.54s
# Validation Loss: 0.4933, Accuracy: 0.7649
# Epoch 51/99, Loss: 0.4661, Accuracy: 0.7699, Time: 41.17s
# Validation Loss: 0.4913, Accuracy: 0.7574
# Epoch 52/99, Loss: 0.4577, Accuracy: 0.7754, Time: 31.56s
# Validation Loss: 0.4896, Accuracy: 0.7574
# Epoch 53/99, Loss: 0.4551, Accuracy: 0.7798, Time: 32.17s
# Validation Loss: 0.4921, Accuracy: 0.7673
# Epoch 54/99, Loss: 0.4477, Accuracy: 0.7742, Time: 41.69s
# Validation Loss: 0.4931, Accuracy: 0.7550
# Epoch 55/99, Loss: 0.4556, Accuracy: 0.7736, Time: 32.56s
# Validation Loss: 0.4893, Accuracy: 0.7649
# Epoch 56/99, Loss: 0.4446, Accuracy: 0.7810, Time: 32.36s
# Validation Loss: 0.4894, Accuracy: 0.7723
# Epoch 57/99, Loss: 0.4517, Accuracy: 0.7730, Time: 40.07s
# Validation Loss: 0.4903, Accuracy: 0.7550
# Epoch 58/99, Loss: 0.4445, Accuracy: 0.7767, Time: 31.58s
# Validation Loss: 0.4936, Accuracy: 0.7351
# Epoch 59/99, Loss: 0.4445, Accuracy: 0.7816, Time: 35.45s
# Validation Loss: 0.4919, Accuracy: 0.7525
# Epoch 60/99, Loss: 0.4447, Accuracy: 0.7792, Time: 41.61s
# Validation Loss: 0.4866, Accuracy: 0.7772
# Epoch 61/99, Loss: 0.4426, Accuracy: 0.7928, Time: 32.64s
# Validation Loss: 0.4905, Accuracy: 0.7723
# Epoch 62/99, Loss: 0.4363, Accuracy: 0.7878, Time: 33.51s
# Validation Loss: 0.4869, Accuracy: 0.7822
# Epoch 63/99, Loss: 0.4411, Accuracy: 0.7872, Time: 31.95s
# Validation Loss: 0.4873, Accuracy: 0.7649
# Epoch 64/99, Loss: 0.4456, Accuracy: 0.7872, Time: 33.26s
# Validation Loss: 0.4861, Accuracy: 0.7624
# Epoch 65/99, Loss: 0.4329, Accuracy: 0.7940, Time: 33.64s
# Validation Loss: 0.4923, Accuracy: 0.7550
# Epoch 66/99, Loss: 0.4345, Accuracy: 0.7841, Time: 31.71s
# Validation Loss: 0.4841, Accuracy: 0.7673
# Epoch 67/99, Loss: 0.4359, Accuracy: 0.7897, Time: 42.64s
# Validation Loss: 0.4850, Accuracy: 0.7649
# Epoch 68/99, Loss: 0.4391, Accuracy: 0.7854, Time: 32.41s
# Validation Loss: 0.4823, Accuracy: 0.7723
# Epoch 69/99, Loss: 0.4378, Accuracy: 0.7866, Time: 34.46s
# Validation Loss: 0.4780, Accuracy: 0.7748
# Epoch 70/99, Loss: 0.4457, Accuracy: 0.7792, Time: 41.23s
# Validation Loss: 0.4754, Accuracy: 0.7847
# Epoch 71/99, Loss: 0.4297, Accuracy: 0.7978, Time: 31.49s
# Validation Loss: 0.4799, Accuracy: 0.7772
# Epoch 72/99, Loss: 0.4273, Accuracy: 0.7885, Time: 33.86s
# Validation Loss: 0.4957, Accuracy: 0.7525
# Epoch 73/99, Loss: 0.4364, Accuracy: 0.7872, Time: 42.26s
# Validation Loss: 0.4854, Accuracy: 0.7797
# Epoch 74/99, Loss: 0.4401, Accuracy: 0.7872, Time: 32.51s
# Validation Loss: 0.4820, Accuracy: 0.7772
# Epoch 75/99, Loss: 0.4220, Accuracy: 0.7953, Time: 35.11s
# Validation Loss: 0.4860, Accuracy: 0.7822
# Epoch 76/99, Loss: 0.4368, Accuracy: 0.7854, Time: 40.92s
# Validation Loss: 0.4733, Accuracy: 0.7698
# Epoch 77/99, Loss: 0.4386, Accuracy: 0.7909, Time: 32.26s
# Validation Loss: 0.4742, Accuracy: 0.7748
# Epoch 78/99, Loss: 0.4355, Accuracy: 0.7872, Time: 32.14s
# Validation Loss: 0.4720, Accuracy: 0.7772
# Epoch 79/99, Loss: 0.4229, Accuracy: 0.8002, Time: 39.80s
# Validation Loss: 0.4899, Accuracy: 0.7475
# Epoch 80/99, Loss: 0.4288, Accuracy: 0.7971, Time: 33.48s
# Validation Loss: 0.4876, Accuracy: 0.7748
# Epoch 81/99, Loss: 0.4367, Accuracy: 0.7909, Time: 32.38s
# Validation Loss: 0.4692, Accuracy: 0.7822
# Epoch 82/99, Loss: 0.4272, Accuracy: 0.8033, Time: 32.36s
# Validation Loss: 0.4772, Accuracy: 0.7896
# Epoch 83/99, Loss: 0.4212, Accuracy: 0.8015, Time: 42.80s
# Validation Loss: 0.4833, Accuracy: 0.7624
# Epoch 84/99, Loss: 0.4263, Accuracy: 0.7903, Time: 32.16s
# Validation Loss: 0.4898, Accuracy: 0.7624
# Epoch 85/99, Loss: 0.4331, Accuracy: 0.7922, Time: 32.60s
# Validation Loss: 0.4697, Accuracy: 0.7847
# Epoch 86/99, Loss: 0.4256, Accuracy: 0.8015, Time: 42.58s
# Validation Loss: 0.4883, Accuracy: 0.7797
# Epoch 87/99, Loss: 0.4195, Accuracy: 0.8027, Time: 32.10s
# Validation Loss: 0.4785, Accuracy: 0.8020
# Epoch 88/99, Loss: 0.4224, Accuracy: 0.7984, Time: 33.21s
# Validation Loss: 0.4748, Accuracy: 0.8045
# Epoch 89/99, Loss: 0.4257, Accuracy: 0.8015, Time: 40.09s
# Validation Loss: 0.4753, Accuracy: 0.7921
# Epoch 90/99, Loss: 0.4220, Accuracy: 0.7940, Time: 32.22s
# Validation Loss: 0.4712, Accuracy: 0.7946
# Epoch 91/99, Loss: 0.4132, Accuracy: 0.7996, Time: 33.68s
# Validation Loss: 0.4817, Accuracy: 0.7871
# Epoch 92/99, Loss: 0.4112, Accuracy: 0.7996, Time: 40.63s
# Validation Loss: 0.4743, Accuracy: 0.8020
# Epoch 93/99, Loss: 0.4139, Accuracy: 0.8040, Time: 32.00s
# Validation Loss: 0.4826, Accuracy: 0.7871
# Epoch 94/99, Loss: 0.4169, Accuracy: 0.7959, Time: 32.41s
# Validation Loss: 0.4795, Accuracy: 0.7970
# Epoch 95/99, Loss: 0.4155, Accuracy: 0.7922, Time: 37.76s
# Validation Loss: 0.4735, Accuracy: 0.7995
# Epoch 96/99, Loss: 0.4090, Accuracy: 0.7990, Time: 32.90s
# Validation Loss: 0.4698, Accuracy: 0.8045
# Epoch 97/99, Loss: 0.4135, Accuracy: 0.8002, Time: 31.42s
# Validation Loss: 0.4779, Accuracy: 0.7822
# Epoch 98/99, Loss: 0.4147, Accuracy: 0.7978, Time: 31.95s
# Validation Loss: 0.4665, Accuracy: 0.7847
# Epoch 99/99, Loss: 0.4092, Accuracy: 0.8058, Time: 40.07s
# Validation Loss: 0.4680, Accuracy: 0.7995
# Model saved with accuracy: 0.8045
# Matriz de Confusión:
# [[156  39]
#  [ 40 169]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80       195
#            1       0.81      0.81      0.81       209
#
#     accuracy                           0.80       404
#    macro avg       0.80      0.80      0.80       404
# weighted avg       0.80      0.80      0.80       404
#
# Accuracy: 0.8045
