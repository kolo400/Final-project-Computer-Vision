# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 60.6 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7

# %%
import rasterio
import torch
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms, datasets
import matplotlib.pyplot as plt
import os
import shutil
import random
from google.colab import drive
import sys
import time
import json
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from PIL import Image

# %%
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#path = '/content/drive/MyDrive/Academico/Computer Vision'
#sys.path.append(path)
base_dir = os.getcwd()

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
def determine_max_pixel_value(data):
    max_value = 0
    for item in data:
        image = Image.open(item['image_path'])
        if image.mode != 'RGB':
            image = image.convert('RGB')
        image_np = np.array(image)
        max_value = max(max_value, image_np.max())
    return max_value

# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader
import rasterio
import numpy as np
from torchvision import transforms

# Function to load data from JSON file
def load_data(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)
    return data

def scale_and_normalize_image(image, max_value):
    image = np.array(image).astype(np.float32)
    image = (image / image.max()) * 255
    return image/max_value

class TiffDataset(Dataset):
    def __init__(self, data, transform=None, max_value = 255.0):
        self.data = data
        self.transform = transform
        self.max_value = max_value

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        image = Image.open(item['image_path'])

        # Convert to RGB if necessary
        if image.mode != 'RGB':
            image = image.convert('RGB')

        image = scale_and_normalize_image(image, self.max_value)

        if self.transform:
            image = self.transform(image)

        label = item['label']
        return image, label

# Load data from JSON files
train_json_file = base_dir + '/Data/Train_80_enhanced.json'
test_json_file = base_dir + '/Data/Test_20_enhanced.json'
train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

#max_pixel_value = determine_max_pixel_value(train_data)
max_pixel_value = 255.0
# Define transformations


transform_tr = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(degrees=180),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.Resize((224,224)),






])


transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((224,224))

])

# Determine the max pixel value from the training dataset for normalization

# Create datasets
train_dataset = TiffDataset(train_data, transform=transform_tr, max_value=max_pixel_value)
test_dataset = TiffDataset(test_data, transform=transform_val, max_value=max_pixel_value)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
import torch.nn as nn
import torch.optim as optim
import time

model = models.resnet50(weights="DEFAULT")
num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 2)

# Move the model to GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Multi-class classification
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Define a learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1) #Drop to 0.0001 after 50 epochs

# Training function
def train_model(model, criterion, optimizer, train_loader, val_loader, scheduler, num_epochs=100):
    best_acc = 0.0
    best_model_wts = None
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        corrects = 0
        start_time = time.time()

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            corrects += torch.sum(preds == labels.data)

        scheduler.step()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = corrects.double() / len(train_loader.dataset)
        elapsed_time = time.time() - start_time
        print(f"Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}, Time: {elapsed_time:.2f}s")

        # Validate the model
        model.eval()
        val_loss = 0.0
        corrects = 0
        all_labels = []
        all_preds = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                corrects += torch.sum(preds == labels.data)
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(preds.cpu().numpy())


        val_loss /= len(val_loader.dataset)
        val_acc = corrects.double() / len(val_loader.dataset)
        print(f"Validation Loss: {val_loss:.4f}, Accuracy: {val_acc:.4f}")
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = model.state_dict()
            best_all_labels = all_labels
            best_all_preds = all_preds

    model.load_state_dict(best_model_wts)


    torch.save(model.state_dict(), base_dir +  '/Redes_entrenadas/Resnet50_enhanced_fp.pth')
    print('Model saved with accuracy: {:.4f}'.format(best_acc))

    cm = confusion_matrix(best_all_labels, best_all_preds)
    cr = classification_report(best_all_labels, best_all_preds)
    accuracy = (np.array(best_all_preds) == np.array(best_all_labels)).mean()
    print("Matriz de Confusión:")
    print(cm)
    print("Reporte de Clasificación:")
    print(cr)
    print(f"Accuracy: {accuracy:.4f}")

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Clase 0', 'Clase 1'], yticklabels=['Clase 0', 'Clase 1'])
    plt.xlabel('Predicción')
    plt.ylabel('Verdadero')
    plt.title('Matriz de Confusión')
    plt.show()

# Train the model
train_model(model, criterion, optimizer, train_loader, test_loader, scheduler, num_epochs=100)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 214MB/s]
# Epoch 0/99, Loss: 0.5180, Accuracy: 0.7630, Time: 284.44s
# Validation Loss: 0.5162, Accuracy: 0.7475
# Epoch 1/99, Loss: 0.4465, Accuracy: 0.7854, Time: 4.20s
# Validation Loss: 0.4302, Accuracy: 0.8045
# Epoch 2/99, Loss: 0.4218, Accuracy: 0.8065, Time: 4.42s
# Validation Loss: 0.4169, Accuracy: 0.8292
# Epoch 3/99, Loss: 0.3971, Accuracy: 0.8189, Time: 4.26s
# Validation Loss: 0.6707, Accuracy: 0.7277
# Epoch 4/99, Loss: 0.4123, Accuracy: 0.8033, Time: 4.39s
# Validation Loss: 0.4148, Accuracy: 0.8342
# Epoch 5/99, Loss: 0.4042, Accuracy: 0.8213, Time: 4.21s
# Validation Loss: 0.4693, Accuracy: 0.8317
# Epoch 6/99, Loss: 0.4028, Accuracy: 0.8040, Time: 4.24s
# Validation Loss: 0.4062, Accuracy: 0.8168
# Epoch 7/99, Loss: 0.3733, Accuracy: 0.8406, Time: 4.39s
# Validation Loss: 0.4559, Accuracy: 0.7946
# Epoch 8/99, Loss: 0.3791, Accuracy: 0.8207, Time: 4.20s
# Validation Loss: 0.4118, Accuracy: 0.8267
# Epoch 9/99, Loss: 0.3799, Accuracy: 0.8269, Time: 4.34s
# Validation Loss: 0.3826, Accuracy: 0.8391
# Epoch 10/99, Loss: 0.3761, Accuracy: 0.8362, Time: 4.17s
# Validation Loss: 0.4423, Accuracy: 0.8144
# Epoch 11/99, Loss: 0.3816, Accuracy: 0.8244, Time: 4.23s
# Validation Loss: 0.5624, Accuracy: 0.8144
# Epoch 12/99, Loss: 0.3736, Accuracy: 0.8375, Time: 4.48s
# Validation Loss: 0.4107, Accuracy: 0.8465
# Epoch 13/99, Loss: 0.3639, Accuracy: 0.8400, Time: 4.27s
# Validation Loss: 0.4659, Accuracy: 0.8342
# Epoch 14/99, Loss: 0.3435, Accuracy: 0.8462, Time: 4.29s
# Validation Loss: 0.3692, Accuracy: 0.8465
# Epoch 15/99, Loss: 0.3500, Accuracy: 0.8406, Time: 4.25s
# Validation Loss: 0.5322, Accuracy: 0.7624
# Epoch 16/99, Loss: 0.3381, Accuracy: 0.8424, Time: 4.31s
# Validation Loss: 0.4158, Accuracy: 0.8465
# Epoch 17/99, Loss: 0.3376, Accuracy: 0.8418, Time: 4.48s
# Validation Loss: 0.4257, Accuracy: 0.8465
# Epoch 18/99, Loss: 0.3595, Accuracy: 0.8406, Time: 4.21s
# Validation Loss: 0.4182, Accuracy: 0.8342
# Epoch 19/99, Loss: 0.3425, Accuracy: 0.8400, Time: 4.50s
# Validation Loss: 0.4022, Accuracy: 0.8366
# Epoch 20/99, Loss: 0.3317, Accuracy: 0.8517, Time: 4.15s
# Validation Loss: 0.4801, Accuracy: 0.8168
# Epoch 21/99, Loss: 0.3238, Accuracy: 0.8530, Time: 4.26s
# Validation Loss: 0.5410, Accuracy: 0.8416
# Epoch 22/99, Loss: 0.3114, Accuracy: 0.8586, Time: 4.41s
# Validation Loss: 0.4392, Accuracy: 0.8465
# Epoch 23/99, Loss: 0.3319, Accuracy: 0.8561, Time: 4.26s
# Validation Loss: 0.7027, Accuracy: 0.7104
# Epoch 24/99, Loss: 0.3346, Accuracy: 0.8418, Time: 4.30s
# Validation Loss: 0.7298, Accuracy: 0.8045
# Epoch 25/99, Loss: 0.3340, Accuracy: 0.8524, Time: 4.24s
# Validation Loss: 0.5647, Accuracy: 0.7797
# Epoch 26/99, Loss: 0.3181, Accuracy: 0.8567, Time: 4.19s
# Validation Loss: 0.4582, Accuracy: 0.8490
# Epoch 27/99, Loss: 0.3132, Accuracy: 0.8598, Time: 4.43s
# Validation Loss: 0.4849, Accuracy: 0.8366
# Epoch 28/99, Loss: 0.3385, Accuracy: 0.8493, Time: 4.11s
# Validation Loss: 0.4026, Accuracy: 0.8391
# Epoch 29/99, Loss: 0.3281, Accuracy: 0.8561, Time: 4.30s
# Validation Loss: 0.6662, Accuracy: 0.8416
# Epoch 30/99, Loss: 0.3289, Accuracy: 0.8443, Time: 4.27s
# Validation Loss: 0.7886, Accuracy: 0.8441
# Epoch 31/99, Loss: 0.3151, Accuracy: 0.8598, Time: 4.28s
# Validation Loss: 0.4146, Accuracy: 0.8589
# Epoch 32/99, Loss: 0.3190, Accuracy: 0.8648, Time: 4.47s
# Validation Loss: 0.4295, Accuracy: 0.8144
# Epoch 33/99, Loss: 0.3143, Accuracy: 0.8623, Time: 4.20s
# Validation Loss: 0.3920, Accuracy: 0.8564
# Epoch 34/99, Loss: 0.3038, Accuracy: 0.8672, Time: 4.48s
# Validation Loss: 0.4298, Accuracy: 0.7921
# Epoch 35/99, Loss: 0.3043, Accuracy: 0.8685, Time: 4.29s
# Validation Loss: 0.5139, Accuracy: 0.8168
# Epoch 36/99, Loss: 0.3110, Accuracy: 0.8629, Time: 4.28s
# Validation Loss: 0.5009, Accuracy: 0.7871
# Epoch 37/99, Loss: 0.3012, Accuracy: 0.8586, Time: 4.44s
# Validation Loss: 0.4100, Accuracy: 0.8490
# Epoch 38/99, Loss: 0.2965, Accuracy: 0.8728, Time: 4.21s
# Validation Loss: 0.3810, Accuracy: 0.8168
# Epoch 39/99, Loss: 0.2972, Accuracy: 0.8629, Time: 4.31s
# Validation Loss: 0.8073, Accuracy: 0.7797
# Epoch 40/99, Loss: 0.3222, Accuracy: 0.8548, Time: 4.36s
# Validation Loss: 0.5068, Accuracy: 0.8243
# Epoch 41/99, Loss: 0.3120, Accuracy: 0.8548, Time: 4.26s
# Validation Loss: 0.4041, Accuracy: 0.8292
# Epoch 42/99, Loss: 0.3084, Accuracy: 0.8592, Time: 4.45s
# Validation Loss: 0.4395, Accuracy: 0.8391
# Epoch 43/99, Loss: 0.3045, Accuracy: 0.8648, Time: 4.14s
# Validation Loss: 0.6396, Accuracy: 0.8416
# Epoch 44/99, Loss: 0.2929, Accuracy: 0.8641, Time: 4.37s
# Validation Loss: 0.4251, Accuracy: 0.8564
# Epoch 45/99, Loss: 0.2928, Accuracy: 0.8648, Time: 4.22s
# Validation Loss: 0.9332, Accuracy: 0.6832
# Epoch 46/99, Loss: 0.2999, Accuracy: 0.8710, Time: 4.20s
# Validation Loss: 1.1338, Accuracy: 0.7153
# Epoch 47/99, Loss: 0.2771, Accuracy: 0.8734, Time: 4.48s
# Validation Loss: 0.5407, Accuracy: 0.7871
# Epoch 48/99, Loss: 0.2806, Accuracy: 0.8828, Time: 4.15s
# Validation Loss: 0.8895, Accuracy: 0.8267
# Epoch 49/99, Loss: 0.2742, Accuracy: 0.8871, Time: 4.21s
# Validation Loss: 0.9577, Accuracy: 0.7624
# Epoch 50/99, Loss: 0.2621, Accuracy: 0.8809, Time: 4.25s
# Validation Loss: 0.4664, Accuracy: 0.8441
# Epoch 51/99, Loss: 0.2409, Accuracy: 0.8852, Time: 4.25s
# Validation Loss: 0.4868, Accuracy: 0.8564
# Epoch 52/99, Loss: 0.2321, Accuracy: 0.9014, Time: 4.40s
# Validation Loss: 0.4798, Accuracy: 0.8515
# Epoch 53/99, Loss: 0.2250, Accuracy: 0.9045, Time: 4.13s
# Validation Loss: 0.4675, Accuracy: 0.8589
# Epoch 54/99, Loss: 0.2292, Accuracy: 0.8983, Time: 4.46s
# Validation Loss: 0.4727, Accuracy: 0.8540
# Epoch 55/99, Loss: 0.2199, Accuracy: 0.9057, Time: 4.62s
# Validation Loss: 0.4793, Accuracy: 0.8515
# Epoch 56/99, Loss: 0.2233, Accuracy: 0.9014, Time: 4.19s
# Validation Loss: 0.4637, Accuracy: 0.8441
# Epoch 57/99, Loss: 0.2125, Accuracy: 0.9069, Time: 4.42s
# Validation Loss: 0.4859, Accuracy: 0.8465
# Epoch 58/99, Loss: 0.2090, Accuracy: 0.9045, Time: 4.22s
# Validation Loss: 0.4747, Accuracy: 0.8441
# Epoch 59/99, Loss: 0.2129, Accuracy: 0.9063, Time: 4.25s
# Validation Loss: 0.4886, Accuracy: 0.8465
# Epoch 60/99, Loss: 0.1958, Accuracy: 0.9150, Time: 4.19s
# Validation Loss: 0.5003, Accuracy: 0.8465
# Epoch 61/99, Loss: 0.2038, Accuracy: 0.9150, Time: 4.18s
# Validation Loss: 0.5229, Accuracy: 0.8465
# Epoch 62/99, Loss: 0.1993, Accuracy: 0.9132, Time: 4.44s
# Validation Loss: 0.5033, Accuracy: 0.8441
# Epoch 63/99, Loss: 0.2012, Accuracy: 0.9150, Time: 4.48s
# Validation Loss: 0.5342, Accuracy: 0.8490
# Epoch 64/99, Loss: 0.1924, Accuracy: 0.9144, Time: 4.53s
# Validation Loss: 0.5443, Accuracy: 0.8342
# Epoch 65/99, Loss: 0.1762, Accuracy: 0.9237, Time: 4.23s
# Validation Loss: 0.5346, Accuracy: 0.8342
# Epoch 66/99, Loss: 0.1981, Accuracy: 0.9169, Time: 4.21s
# Validation Loss: 0.5561, Accuracy: 0.8441
# Epoch 67/99, Loss: 0.1897, Accuracy: 0.9249, Time: 4.36s
# Validation Loss: 0.5665, Accuracy: 0.8441
# Epoch 68/99, Loss: 0.1739, Accuracy: 0.9280, Time: 4.30s
# Validation Loss: 0.5184, Accuracy: 0.8465
# Epoch 69/99, Loss: 0.1778, Accuracy: 0.9206, Time: 4.33s
# Validation Loss: 0.5584, Accuracy: 0.8540
# Epoch 70/99, Loss: 0.1728, Accuracy: 0.9293, Time: 4.23s
# Validation Loss: 0.5293, Accuracy: 0.8441
# Epoch 71/99, Loss: 0.1771, Accuracy: 0.9262, Time: 4.13s
# Validation Loss: 0.5857, Accuracy: 0.8317
# Epoch 72/99, Loss: 0.1824, Accuracy: 0.9243, Time: 4.32s
# Validation Loss: 0.5567, Accuracy: 0.8342
# Epoch 73/99, Loss: 0.1695, Accuracy: 0.9367, Time: 4.24s
# Validation Loss: 0.5691, Accuracy: 0.8366
# Epoch 74/99, Loss: 0.1788, Accuracy: 0.9218, Time: 4.31s
# Validation Loss: 0.5336, Accuracy: 0.8391
# Epoch 75/99, Loss: 0.1707, Accuracy: 0.9262, Time: 4.14s
# Validation Loss: 0.5528, Accuracy: 0.8391
# Epoch 76/99, Loss: 0.1758, Accuracy: 0.9175, Time: 4.28s
# Validation Loss: 0.5497, Accuracy: 0.8317
# Epoch 77/99, Loss: 0.1648, Accuracy: 0.9349, Time: 4.38s
# Validation Loss: 0.6138, Accuracy: 0.8366
# Epoch 78/99, Loss: 0.1693, Accuracy: 0.9355, Time: 4.14s
# Validation Loss: 0.6016, Accuracy: 0.8342
# Epoch 79/99, Loss: 0.1555, Accuracy: 0.9373, Time: 4.32s
# Validation Loss: 0.6491, Accuracy: 0.8416
# Epoch 80/99, Loss: 0.1439, Accuracy: 0.9429, Time: 4.20s
# Validation Loss: 0.6255, Accuracy: 0.8540
# Epoch 81/99, Loss: 0.1458, Accuracy: 0.9367, Time: 4.25s
# Validation Loss: 0.6268, Accuracy: 0.8490
# Epoch 82/99, Loss: 0.1536, Accuracy: 0.9386, Time: 4.31s
# Validation Loss: 0.5969, Accuracy: 0.8465
# Epoch 83/99, Loss: 0.1461, Accuracy: 0.9361, Time: 4.11s
# Validation Loss: 0.6154, Accuracy: 0.8292
# Epoch 84/99, Loss: 0.1433, Accuracy: 0.9386, Time: 4.35s
# Validation Loss: 0.6376, Accuracy: 0.8391
# Epoch 85/99, Loss: 0.1355, Accuracy: 0.9386, Time: 4.29s
# Validation Loss: 0.6317, Accuracy: 0.8515
# Epoch 86/99, Loss: 0.1439, Accuracy: 0.9429, Time: 4.22s
# Validation Loss: 0.6747, Accuracy: 0.8416
# Epoch 87/99, Loss: 0.1335, Accuracy: 0.9467, Time: 4.32s
# Validation Loss: 0.6044, Accuracy: 0.8317
# Epoch 88/99, Loss: 0.1389, Accuracy: 0.9448, Time: 4.25s
# Validation Loss: 0.6762, Accuracy: 0.8366
# Epoch 89/99, Loss: 0.1221, Accuracy: 0.9522, Time: 4.35s
# Validation Loss: 0.6602, Accuracy: 0.8490
# Epoch 90/99, Loss: 0.1336, Accuracy: 0.9467, Time: 4.22s
# Validation Loss: 0.6070, Accuracy: 0.8193
# Epoch 91/99, Loss: 0.1356, Accuracy: 0.9473, Time: 4.21s
# Validation Loss: 0.6324, Accuracy: 0.8292
# Epoch 92/99, Loss: 0.1426, Accuracy: 0.9423, Time: 4.49s
# Validation Loss: 0.6939, Accuracy: 0.8465
# Epoch 93/99, Loss: 0.1214, Accuracy: 0.9473, Time: 4.17s
# Validation Loss: 0.7582, Accuracy: 0.8243
# Epoch 94/99, Loss: 0.1088, Accuracy: 0.9553, Time: 4.33s
# Validation Loss: 0.8358, Accuracy: 0.8267
# Epoch 95/99, Loss: 0.1176, Accuracy: 0.9560, Time: 4.15s
# Validation Loss: 0.7586, Accuracy: 0.8391
# Epoch 96/99, Loss: 0.1184, Accuracy: 0.9535, Time: 4.15s
# Validation Loss: 0.6892, Accuracy: 0.8342
# Epoch 97/99, Loss: 0.1349, Accuracy: 0.9454, Time: 4.33s
# Validation Loss: 0.7308, Accuracy: 0.8515
# Epoch 98/99, Loss: 0.1118, Accuracy: 0.9547, Time: 4.21s
# Validation Loss: 0.7089, Accuracy: 0.8366
# Epoch 99/99, Loss: 0.1208, Accuracy: 0.9516, Time: 4.48s
# Validation Loss: 0.7324, Accuracy: 0.8366
# Model saved with accuracy: 0.8589
# Matriz de Confusión:
# [[154  41]
#  [ 16 193]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.84       195
#            1       0.82      0.92      0.87       209
#
#     accuracy                           0.86       404
#    macro avg       0.87      0.86      0.86       404
# weighted avg       0.86      0.86      0.86       404
#
# Accuracy: 0.8589
