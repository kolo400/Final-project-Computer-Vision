# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 50.9 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7

# %%
import rasterio
import torch
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms, datasets
import matplotlib.pyplot as plt
import os
import shutil
import random
from google.colab import drive
import sys
import time
import json
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from PIL import Image

# %%
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#path = '/content/drive/MyDrive/Academico/Computer Vision'
#sys.path.append(path)
base_dir = os.getcwd()

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
def determine_max_pixel_value(data):
    max_value = 0
    for item in data:
        with rasterio.open(item['image_path']) as src:
            max_value = max(max_value, src.read([1,2,3]).max())
    return max_value

# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader
import rasterio
import numpy as np
from torchvision import transforms

# Function to load data from JSON file
def load_data(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)
    return data

def scale_and_normalize_image(image, max_value):
    image = np.array(image).astype(np.float32)
    image = (image / image.max()) * 255
    return image/max_value

class TiffDataset(Dataset):
    def __init__(self, data, transform=None, max_value = 255.0):
        self.data = data
        self.transform = transform
        self.max_value = max_value

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):

        item = self.data[idx]
        with rasterio.open(item['image_path']) as src:
            image = src.read([1,2,3])  # Read RGB bands
            image = np.transpose(image, (1, 2, 0))  # Channels last
            image = scale_and_normalize_image(image, self.max_value)

        if self.transform:
          image = self.transform(image)


        label = item['label']
        return image, label


# Load data from JSON files
train_json_file = base_dir + '/Data/Train_80.json'
test_json_file = base_dir + '/content/drive/MyDrive/Academico/Computer Vision/Test_20.json'
train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

train_data = load_data(train_json_file)
test_data = load_data(test_json_file)

#max_pixel_value = determine_max_pixel_value(train_data)
max_pixel_value = 255.0
# Define transformations


transform_tr = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(degrees=180),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.Resize((224,224)),






])


transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((224,224))




])

# Determine the max pixel value from the training dataset for normalization

# Create datasets
train_dataset = TiffDataset(train_data, transform=transform_tr, max_value=max_pixel_value)
test_dataset = TiffDataset(test_data, transform=transform_val, max_value=max_pixel_value)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
import torch.nn as nn
import torch.optim as optim
import time


model = models.vgg13(weights="DEFAULT")
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 2)

# Move the model to GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Multi-class classification
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Define a learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1) #Drop to 0.0001 after 50 epochs

# Training function
def train_model(model, criterion, optimizer, train_loader, val_loader, scheduler, num_epochs=100):
    best_acc = 0.0
    best_model_wts = None
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        corrects = 0
        start_time = time.time()

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            corrects += torch.sum(preds == labels.data)

        scheduler.step()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = corrects.double() / len(train_loader.dataset)
        elapsed_time = time.time() - start_time
        print(f"Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}, Time: {elapsed_time:.2f}s")

        # Validate the model
        model.eval()
        val_loss = 0.0
        corrects = 0
        all_labels = []
        all_preds = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                corrects += torch.sum(preds == labels.data)
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(preds.cpu().numpy())


        val_loss /= len(val_loader.dataset)
        val_acc = corrects.double() / len(val_loader.dataset)
        print(f"Validation Loss: {val_loss:.4f}, Accuracy: {val_acc:.4f}")
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = model.state_dict()
            best_all_labels = all_labels
            best_all_preds = all_preds

    model.load_state_dict(best_model_wts)


    torch.save(model.state_dict(), base_dir + '/Redes_entrenadas/Vgg13_not_enhanced.pth')
    print('Model saved with accuracy: {:.4f}'.format(best_acc))

    cm = confusion_matrix(best_all_labels, best_all_preds)
    cr = classification_report(best_all_labels, best_all_preds)
    accuracy = (np.array(best_all_preds) == np.array(best_all_labels)).mean()
    print("Matriz de Confusión:")
    print(cm)
    print("Reporte de Clasificación:")
    print(cr)
    print(f"Accuracy: {accuracy:.4f}")

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Clase 0', 'Clase 1'], yticklabels=['Clase 0', 'Clase 1'])
    plt.xlabel('Predicción')
    plt.ylabel('Verdadero')
    plt.title('Matriz de Confusión')
    plt.show()

# Train the model
train_model(model, criterion, optimizer, train_loader, test_loader, scheduler, num_epochs=100)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg13-19584684.pth" to /root/.cache/torch/hub/checkpoints/vgg13-19584684.pth
# 100%|██████████| 508M/508M [00:04<00:00, 130MB/s]
# Epoch 0/99, Loss: 1.0234, Accuracy: 0.5062, Time: 80.25s
# Validation Loss: 0.7017, Accuracy: 0.5173
# Epoch 1/99, Loss: 0.7093, Accuracy: 0.4833, Time: 35.36s
# Validation Loss: 0.6918, Accuracy: 0.5173
# Epoch 2/99, Loss: 0.7340, Accuracy: 0.4926, Time: 44.96s
# Validation Loss: 0.6764, Accuracy: 0.6262
# Epoch 3/99, Loss: 0.6961, Accuracy: 0.5360, Time: 32.77s
# Validation Loss: 0.6919, Accuracy: 0.5173
# Epoch 4/99, Loss: 0.7056, Accuracy: 0.5043, Time: 33.69s
# Validation Loss: 0.7000, Accuracy: 0.4827
# Epoch 5/99, Loss: 0.6973, Accuracy: 0.5217, Time: 43.86s
# Validation Loss: 0.7432, Accuracy: 0.5173
# Epoch 6/99, Loss: 0.7024, Accuracy: 0.5062, Time: 32.80s
# Validation Loss: 0.6973, Accuracy: 0.4827
# Epoch 7/99, Loss: 0.7007, Accuracy: 0.4932, Time: 32.00s
# Validation Loss: 0.7026, Accuracy: 0.4827
# Epoch 8/99, Loss: 0.7008, Accuracy: 0.5037, Time: 42.46s
# Validation Loss: 0.6928, Accuracy: 0.5173
# Epoch 9/99, Loss: 0.6960, Accuracy: 0.5068, Time: 30.78s
# Validation Loss: 0.6931, Accuracy: 0.5173
# Epoch 10/99, Loss: 0.6949, Accuracy: 0.5006, Time: 32.06s
# Validation Loss: 0.6926, Accuracy: 0.5173
# Epoch 11/99, Loss: 0.6964, Accuracy: 0.4870, Time: 41.18s
# Validation Loss: 0.6931, Accuracy: 0.5173
# Epoch 12/99, Loss: 0.6974, Accuracy: 0.5136, Time: 31.15s
# Validation Loss: 0.7069, Accuracy: 0.4827
# Epoch 13/99, Loss: 0.7002, Accuracy: 0.4845, Time: 34.27s
# Validation Loss: 0.6948, Accuracy: 0.4827
# Epoch 14/99, Loss: 0.6972, Accuracy: 0.5180, Time: 39.80s
# Validation Loss: 0.6951, Accuracy: 0.5173
# Epoch 15/99, Loss: 0.6952, Accuracy: 0.5087, Time: 32.07s
# Validation Loss: 0.6937, Accuracy: 0.5173
# Epoch 16/99, Loss: 0.6974, Accuracy: 0.5056, Time: 31.70s
# Validation Loss: 0.6947, Accuracy: 0.4827
# Epoch 17/99, Loss: 0.6968, Accuracy: 0.4926, Time: 31.87s
# Validation Loss: 0.6929, Accuracy: 0.5173
# Epoch 18/99, Loss: 0.6952, Accuracy: 0.4845, Time: 42.24s
# Validation Loss: 0.6926, Accuracy: 0.5173
# Epoch 19/99, Loss: 0.6969, Accuracy: 0.5093, Time: 32.14s
# Validation Loss: 0.6952, Accuracy: 0.5173
# Epoch 20/99, Loss: 0.6957, Accuracy: 0.5025, Time: 34.81s
# Validation Loss: 0.6945, Accuracy: 0.4827
# Epoch 21/99, Loss: 0.6938, Accuracy: 0.5180, Time: 39.63s
# Validation Loss: 0.7039, Accuracy: 0.4827
# Epoch 22/99, Loss: 0.7011, Accuracy: 0.4659, Time: 32.84s
# Validation Loss: 0.6931, Accuracy: 0.5173
# Epoch 23/99, Loss: 0.6959, Accuracy: 0.4926, Time: 33.00s
# Validation Loss: 0.7038, Accuracy: 0.4827
# Epoch 24/99, Loss: 0.6962, Accuracy: 0.4851, Time: 45.16s
# Validation Loss: 0.6947, Accuracy: 0.4827
# Epoch 25/99, Loss: 0.6963, Accuracy: 0.4926, Time: 36.83s
# Validation Loss: 0.6951, Accuracy: 0.4827
# Epoch 26/99, Loss: 0.6971, Accuracy: 0.4895, Time: 34.39s
# Validation Loss: 0.6997, Accuracy: 0.4827
# Epoch 27/99, Loss: 0.6988, Accuracy: 0.5043, Time: 43.17s
# Validation Loss: 0.7051, Accuracy: 0.4827
# Epoch 28/99, Loss: 0.6954, Accuracy: 0.5130, Time: 35.53s
# Validation Loss: 0.7051, Accuracy: 0.4827
# Epoch 29/99, Loss: 0.6972, Accuracy: 0.4888, Time: 33.93s
# Validation Loss: 0.6997, Accuracy: 0.4827
# Epoch 30/99, Loss: 0.6934, Accuracy: 0.5167, Time: 41.57s
# Validation Loss: 0.6927, Accuracy: 0.5173
# Epoch 31/99, Loss: 0.6968, Accuracy: 0.4938, Time: 34.49s
# Validation Loss: 0.6925, Accuracy: 0.5173
# Epoch 32/99, Loss: 0.6936, Accuracy: 0.5081, Time: 33.22s
# Validation Loss: 0.6940, Accuracy: 0.4827
# Epoch 33/99, Loss: 0.6951, Accuracy: 0.5081, Time: 43.62s
# Validation Loss: 0.6965, Accuracy: 0.4827
# Epoch 34/99, Loss: 0.6957, Accuracy: 0.4795, Time: 34.58s
# Validation Loss: 0.6956, Accuracy: 0.4827
# Epoch 35/99, Loss: 0.6942, Accuracy: 0.4895, Time: 34.45s
# Validation Loss: 0.6974, Accuracy: 0.4827
# Epoch 36/99, Loss: 0.6916, Accuracy: 0.5261, Time: 42.41s
# Validation Loss: 0.6933, Accuracy: 0.5173
# Epoch 37/99, Loss: 0.6961, Accuracy: 0.4969, Time: 32.85s
# Validation Loss: 0.6975, Accuracy: 0.4827
# Epoch 38/99, Loss: 0.6952, Accuracy: 0.5000, Time: 34.32s
# Validation Loss: 0.6949, Accuracy: 0.4827
# Epoch 39/99, Loss: 0.6930, Accuracy: 0.5211, Time: 42.57s
# Validation Loss: 0.6934, Accuracy: 0.4827
# Epoch 40/99, Loss: 0.6940, Accuracy: 0.5105, Time: 34.11s
# Validation Loss: 0.6934, Accuracy: 0.5173
# Epoch 41/99, Loss: 0.6958, Accuracy: 0.4901, Time: 34.69s
# Validation Loss: 0.6926, Accuracy: 0.5173
# Epoch 42/99, Loss: 0.6944, Accuracy: 0.5136, Time: 42.38s
# Validation Loss: 0.6930, Accuracy: 0.5173
# Epoch 43/99, Loss: 0.6953, Accuracy: 0.4944, Time: 35.19s
# Validation Loss: 0.6934, Accuracy: 0.4827
# Epoch 44/99, Loss: 0.6955, Accuracy: 0.4938, Time: 34.26s
# Validation Loss: 0.6938, Accuracy: 0.4827
# Epoch 45/99, Loss: 0.6950, Accuracy: 0.4882, Time: 43.23s
# Validation Loss: 0.6926, Accuracy: 0.5173
# Epoch 46/99, Loss: 0.6957, Accuracy: 0.4727, Time: 32.78s
# Validation Loss: 0.6952, Accuracy: 0.4827
# Epoch 47/99, Loss: 0.6938, Accuracy: 0.4944, Time: 33.52s
# Validation Loss: 0.6936, Accuracy: 0.4827
# Epoch 48/99, Loss: 0.6947, Accuracy: 0.5081, Time: 41.46s
# Validation Loss: 0.6939, Accuracy: 0.4827
# Epoch 49/99, Loss: 0.6947, Accuracy: 0.5167, Time: 32.82s
# Validation Loss: 0.6932, Accuracy: 0.5173
# Epoch 50/99, Loss: 0.6962, Accuracy: 0.4901, Time: 33.95s
# Validation Loss: 0.6925, Accuracy: 0.5173
# Epoch 51/99, Loss: 0.6937, Accuracy: 0.5105, Time: 41.53s
# Validation Loss: 0.6929, Accuracy: 0.5173
# Epoch 52/99, Loss: 0.6930, Accuracy: 0.5217, Time: 34.05s
# Validation Loss: 0.6934, Accuracy: 0.4827
# Epoch 53/99, Loss: 0.6934, Accuracy: 0.4944, Time: 34.75s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 54/99, Loss: 0.6936, Accuracy: 0.5149, Time: 42.59s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 55/99, Loss: 0.6945, Accuracy: 0.4801, Time: 36.19s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 56/99, Loss: 0.6942, Accuracy: 0.4895, Time: 33.58s
# Validation Loss: 0.6936, Accuracy: 0.4827
# Epoch 57/99, Loss: 0.6935, Accuracy: 0.5118, Time: 42.41s
# Validation Loss: 0.6933, Accuracy: 0.4827
# Epoch 58/99, Loss: 0.6935, Accuracy: 0.5006, Time: 33.84s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 59/99, Loss: 0.6942, Accuracy: 0.4864, Time: 32.34s
# Validation Loss: 0.6932, Accuracy: 0.4827
# Epoch 60/99, Loss: 0.6935, Accuracy: 0.5087, Time: 32.71s
# Validation Loss: 0.6938, Accuracy: 0.4827
# Epoch 61/99, Loss: 0.6941, Accuracy: 0.5068, Time: 41.34s
# Validation Loss: 0.6937, Accuracy: 0.4827
# Epoch 62/99, Loss: 0.6942, Accuracy: 0.4870, Time: 34.36s
# Validation Loss: 0.6936, Accuracy: 0.4827
# Epoch 63/99, Loss: 0.6923, Accuracy: 0.5167, Time: 34.29s
# Validation Loss: 0.6932, Accuracy: 0.4827
# Epoch 64/99, Loss: 0.6939, Accuracy: 0.5087, Time: 41.82s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 65/99, Loss: 0.6941, Accuracy: 0.4839, Time: 34.34s
# Validation Loss: 0.6932, Accuracy: 0.4827
# Epoch 66/99, Loss: 0.6942, Accuracy: 0.4919, Time: 33.40s
# Validation Loss: 0.6934, Accuracy: 0.4827
# Epoch 67/99, Loss: 0.6936, Accuracy: 0.5087, Time: 39.32s
# Validation Loss: 0.6934, Accuracy: 0.4827
# Epoch 68/99, Loss: 0.6940, Accuracy: 0.4957, Time: 33.79s
# Validation Loss: 0.6933, Accuracy: 0.4827
# Epoch 69/99, Loss: 0.6939, Accuracy: 0.5006, Time: 33.01s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 70/99, Loss: 0.6942, Accuracy: 0.5025, Time: 41.51s
# Validation Loss: 0.6932, Accuracy: 0.4827
# Epoch 71/99, Loss: 0.6935, Accuracy: 0.5074, Time: 34.43s
# Validation Loss: 0.6932, Accuracy: 0.4827
# Epoch 72/99, Loss: 0.6940, Accuracy: 0.4845, Time: 33.74s
# Validation Loss: 0.6936, Accuracy: 0.4827
# Epoch 73/99, Loss: 0.6936, Accuracy: 0.5081, Time: 41.93s
# Validation Loss: 0.6936, Accuracy: 0.4827
# Epoch 74/99, Loss: 0.6933, Accuracy: 0.5068, Time: 33.11s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 75/99, Loss: 0.6944, Accuracy: 0.4938, Time: 32.45s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 76/99, Loss: 0.6937, Accuracy: 0.5000, Time: 40.63s
# Validation Loss: 0.6936, Accuracy: 0.4827
# Epoch 77/99, Loss: 0.6938, Accuracy: 0.5025, Time: 33.87s
# Validation Loss: 0.6934, Accuracy: 0.4827
# Epoch 78/99, Loss: 0.6938, Accuracy: 0.5068, Time: 33.60s
# Validation Loss: 0.6936, Accuracy: 0.4827
# Epoch 79/99, Loss: 0.6947, Accuracy: 0.4907, Time: 37.12s
# Validation Loss: 0.6936, Accuracy: 0.4827
# Epoch 80/99, Loss: 0.6941, Accuracy: 0.4919, Time: 33.86s
# Validation Loss: 0.6934, Accuracy: 0.4827
# Epoch 81/99, Loss: 0.6927, Accuracy: 0.5180, Time: 32.48s
# Validation Loss: 0.6937, Accuracy: 0.4827
# Epoch 82/99, Loss: 0.6935, Accuracy: 0.4981, Time: 33.85s
# Validation Loss: 0.6933, Accuracy: 0.4827
# Epoch 83/99, Loss: 0.6934, Accuracy: 0.4913, Time: 36.12s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 84/99, Loss: 0.6933, Accuracy: 0.5043, Time: 29.08s
# Validation Loss: 0.6934, Accuracy: 0.4827
# Epoch 85/99, Loss: 0.6936, Accuracy: 0.5205, Time: 29.05s
# Validation Loss: 0.6934, Accuracy: 0.4827
# Epoch 86/99, Loss: 0.6930, Accuracy: 0.5081, Time: 38.04s
# Validation Loss: 0.6937, Accuracy: 0.4827
# Epoch 87/99, Loss: 0.6933, Accuracy: 0.5180, Time: 30.43s
# Validation Loss: 0.6937, Accuracy: 0.4827
# Epoch 88/99, Loss: 0.6945, Accuracy: 0.4957, Time: 28.36s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 89/99, Loss: 0.6942, Accuracy: 0.4801, Time: 30.27s
# Validation Loss: 0.6937, Accuracy: 0.4827
# Epoch 90/99, Loss: 0.6948, Accuracy: 0.4789, Time: 36.50s
# Validation Loss: 0.6937, Accuracy: 0.4827
# Epoch 91/99, Loss: 0.6943, Accuracy: 0.4882, Time: 30.63s
# Validation Loss: 0.6936, Accuracy: 0.4827
# Epoch 92/99, Loss: 0.6927, Accuracy: 0.5037, Time: 31.72s
# Validation Loss: 0.6937, Accuracy: 0.4827
# Epoch 93/99, Loss: 0.6934, Accuracy: 0.5143, Time: 39.50s
# Validation Loss: 0.6933, Accuracy: 0.4827
# Epoch 94/99, Loss: 0.6936, Accuracy: 0.5081, Time: 31.96s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 95/99, Loss: 0.6944, Accuracy: 0.4957, Time: 29.30s
# Validation Loss: 0.6935, Accuracy: 0.4827
# Epoch 96/99, Loss: 0.6938, Accuracy: 0.4876, Time: 28.94s
# Validation Loss: 0.6936, Accuracy: 0.4827
# Epoch 97/99, Loss: 0.6941, Accuracy: 0.5043, Time: 36.76s
# Validation Loss: 0.6939, Accuracy: 0.4827
# Epoch 98/99, Loss: 0.6944, Accuracy: 0.4808, Time: 29.10s
# Validation Loss: 0.6934, Accuracy: 0.4827
# Epoch 99/99, Loss: 0.6929, Accuracy: 0.5074, Time: 30.65s
# Validation Loss: 0.6933, Accuracy: 0.4827
# Model saved with accuracy: 0.6262
# Matriz de Confusión:
# [[ 64 131]
#  [ 20 189]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.76      0.33      0.46       195
#            1       0.59      0.90      0.71       209
#
#     accuracy                           0.63       404
#    macro avg       0.68      0.62      0.59       404
# weighted avg       0.67      0.63      0.59       404
#
# Accuracy: 0.6262
